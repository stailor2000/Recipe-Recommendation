# %%
import ollama
import pandas as pd
import sqlite3
import re
from collections import Counter
import json
from thefuzz import fuzz
from itertools import combinations

# %%
# Retrieve recipes data from db
conn = sqlite3.connect("./data/all_recipes.db")
query = "SELECT * FROM recipes"
df_recipes = pd.read_sql_query(query, conn)
conn.close()

# %%
# Function to find all unique words in a column regaerdless of the entry being a list of words
def find_unique_vals(df, column_name):
    unique_list = set(
        word.strip()
        for courses in df[column_name]
        if courses is not None  # Skip None values
        for word in courses.split(";")
    )
    return unique_list

# %%
# Find all ingredients mentioned across all recipes
ingredients_list = find_unique_vals(df_recipes, "ingredients")
print("Number of ingredients:", len(ingredients_list))

# Convert from set to list
ingredients_list = list(ingredients_list)

ingredient_mappings = dict()
# Out:
# Number of ingredients: 3617

# %%
# Function to clean non-alphabetical characters (except spaces)
def clean_ingredient(ingredient):
    # Remove anything that is not a letter or space
    return re.sub(r"[^a-zA-Z\s]", "", ingredient)


# Clean the entire ingredients list before processing
ingredients_list = [clean_ingredient(ingredient) for ingredient in ingredients_list]

# %%
print("Number of ingredients to process: ", len(ingredients_list))

# Updated regex pattern to support both single and double quotes
pattern = r"['\"]([a-zA-Z\s]+)['\"]\s*:\s*['\"]([a-zA-Z\s]+)['\"]"

# how many ingredients to give the LLM at a time
n = 20


while ingredients_list:

    # gets the current batch of ingredients for LLM to process
    current_ingredients, ingredients_list = ingredients_list[:n], ingredients_list[n:]
    number_ingredients = len(current_ingredients)

    content = f"""The following are common ingredient variations. Normalize each ingredient variation by mapping it to the appropriate standardized name:

    Salt, Kosher Salt, Sea Salt, Flaky Salt -> Salt
    Olive Oil, Extra Virgin Olive Oil, Virgin Olive Oil -> Olive Oil
    Tomatoes, Canned Tomatoes, Cherry Tomatoes, Roma Tomatoes -> Tomatoes
    Potatoes, Russet Potatoes, Yukon Gold Potatoes -> Potatoes
    Garlic, Garlic Powder, Minced Garlic -> Garlic

    Create a python dictionary, where each key refers to one of the original ingredients lists below and its value is your answer. You can only give one ingredient answer. Do not include the above examples in the python dictionary to be created. Do not return anything other than the python dictionary in your response.

    There are {number_ingredients} listed below, as such you must output {number_ingredients} ingredient mappings. If the ingredient is in fact not an ingredient then assign it 'NaN'.
    Normalize the ingredients found in this python list:
    {current_ingredients}"""

    response = ollama.generate(model="gemma2", prompt=content)

    #### ADD INGREDIENT MAPPINGS TO GLOBAL LIST
    raw_output = response["response"]

    # Find all matching pairs
    matches = re.findall(pattern, raw_output)

    # Create a dictionary from the matches
    ingredient_standardization = dict(matches)
    ingredient_mappings.update(ingredient_standardization)

    ## Find all the ingredients the LLM didn't process so it can re-process it
    llm_returned_keys = list(ingredient_standardization.keys())
    missing_items = [
        item for item in current_ingredients if item not in llm_returned_keys
    ]
    ingredients_list.extend(missing_items)

    print(f"\rNumber of ingredients processed: {len(ingredient_mappings)}", end="")

    if ingredients_list == []:
        break
# Out:
# Number of ingredients to process:  3597
# Number of ingredients processed: 3601
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 30
#      14 number_ingredients = len(current_ingredients)
#      16 content = f"""The following are common ingredient variations. Normalize each ingredient variation by mapping it to the appropriate standardized name:
#      17
#      18 Salt, Kosher Salt, Sea Salt, Flaky Salt -> Salt
#    (...)
#      27 Normalize the ingredients found in this python list:
#      28 {current_ingredients}"""
# ---> 30 response = ollama.generate(model="gemma2", prompt=content)
#      32 #### ADD INGREDIENT MAPPINGS TO GLOBAL LIST
#      33 raw_output = response["response"]
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/ollama/_client.py:241, in Client.generate(self, model, prompt, suffix, system, template, context, stream, raw, format, images, options, keep_alive)
#     215 def generate(
#     216   self,
#     217   model: str = '',
#    (...)
#     229   keep_alive: Optional[Union[float, str]] = None,
#     230 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     231   """
#     232   Create a response using the requested model.
#     233
#    (...)
#     238   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     239   """
# --> 241   return self._request(
#     242     GenerateResponse,
#     243     'POST',
#     244     '/api/generate',
#     245     json=GenerateRequest(
#     246       model=model,
#     247       prompt=prompt,
#     248       suffix=suffix,
#     249       system=system,
#     250       template=template,
#     251       context=context,
#     252       stream=stream,
#     253       raw=raw,
#     254       format=format,
#     255       images=[Image(value=image) for image in images] if images else None,
#     256       options=options,
#     257       keep_alive=keep_alive,
#     258     ).model_dump(exclude_none=True),
#     259     stream=stream,
#     260   )
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/ollama/_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     117 def _request_raw(self, *args, **kwargs):
# --> 118   r = self._client.request(*args, **kwargs)
#     119   try:
#     120     r.raise_for_status()
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/envs/recipes/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
# Saves standadised names to a .txt file so its not lost
with open("standardised_names.txt", "w") as convert_file:
    convert_file.write(json.dumps(ingredient_mappings))

# %% [markdown]
# ------
#
# ## Re-Evaluate Ingredients with NaN Values

# %%
# Get all keys where the values are NaN
nan_ingredients = [key for key, value in ingredient_mappings.items() if value == "NaN"]
print(nan_ingredients)
print(len(nan_ingredients))

# Saves NaN names to a .txt file so its not lost
with open("NaN_names.txt", "w") as convert_file:
    convert_file.write(json.dumps(nan_ingredients))
# Out:
# ['Homemade Shrimp Tempura', 'FoodSaver FM Vacuum Sealing System', 'Optional Garnish', 'Reynolds Wrap NonStick Foil', 'pine nutsdried jujubescitron syrupmint leaves', 'leftover rice water', 'reserved tomato blanching water', 'Chinese', 'udon noodles total oz   g', 'reserved seafood sauce', 'burger buns', 'water for stove top', 'astragalus', 'sev farsan', 'Syrup to taste', 'shio koji karaage', 'Yaki Onigiri Grilled Rice Ball', 'warm water F  C', 'Homemade Castella Cake', 'cold tap water', 'flat plate or smooth metal or stone surface', 'dry rub of your choice', 'Chrysanthemum leaves or Crown Daisies', 'block', 'liquor of your choice', 'reserved shiitake soaking liquid', 'mixed fruit or vanilla essence', 'gyoza', 'whole bonein', 'reserved water from soaking kiriboshi daikon', 'soboro don', 'lily bulb', 'codonopsis root', 'Lamb with carrot and zucchini', 'SPAM', 'homemade kansui', 'rosdee flavor seasoning', 'sev or bhujia', 'Chopped walnuts and  or raw sugar', 'suki sauce', 'vegetables of your choice', 'Spicy Bean Sprout Salad', 'precooked muthia', 'flavor seasoning', 'Pocky', 'yanang', 'dalgona mold or cookie cutter molds', 'Japanese milk bread', 'ice bath', 'Electric Mixer', 'Dumpling dipping sauce', 'hot dogs', 'nuts', 'bracken fiddleheads', 'salad dressing', 'bread', 'Idli batter', 'marinade sauce', 'and  tablespoons light soy sauce', 'Dried rose petals', 'hot boiling water', 'Parchment paper', 'atap fruit', 'rum', 'seafood', 'kimchi', 'handful dried lily flowers', 'reserved pasta water', 'toasts', 'medium grade cheesecloth', 'rose syrup', 'handwa flour', 'A gram Mooncake mold', 'Fluted pastry cutter', 'Japanese curry of your choice', 'fresh pine needles', 'frozen veggies of your choice', 'bubu arare crispy puffed rice pellets', 'bird nest', 'a silicone or cheese cloth liner for the steamer if no pine needles', 'ice cubes', 'soju', 'tonkatsu or Worcestershire sauce  ketchup', 'Tofu knots', 'Reynolds Wrap Heavy Duty Foil', 'chocolate granola', 'used kombu kelp', 'papdi', 'chaat masala', 'soaking water from the lily flower and mushroom', 'Cotton twine or narrow stalks to tie the zongzi', 'pack spring roll wrappers', 'bamboo skewers', 'servings noodles', 'noodle boiling water', 'a few drops of Maggi seasoning sauce', 'onion flower stem', 'bread of your choice', 'bok choy flower', 'sesame dipping sauce', 'XO Sauce', 'CocaCola', 'shaved ice', 'codonopsis', 'sudachi', 'Dhokli', 'kashmiri', 'Chee Hou sauce', 'meatballs  fish balls', 'takoyaki sauce', 'bhel mix', 'package of spring roll wrappers', 'Japanese curry roux', 'pack dumpling wrappers', 'food coloring', 'cigarette cookies', ' oz gram flour sifted', 'nam prik pao', 'chicken nanban', 'Shredded carrots and cucumber', 'Gravy', 'calabash', 'Nutella', 'calcium hydroxide', 'Hikari Miso Shio Koji', 'pickle masala', 'crushed ice', 'bamboo leaves', 'stainless steel mixing bowl or pot', 'vanilla ice cream', 'mixed green salad to serve with', 'Optional Toppings', 'cooked sea bream bone and head', 'metal chopstick or a candy stick', 'sprite or Korean cider', 'Kitchen twine', 'of charcoal', 'RosDee seasoning powder', 'sprinkles of your choice', 'fruits of your choice', 'New England style splittop hot dog buns', 'Japanese potato salad', 'Homemade Kasudoko', 'Carrot and eggs', 'fine sev', 'Hong Kong style pan fried noodles', 'Dried jujubespine nutsalmonds', 'dried lily flowers', 'Japanese Sesame Dressing', 'toasted bread', 'Sliced tomato onion and lettuce leaves for toppings', 'baked croquettes', 'of water', 'Pan drippings', 'Homemade chili oil', 'dumpling dipping sauce', 'Homemade duck pancakes', 'Kawan parathas', 'gulkand', 'mushroom soaking water', 'mawa  grams', 'steamer', 'kimchi liquid', 'homemade flatbreads', 'green tea ice cream', 'Kawan Parathas', 'tian mian jiang sweet flour sauce', 'drumsticks', 'sheets dried or fresh bamboo leaves', 'loosely packed crown daisies', 'meat', 'Homemade soy sauce egg', 'syrup from kuri kanroni', 'SPAM  oz', 'chicken katsu', 'ravasemolina', 'of bread',  ...
# 332

# %%
print("Number of ingredients to process: ", len(nan_ingredients))

# Updated regex pattern to support both single and double quotes
pattern = r"['\"]([a-zA-Z\s]+)['\"]\s*:\s*['\"]([a-zA-Z\s]+)['\"]"

# how many ingredients to give the LLM at a time
n = 20

counter = 1

nan_ingredient_mappings = dict()

while nan_ingredients:

    # gets the current batch of ingredients for LLM to process
    current_ingredients, nan_ingredients = nan_ingredients[:n], nan_ingredients[n:]
    number_ingredients = len(current_ingredients)

    content = f"""The following are common ingredient variations. Normalize each ingredient variation by mapping it to the appropriate standardized name:

    Salt, Kosher Salt, Sea Salt, Flaky Salt -> Salt
    Olive Oil, Extra Virgin Olive Oil, Virgin Olive Oil -> Olive Oil
    Tomatoes, Canned Tomatoes, Cherry Tomatoes, Roma Tomatoes -> Tomatoes
    Potatoes, Russet Potatoes, Yukon Gold Potatoes -> Potatoes
    Garlic, Garlic Powder, Minced Garlic -> Garlic

    Create a python dictionary, where each key refers to one of the original ingredients lists below and its value is your answer. You can only give one ingredient answer. Do not include the above examples in the python dictionary to be created. Do not return anything other than the python dictionary in your response.

    There are {number_ingredients} listed below, as such you must output {number_ingredients} ingredient mappings. If the ingredient is in fact not an ingredient then assign it 'NaN'.
    Normalize the ingredients found in this python list:
    {current_ingredients}"""

    response = ollama.generate(model="gemma2", prompt=content)

    #### ADD INGREDIENT MAPPINGS TO GLOBAL LIST
    raw_output = response["response"]

    # Find all matching pairs
    matches = re.findall(pattern, raw_output)

    # Create a dictionary from the matches
    ingredient_standardization = dict(matches)
    nan_ingredient_mappings.update(ingredient_standardization)

    ## Find all the ingredients the LLM didn't process so it can re-process it
    llm_returned_keys = list(ingredient_standardization.keys())
    missing_items = [
        item for item in current_ingredients if item not in llm_returned_keys
    ]
    nan_ingredients.extend(missing_items)

    print(
        f"\rCycle: {counter}, Number of ingredients processed: {len(nan_ingredient_mappings)}, Number left to process: {len(nan_ingredients)}",
        end="",
    )
    counter += 1

    if nan_ingredients == []:
        break
# Out:
# Number of ingredients to process:  332
# Cycle: 18, Number of ingredients processed: 337, Number left to process: 020

# %%
nan_ingredient_mappings
# Out:
# {'Homemade Shrimp Tempura': 'Shrimp',
#  'FoodSaver FM Vacuum Sealing System': 'NaN',
#  'Optional Garnish': 'NaN',
#  'Reynolds Wrap NonStick Foil': 'NaN',
#  'leftover rice water': 'Rice Water',
#  'reserved tomato blanching water': 'Tomato Water',
#  'Chinese': 'NaN',
#  'udon noodles total oz   g': 'Udon Noodles',
#  'reserved seafood sauce': 'Seafood Sauce',
#  'burger buns': 'Buns',
#  'water for stove top': 'Water',
#  'astragalus': 'Astragalus',
#  'sev farsan': 'Sev Farsan',
#  'Syrup to taste': 'Syrup',
#  'shio koji karaage': 'Chicken',
#  'Yaki Onigiri Grilled Rice Ball': 'Rice',
#  'warm water F  C': 'Water',
#  'Homemade Castella Cake': 'Cake',
#  'cold tap water': 'Water',
#  'flat plate or smooth metal or stone surface': 'NaN',
#  'dry rub of your choice': 'NaN',
#  'Chrysanthemum leaves or Crown Daisies': 'NaN',
#  'block': 'NaN',
#  'liquor of your choice': 'NaN',
#  'reserved shiitake soaking liquid': 'NaN',
#  'mixed fruit or vanilla essence': 'NaN',
#  'gyoza': 'NaN',
#  'whole bonein': 'NaN',
#  'reserved water from soaking kiriboshi daikon': 'NaN',
#  'soboro don': 'NaN',
#  'lily bulb': 'NaN',
#  'codonopsis root': 'NaN',
#  'SPAM': 'NaN',
#  'homemade kansui': 'NaN',
#  'rosdee flavor seasoning': 'NaN',
#  'sev or bhujia': 'NaN',
#  'suki sauce': 'NaN',
#  'vegetables of your choice': 'NaN',
#  'Spicy Bean Sprout Salad': 'NaN',
#  'precooked muthia': 'NaN',
#  'flavor seasoning': 'NaN',
#  'Pocky': 'NaN',
#  'yanang': 'NaN',
#  'dalgona mold or cookie cutter molds': 'NaN',
#  'Japanese milk bread': 'NaN',
#  'ice bath': 'NaN',
#  'Electric Mixer': 'NaN',
#  'Dumpling dipping sauce': 'NaN',
#  'hot dogs': 'Hot Dogs',
#  'nuts': 'Nuts',
#  'bracken fiddleheads': 'Fiddleheads',
#  'salad dressing': 'Salad Dressing',
#  'bread': 'Bread',
#  'Idli batter': 'NaN',
#  'marinade sauce': 'Marinade',
#  'and  tablespoons light soy sauce': 'Soy Sauce',
#  'Dried rose petals': 'Rose Petals',
#  'hot boiling water': 'Water',
#  'Parchment paper': 'NaN',
#  'atap fruit': 'NaN',
#  'rum': 'NaN',
#  'seafood': 'Seafood',
#  'kimchi': 'Kimchi',
#  'handful dried lily flowers': 'Lily Flowers',
#  'reserved pasta water': 'Water',
#  'toasts': 'Bread',
#  'medium grade cheesecloth': 'Cheesecloth',
#  'rose syrup': 'Rose Syrup',
#  'handwa flour': 'Flour',
#  'A gram Mooncake mold': 'NaN',
#  'Fluted pastry cutter': 'NaN',
#  'Japanese curry of your choice': 'Curry',
#  'fresh pine needles': 'Pine Needles',
#  'frozen veggies of your choice': 'Vegetables',
#  'bubu arare crispy puffed rice pellets': 'Rice',
#  'bird nest': 'Bird Nest',
#  'a silicone or cheese cloth liner for the steamer if no pine needles': 'Liner',
#  'ice cubes': 'NaN',
#  'soju': 'NaN',
#  'tonkatsu or Worcestershire sauce ketchup': 'NaN',
#  'Tofu knots': 'Tofu',
#  'Reynolds Wrap Heavy Duty Foil': 'NaN',
#  'chocolate granola': 'Granola',
#  'used kombu kelp': 'NaN',
#  'papdi': 'Papdi',
#  'chaat masala': 'Chaat Masala',
#  'soaking water from the lily flower and mushroom': 'NaN',
#  'Cotton twine or narrow stalks to tie the zongzi': 'NaN',
#  'pack spring roll wrappers': 'Spring Roll Wrapper',
#  'bamboo skewers': 'Skewer',
#  'servings noodles': 'Noodles',
#  'noodle boiling water': 'NaN',
#  'a few drops of Maggi seasoning sauce': 'Seasoning',
#  'onion flower stem': 'Onion Stem',
#  'bread of your choice': 'Bread',
#  'bok choy flower': 'Bok Choy',
#  'sesame dipping sauce': 'Dipping Sauce',
#  'XO Sauce': 'XO Sauce',
#  'CocaCola': 'NaN',
#  'shaved ice': 'NaN',
#  'codonopsis': 'Codonopsis',
#  'sudachi': 'Sudachi',
#  'Dhokli': 'NaN',
#  'kashmiri': 'Kashmiri Chili',
#  'Chee Hou sauce': 'Chee Hou Sauce',
#  'meatballs  fish balls': 'NaN',
#  'takoyaki sauce': 'Takoyaki Sauce',
#  'bhel mix': 'Bhel',
#  'package of spring roll wrappers': 'Spring Roll Wrappers',
#  'Japanese curry roux': 'Japanese Curry Roux',
#  'pack dumpling wrappers': 'Dumpling Wrappers',
#  'food coloring': 'NaN',
#  'cigarette cookies': 'NaN',
#  ' oz gram flour sifted': 'Gram Flour',
#  'nam prik pao': 'Nam Prik Pao',
#  'chicken nanban': 'Chicken Nanban',
#  'Gravy': 'Gravy',
#  'calabash': 'NaN',
#  'Nutella': 'Nutella',
#  'calcium hydroxide': 'NaN',
#  'Hikari Miso Shio Koji': 'NaN',
#  'pickle masala': 'Pickle Masala',
#  'crushed ice': 'NaN',
#  'bamboo leaves': 'NaN',
#  'stainless steel mixing bowl or pot': 'NaN',
#  'vanilla ice cream': 'Vanilla Ice Cream',
#  'mixed green salad to serve with': 'Salad Greens',
#  'Optional Toppings': 'NaN',
#  'cooked sea bream bone and head': 'Sea Bream',
#  'metal chopstick or a candy stick': 'NaN',
#  'sprite or Korean cider': 'Soda',
#  'Kitchen twine': 'NaN',
#  'of charcoal': 'NaN',
#  'RosDee seasoning powder': 'Seasoning',
#  'sprinkles of your choice': 'Sprinkles',
#  'fruits of your choice': 'Fruit',
#  'New England style splittop hot dog buns': 'NaN',
#  'Japanese potato salad': 'Potato Salad',
#  'Homemade Kasudoko': 'NaN',
#  'Carrot and eggs': 'NaN',
#  'fine sev': 'NaN',
#  'Hong Kong style pan fried noodles': 'Noodles',
#  'Dried jujubespine nutsalmonds': 'NaN',
#  'dried lily flowers': 'NaN',
#  'Japanese Sesame Dressing': 'Dressing',
#  'toasted bread': 'Bread',
#  'Sliced tomato onion and lettuce leaves for toppings': 'Toppings',
#  'baked croquettes': 'Croquettes',
#  'of water': 'Water',
#  'Pan drippings': 'NaN',
#  'Homemade chili oil': 'Chili Oil',
#  'dumpling dipping sauce': 'Dipping Sauce',
#  'Homemade duck pancakes': 'Pancake',
#  'Kawan parathas': 'Paratha',
#  'gulkand': 'NaN',
#  'mushroom soaking water': 'Water',
#  'mawa grams': 'NaN',
#  'steamer': 'NaN',
#  'kimchi liquid': 'NaN',
#  'homemade flatbreads': 'Bread',
#  'green tea ice cream': 'NaN',
#  'Kawan Parathas': 'NaN',
#  'tian mian jiang sweet flour sauce': 'NaN',
#  'drumsticks': 'Chicken',
#  'sheets dried or fresh bamboo leaves': 'Bamboo Leaves',
#  'loosely packed crown daisies': 'NaN',
#  'meat': 'NaN',
#  'Homemade soy sauce egg': 'Egg',
#  'syrup from kuri kanroni': 'NaN',
#  'SPAM oz': 'Spam',
#  'chicken katsu': 'Chicken',
#  'ravasemolina': 'NaN',
#  'of bread': 'NaN',
#  'handfuls dried lily flowers': 'Lily Flowers',
#  'rose essence': 'NaN',
#  'dinner rolls': 'NaN',
#  'scoops vanilla ice cream': 'NaN',
#  'red food coloring': 'NaN',
#  'asparagus beef rolls': 'NaN',
#  'Bamboo skewers': 'NaN',
#  'crown daisies': 'NaN',
#  'Lao Gan Ma Spicy Chili Crisp': 'NaN',
#  'tonkatsu sauce': 'NaN',
#  'Sui Mi Ya Cai': 'NaN',
#  'head bibb': 'Lettuce',
#  'ice cream of your choice': 'NaN',
#  'dried fruit mix': 'NaN',
#  'gulkandrose preserve': 'NaN',
#  'Idli Batter': 'NaN',
#  'fried gluten balls': 'NaN',
#  'Baijiu': 'NaN',
#  'awamori Okinawan distilled liquor': 'NaN',
#  'Chopped peanuts for garnish': 'Peanuts',
#  'dried lily flower': 'NaN',
#  'saltpickled cherry blossoms': 'NaN',
#  'okonomiyaki sauce': 'Okonomiyaki Sauce',
#  'kanom jeen': 'Kanom Jeen',
#  'green leaf': 'NaN',
#  'large banana leaves': 'Banana Leaves',
#  'toppings of your choice': 'NaN',
#  'lobster tails with shell': 'Lobster Tails',
#  'dried hoba leaves': 'Hoba Leaves',
#  'okara': 'Okara',
#  'proteins': 'NaN',
#  'sliced white bread': 'Bread',
#  'korokke Japanese croquette': 'Croquettes',
#  'FoodSaver Sousvide Vacuum Seal Bags': 'NaN',
#  'Vegan': 'NaN',
#  'ssukat': 'NaN',
#  'Omija Five Flavor Berry Tea': 'Tea',
#  'hot pot bases': 'Hot Pot Base',
#  'bunnyshaped apple': 'Apple',
#  'reserved blanching liquid': 'Blanching Liquid',
#  'the leftover Japanese curry of your choice': 'Japanese Curry',
#  'dipping sauces': 'Dipping Sauces',
#  'golden mountain seasoning sauce': 'NaN',
#  'milk bread': 'NaN',
#  'alkaline water': 'Water',
#  'brownies': 'NaN',
#  'golden mountain sauce': 'NaN',
#  'egg roll wrappers': 'NaN',
#  'acacia leaves': 'NaN',
#  'Sousvide precision cooker': 'NaN',
#  'Rice Kheer': 'NaN',
#  'fine ravasemolina': 'NaN',
#  'a large bowl lukewarm water': 'Water',
#  'milk mixture': 'NaN',
#  'yukari rice seasoning': 'Seasoning',
#  'Water Dropwort': 'NaN',
#  'Toppings': 'NaN',
#  'CocaCola  oz   ml can': 'Soda',
#  'look chin': 'NaN',
#  'vanilla extract': 'Vanilla Extract',
#  'handvo flour': 'Flour',
#  ' cup   tablespoons cool water': 'Water',
#  'fresh Hong Kong Pan Fried Noodles': 'Noodles',
#  'pumpkin pie spice': 'Spices',
#  'segment': 'NaN',
#  'peanut bar': 'NaN',
#  'of garlic': 'Garlic',
#  'spring roll wrappers': 'Wrappers',
#  'Tamagoyaki Easy Version': 'Eggs',
#  'twine': 'NaN',
#  'Mugwort Ssuk': 'Mugwort',
#  'karaage': 'Chicken',
#  'frozen Kawan parathas': 'Paratha',
#  'edible gold leaf flakes': 'Gold Leaf',
#  'sausage casing': 'NaN',
#  'kuchinashi no mi dried gardenia pods': 'Fruit',
#  'small silicon spatula or spoon for scraping': 'NaN',
#  'condiments of your choice': 'Condiments',
#  'ice': 'Ice',
#  'mushroom soaking liquid': 'Water',
#  'Kimchi pork base mix': 'Pork',
#  'Maggi seasoning sauce': 'Sauce',
#  'oxtail': 'Oxtail',
#  'homemade dumpling wrappers': 'Dumpling Wrappers',
#  'guk kanjang': 'Gukkanjang',
#  'stalks of chrysanthemum leaves': 'Chrysanthemum Leaves',
#  'Homemade nutty sauce': 'Sauce',
#  'ume plum compote': 'Plum Compote',
#  'liquid smoke': 'Liquid Smoke',
#  'Rice cakes': 'Rice Cakes',
#  'Optional Toasted sesame seeds for garnish': 'Sesame Seeds',
#  'of white bread': 'NaN',
#  'almond extract': 'Almond Extract',
#  'spinach gomaae': 'Spinach Gomaae',
#  'rice paper wrappers': 'Rice Paper Wrappers',
#  'rice paddy herb': 'NaN',
#  'Soft Buns': 'Buns',
#  'thin bamboo sticks': 'Bamboo Sticks',
#  'x water': 'Water',
#  'Sansai Mix Sansai Mizuni': 'Sansai',
#  'rose petals': 'Rose Petals',
#  'liqueur of your choice': 'Liquor',
#  'braising liquid': 'Braising Liquid',
#  'Garnish': 'NaN',
#  'Serving options': 'NaN',
#  'homemade orange sauce': 'Sauce',
#  'Puri': 'NaN',
#  'onsen tamago': 'Egg',
#  'chirashi sushi mix': 'Sushi Rice',
#  'cut in wedges': 'NaN',
#  'Pav': 'NaN',
#  'flavored syrup': 'Syrup',
#  'to  tablespoons homemade chicken stock or  teaspoon chicken bouillon powder': 'Chicken Stock',
#  'thandai powder': 'Spice',
#  'white lotus seeds': 'Seed',
#  'kawan parathas ': 'NaN',
#  'MSG': 'Seasoning',
#  'kalbi bones with meat': 'Meat',
#  'dried radish strips mumalleangi': 'Radish',
#  'apricot jam': 'Jam',
#  'iced water': 'Water',
#  'gosari reconstituted': 'Vegetable',
#  'Small Chinese rolling pin': 'NaN',
#  'of sesame seeds as garnish': 'Sesame Seeds',
#  'Shitake mushroom water from hydrating mushrooms': 'Mushroom Water',
#  'walnut half': 'Walnut',
#  'set of Chinese fivespice set': 'Five Spice Powder',
#  'green': 'NaN',
#  'gyudon': 'Beef Bowl',
#  'banana': 'Banana',
#  'ladyfingers': 'Ladyfingers',
#  'Sushi rolling mat': 'NaN',
#  'Japanese Cream Stew Mix': 'Stew Mix',
#  'oz   g block firm': 'NaN',
#  'cold water bath': 'NaN',
#  'nonoil aojiso dressing': 'Dressing',
#  'ice shaver machine and ice': 'Ice',
#  'Egg tart mold': 'NaN',
#  'ladle or large spoon': 'Ladle',
#  'gajar halwa': 'Carrot Pudding',
#  'shochu': 'Shochu',
#  'outer layers of the Tokyo negis white stalk': 'NaN',
#  'pounds fresh hawthorn berries': 'Hawthorn Berries',
#  'dried rose petals': 'Rose Petals',
#  'broiled salmon': 'Salmon',
#  'rosdee seasoning powder': 'NaN',
#  'Naan': 'NaN',
#  'saltpickled kashiwa oak leaves': 'Kashiwa Oak Leaves',
#  'pie crust': 'NaN',
#  'Tamagoyaki Sweet Rolled Omelette': 'Omelette',
#  'sweet red bean paste adzuki beans': 'Red Bean Paste',
#  'duck legs': 'Duck',
#  'to tablespoons homemade chicken stock or teaspoon chicken bouillon powder': 'Chicken Stock',
#  'Lamb with carrot and zucchini': 'Lamb',
#  'mawa  grams': 'NaN',
#  'SPAM  oz': 'Spam',
#  'Sauce': 'Sauce',
#  ' oz   g block firm': 'NaN',
#  ' pounds fresh hawthorn berries': 'Hawthorn Berries',
#  'pine nutsdried jujubescitron syrupmint leaves': 'Pine Nuts',
#  'Chopped walnuts and  or raw sugar': 'Walnuts',
#  'tonkatsu or Worcestershire sauce  ketchup': 'Worcestershire Sauce',
#  'Shredded carrots and cucumber': 'Carrots',
#  'Rose petals  pistachios for garnish': 'Pistachios'}

# %%
len(nan_ingredient_mappings)

# Get original ingredients that were NaN
nan_ingredients = [key for key, value in ingredient_mappings.items() if value == "NaN"]

# Manually check the ingredients originally listed as nan as their new stadnadised names
for i in range(len(nan_ingredients)):
    current = nan_ingredients[i]
    standardised = nan_ingredient_mappings[current]
    answer = input(f"[{i}/{len(nan_ingredients)}] {current} --> {standardised}: ")
    if answer == "":
        ingredient_mappings[current] = standardised
    else:
        ingredient_mappings[current] = answer

# %%
# Saves standadised names to a .txt file so its not lost
with open("standardised_names.txt", "w") as convert_file:
    convert_file.write(json.dumps(ingredient_mappings))

# %% [markdown]
# ------
#
# ## Group Standardised Name into Categories taking into account for mispellings and pluralisation

# %%
# Create ingredient maps where key is the standard name and values are lists of ingreidnets that map to it
mapping_lists = dict()

for key, value in ingredient_mappings.items():
    if value not in mapping_lists:
        mapping_lists[value] = [key]
    else:
        mapping_lists[value].append(key)

print(sorted(mapping_lists.keys()))
# Out:
# ['Aamchoor', 'Aamchur', 'Abalone', 'Acorn Powder', 'Active Dry Yeast', 'Agar Agar', 'Agave Syrup', 'Ajwain', 'Allspice', 'Almond', 'Almond Extract', 'Almond Meal', 'Almond Milk', 'Almonds', 'Amchur Powder', 'Anaheim Pepper', 'Anaheim peppers', 'Anchovies', 'Anchovy', 'Anchovy Sauce', 'Anchovy Stock', 'Apple', 'Apple Cider Vinegar', 'Apple Juice', 'Apricots', 'Arrowroot', 'Artichoke Heart', 'Arugula', 'Asafetida', 'Asafoetida', 'Asparagus', 'Astragalus', 'Avocado', 'Avocado Oil', 'Bacon', 'Baguette', 'Baking Powder', 'Baking Soda', 'Bamboo Leaves', 'Bamboo Shoot', 'Bamboo Shoots', 'Banana', 'Banana Leaves', 'Barbecue Sauce', 'Barley', 'Basil', 'Basil Seeds', 'Basmati Rice', 'Bay Leaf', 'Bay Leaves', 'Bean Liquid', 'Bean Paste', 'Bean Sauce', 'Bean Sprout', 'Bean Sprouts', 'Beans', 'Beef', 'Beef Bones', 'Beef Bowl', 'Beef Brisket', 'Beef Broth', 'Beef Chuck Roast', 'Beef Short Ribs', 'Beef Stock', 'Beef Tongue', 'Beer', 'Beetroot', 'Beets', 'Bell Pepper', 'Bell Peppers', 'Bellflower Root', 'Berries', 'Berry', 'Besan', 'Bhel', 'Biryani Spice', 'Bitter Melon', 'Black Bean Sauce', 'Black Beans', 'Black Cumin Seeds', 'Black Eyed Peas', 'Black Gram Beans', 'Black Mustard Seeds', 'Black Pepper', 'Black Sesame Paste', 'Black Soybeans', 'Black Tea', 'Black Vinegar', 'Blood', 'Blueberries', 'Bok Choy', 'Bonito Flakes', 'Bottle Gourd', 'Bouillon', 'Bouillon Cube', 'Bracken starch', 'Bread', 'Bread Crumbs', 'Bread Rolls', 'Breadcrumbs', 'Brisket', 'Broccoli', 'Broccoli Rabe', 'Broth', 'Brown Sugar', 'Brownies', 'Buckwheat Flour', 'Buckwheat Sprouts', 'Bulgogi', 'Bun', 'Buns', 'Burdock Root', 'Butter', 'Butterfly Pea Flower', 'Buttermilk', 'Cabbage', 'Cake', 'Cake Flour', 'Calamari', 'Canola Oil', 'Cardamom', 'Carom Seeds', 'Carrot', 'Carrots', 'Cashew', 'Cashews', 'Catfish', 'Cauliflower', 'Cauliflower Rice', 'Cayenne Pepper', 'Celery', 'Celtuce', 'Century Eggs', 'Chaat Masala', 'Chana Dal', 'Chat Masala', 'Cheddar Cheese', 'Cheese', 'Cherries', 'Cherry', 'Chestnuts', 'Chicken', 'Chicken Breast', 'Chicken Broth', 'Chicken Fat', 'Chicken Feet', 'Chicken Katsu', 'Chicken Leg', 'Chicken Leg Quarters', 'Chicken Legs', 'Chicken Nanban', 'Chicken Skin', 'Chicken Stock', 'Chicken Thigh', 'Chicken Thighs', 'Chicken Wings', 'Chickpea', 'Chickpea Flour', 'Chickpeas', 'Chile Pepper', 'Chile Peppers', 'Chiles', 'Chili', 'Chili Crisp', 'Chili Flakes', 'Chili Garlic Sauce', 'Chili Oil', 'Chili Paste', 'Chili Pepper', 'Chili Pepper Flakes', 'Chili Pepper Powder', 'Chili Peppers', 'Chili Powder', 'Chili Sauce', 'Chilies', 'Chilli Pepper', 'Chilli Peppers', 'Chinese Cabbage', 'Chinese Chives', 'Chinese Greens', 'Chinese Olive Vegetables', 'Chinese Pickled Mustard Greens', 'Chives', 'Chocolate', 'Chocolate Chips', 'Chocolate Syrup', 'Chow Mein Noodles', 'Choy Sum', 'Chrysanthemum', 'Chrysanthemum Leaves', 'Chutney', 'Cilantro', 'Cinnamon', 'Citric Acid', 'Citrus', 'Citrus Peel', 'Clams', 'Cloves', 'CocaCola', 'Cocoa Powder', 'Coconut', 'Coconut Milk', 'Coconut Oil', 'Coconut Water', 'Cod', 'Codonopsis', 'Coffee', 'Condensed Milk', 'Cooking Spray', 'Cooking Wine', 'Coriander', 'Coriander Powder', 'Coriander Root', 'Corn', 'Corn Flakes', 'Corn Noodles', 'Cornichon', 'Cornmeal', 'Cornstarch', 'Crab', 'Crab Legs', 'Crab Meat', 'Crab Salad', 'Crab Sticks', 'Crabmeat', 'Cranberries', 'Cream', 'Cream Cheese', 'Cream of Tartar', 'Croquettes', 'Cucumber', 'Cucumbers', 'Culantro', 'Cumin', 'Cumin Powder', 'Cumin Seeds', 'Curry', 'Curry Leaves', 'Curry Paste', 'Curry Powder', 'Curry Sauce', 'Dabeli Masala', 'Daikon', 'Daikon Radish', 'Daikon Sprout', 'Dashi', 'Date', 'Dates', 'Demiglace Sauce', 'Dill', 'Dipping Sauce', 'Dipping Sauces', 'Doenjang', 'Doubanjiang', 'Douchi', 'Dressing', 'Dried Fruit', 'Dried Sardine', 'Duck', 'Duck Egg', 'Duck Egg Yolk', 'Duck Legs', 'Duck Pancakes', 'Duck Yolk', 'Dudhi', 'Dumpling', 'Dumpling Wrapper', 'Dumpling Wrappers', 'Dumplings', 'Edamame', 'Eel', 'Egg', 'Egg Crepe', 'Egg Noodles', 'Egg Roll Wrappers', 'Egg White', 'Egg Whites',  ...

# %%
keys_standardised_names = list(mapping_lists.keys())
print(len(keys_standardised_names))

# Initialize an empty dictionary to store the fuzzy scores
fuzzy_scores = {}


# Loop over each pair of ingredients using itertools.combinations to avoid duplicates
for key1, key2 in combinations(set(keys_standardised_names), 2):
    # Compute the fuzzy match score
    score = fuzz.ratio(key1, key2)

    # Store the score in the dictionary
    if (key2, key1) not in fuzzy_scores:
        fuzzy_scores[(key1, key2)] = score

list_fuzz_pairs = []

# Display the fuzzy scores
for pair, score in fuzzy_scores.items():
    if score >= 75:
        pair = list(pair)
        list_fuzz_pairs.append(pair)

print(list_fuzz_pairs)
print(len(list_fuzz_pairs))
# Out:
# 924
# [['Bouillon Cube', 'Bouillon'], ['Peanuts', 'Peanut'], ['Peanuts', 'Pecans'], ['Asafetida', 'Asafoetida'], ['Lemon Zest', 'Lemons'], ['Yellow Curry Powder', 'Curry Powder'], ['Takoyaki Sauce', 'Teriyaki Sauce'], ['Takoyaki Sauce', 'Okonomiyaki Sauce'], ['Cauliflower Rice', 'Cauliflower'], ['Apple Juice', 'Pineapple Juice'], ['Okara', 'Okra'], ['Lily Flower Bud', 'Lily Flower'], ['Lily Flower Bud', 'Lily Flowers'], ['Mushroom Powder', 'Mushroom Water'], ['Peppercorns', 'Peppers'], ['Peppercorns', 'Peppercorn'], ['Pickled Mustard Greens', 'Mustard Greens'], ['Pickled Mustard Greens', 'Chinese Pickled Mustard Greens'], ['Rice Powder', 'Rice Paper'], ['Chilies', 'Chives'], ['Chilies', 'Chiles'], ['Chilies', 'Chili'], ['Pickled Vegetables', 'Mixed Vegetables'], ['Pickled Vegetables', 'Pickled Leaves'], ['Coconut Milk', 'Coconut Oil'], ['Cashew', 'Cashews'], ['Wood Ear Mushroom', 'Wood Ear Mushrooms'], ['Shiitake Mushrooms', 'Shimeji Mushrooms'], ['Shiitake Mushrooms', 'Straw Mushrooms'], ['Shiitake Mushrooms', 'Maitake Mushrooms'], ['Shiitake Mushrooms', 'Shiitake Mushroom'], ['Shiitake Mushrooms', 'Matsutake Mushrooms'], ['Bonito Flakes', 'Corn Flakes'], ['Chicken Skin', 'Chicken Stock'], ['Chicken Skin', 'Chicken Wings'], ['Cranberries', 'Strawberries'], ['Buckwheat Sprouts', 'Buckwheat Flour'], ['Buckwheat Sprouts', 'Bean Sprouts'], ['Udon Noodles', 'Corn Noodles'], ['Udon Noodles', 'Somen Noodles'], ['Udon Noodles', 'Wonton Noodles'], ['Udon Noodles', 'Soba Noodles'], ['Udon Noodles', 'Konjac Noodles'], ['Orange', 'Oranges'], ['Chocolate', 'Chocolate Syrup'], ['Chocolate', 'Chocolate Chips'], ['Chocolate', 'White Chocolate'], ['Buttermilk', 'Butter'], ['Cream Cheese', 'Cheddar Cheese'], ['Chestnuts', 'Water Chestnuts'], ['Potatoes', 'Tomatoes'], ['Potatoes', 'Potato'], ['Anaheim peppers', 'Anaheim Pepper'], ['Walnuts', 'Walnut'], ['Lady Fingers', 'Ladyfingers'], ['Tomatoes', 'Tomato'], ['Strawberry', 'Strawberries'], ['Sesame Seed', 'Sesame Seeds'], ['Sesame Seed', 'Sesame Sauce'], ['Date', 'Dates'], ['Anchovy', 'Anchovies'], ['Egg Roll Wrappers', 'Spring Roll Wrapper'], ['Egg Roll Wrappers', 'Spring Roll Wrappers'], ['Milk', 'Milt'], ['Jasmine Rice', 'Basmati Rice'], ['Pork Loin', 'Pork Skin'], ['Pork Loin', 'Pork Bone'], ['Sichuan Peppercorn Oil', 'Sichuan Peppercorns'], ['Sichuan Peppercorn Oil', 'Sichuan Peppercorn'], ['Black Gram Beans', 'Black Beans'], ['Enoki Mushroom', 'Enoki Mushrooms'], ['Lemongrass', 'Lemons'], ['Serrano Pepper', 'Sansho Pepper'], ['Cherries', 'Berries'], ['Dumplings', 'Dumpling'], ['Garlic Oil', 'Garlic'], ['Seasoning Powder', 'Baking Powder'], ['Kaffir Lime Leaves', 'Lime Leaves'], ['Peanut', 'Peanut Oil'], ['Mint', 'Milt'], ['Sweet Rice Flour', 'Sweet Rice'], ['Sweet Rice Flour', 'Rice Flour'], ['Nuts', 'Nut'], ['Sichuan Peppercorns', 'Sichuan Peppercorn'], ['Red Pepper Flakes', 'Chili Pepper Flakes'], ['Red Chili Peppers', 'Chili Peppers'], ['Red Chili Peppers', 'Red Chili Powder'], ['Red Chili Peppers', 'Green Chili Pepper'], ['Red Chili Peppers', 'Chilli Peppers'], ['Red Chili Peppers', 'Chili Pepper'], ['Red Chili Peppers', 'Chile Pepper'], ['Red Chili Peppers', 'Chilli Pepper'], ['Red Chili Peppers', 'Chile Peppers'], ['Dumpling Wrappers', 'Dumpling Wrapper'], ['Eggs', 'Egg'], ['Watermelon', 'Watermelon Juice'], ['Tempura Dipping Sauce', 'Dipping Sauce'], ['Lily Flower', 'Lily Flowers'], ['Sesame Seeds', 'Sesame Sauce'], ['Orange Zest', 'Oranges'], ['Scallions', 'Scallop'], ['Scallions', 'Scallops'], ['Scallions', 'Scallion'], ['Soybeans', 'Soybean Paste'], ['Chicken Stock', 'Chicken Fat'], ['Chives', 'Chiles'], ['Chili Pepper Flakes', 'Chili Peppers'], ['Chili Pepper Flakes', 'Chili Flakes'], ['Chili Pepper Flakes', 'Chilli Peppers'], ['Chili Pepper Flakes', 'Chili Pepper'], ['Chili Pepper Flakes', 'Chilli Pepper'], ['Chili Pepper Flakes', 'Chile Peppers'], ['Sweet Bean Sauce', 'Sweet Bean Paste'], ['Sweet Bean Sauce', 'Bean Sauce'], ['Sweet Bean Sauce', 'Sweet Soy Sauce'], ['Chicken Feet',  ...
# 400

# %%
def get_master_name(ingredient, merge_history):
    # This function will return the final master ingredient after all merges.
    while ingredient in merge_history:
        ingredient = merge_history[ingredient]
    return ingredient


# Track the final master names after merges, where key is the ingredient and value is its new name
merge_history = dict()

# Attempt to merge the ingredients
for i in range(len(list_fuzz_pairs)):
    ingredient1, ingredient2 = list_fuzz_pairs[i]

    # Get the master names for both ingredients
    ingredient1_master = get_master_name(ingredient1, merge_history)
    ingredient2_master = get_master_name(ingredient2, merge_history)

    # If both ingredients already have the same master name, no merge is needed
    if ingredient1_master == ingredient2_master:
        print(
            f"Ingredients '{ingredient1}' and '{ingredient2}' are already merged as '{ingredient1_master}'. Skipping merge."
        )

    # Otherwise, ask for human input
    else:
        user_input = input(
            f"[{i}/{len(list_fuzz_pairs)}] 1: {ingredient1_master}, 2: {ingredient2_master}"
        )

        if user_input == "1":
            # Merge ingredient2 into ingredient1
            mapping_lists[ingredient1_master].extend(mapping_lists[ingredient2_master])
            del mapping_lists[ingredient2_master]
            merge_history[ingredient2_master] = ingredient1_master
        elif user_input == "2":
            # Merge ingredient1 into ingredient2
            mapping_lists[ingredient2_master].extend(mapping_lists[ingredient1_master])
            del mapping_lists[ingredient1_master]
            merge_history[ingredient1_master] = ingredient2_master
# Out:
# Ingredients 'Lily Flower' and 'Lily Flowers' are already merged as 'Lily Flower'. Skipping merge.
# Ingredients 'Chili Peppers' and 'Green Chili Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Peppers' and 'Chilli Peppers' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Peppers' and 'Chili Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Peppers' and 'Chile Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Peppers' and 'Chilli Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Peppers' and 'Chile Peppers' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Green Chili Pepper' and 'Chilli Peppers' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Green Chili Pepper' and 'Chili Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Green Chili Pepper' and 'Green Chillies' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Green Chili Pepper' and 'Chilli Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Green Chili Pepper' and 'Green Chili Paste' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Pepper Powder' and 'Chili Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Pepper Powder' and 'Chilli Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Green Chiles' and 'Green Chillies' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Green Chiles' and 'Green Chili Paste' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Black Mustard Seeds' and 'Mustard Seed' are already merged as 'Mustard Seeds'. Skipping merge.
# Ingredients 'White Bean Paste' and 'Red Bean Paste' are already merged as 'Bean Paste'. Skipping merge.
# Ingredients 'Chilli Peppers' and 'Chili Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chilli Peppers' and 'Chile Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chilli Peppers' and 'Chilli Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chilli Peppers' and 'Chile Peppers' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Pepper' and 'Chile Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Pepper' and 'Chilli Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Pepper' and 'Chile Peppers' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Bell Peppers' and 'Bell Pepper' are already merged as 'Bell Peppers'. Skipping merge.
# Ingredients 'Matsutake Mushroom' and 'Matsutake Mushrooms' are already merged as 'Mushrooms'. Skipping merge.
# Ingredients 'Green Chillies' and 'Green Chili Paste' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chile Pepper' and 'Chilli Pepper' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chile Pepper' and 'Chile Peppers' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Bean Paste' and 'Red Bean Paste' are already merged as 'Bean Paste'. Skipping merge.
# Ingredients 'Fiddleheads' and 'Fiddlehead' are already merged as 'Fiddleheads'. Skipping merge.
# Ingredients 'Chilli Pepper' and 'Chile Peppers' are already merged as 'Chili Pepper'. Skipping merge.
# Ingredients 'Chili Powder' and 'Korean Chili Powder' are already merged as 'Chili Powder'. Skipping merge.
# Ingredients 'Bean Sprout' and 'Mung Bean Sprout' are already merged as 'Bean Sprouts'. Skipping merge.
# Ingredients 'King Oyster Mushroom' and 'Oyster mushrooms' are already merged as 'Oyster Mushrooms'. Skipping merge.
# Ingredients 'Tomato Puree' and 'Tomato Sauce' are already merged as 'Tomato Sauce'. Skipping merge.
# Ingredients 'Tomato Sauce' and 'Tomato Juice' are already merged as 'Tomato Sauce'. Skipping merge.

# %%
len(mapping_lists)
# Out:
# 754

# %%
# If mapping lists has been re-initialised and merge history has already been created
for key, value in merge_history.items():
    master_ingredient = get_master_name(key, merge_history)
    mapping_lists[master_ingredient].extend(mapping_lists[key])
    del mapping_lists[key]

# %%
# Convert the list to a DataFrame and save it to a CSV
keys_standardised_names = list(mapping_lists.keys())
df = pd.DataFrame(sorted(keys_standardised_names), columns=["Ingredients"])

# Save the DataFrame to a CSV file
csv_file_path = "ingredients_for_manual_cleaning.csv"
df.to_csv(csv_file_path, index=False)

# %%
len(mapping_lists)
# Out:
# 754

# %%
# Load the CSV file
file_path = "manually_cleaned_done.csv"
df = pd.read_csv(file_path)

# Loop over each row in the DataFrame
for index, row in df.iterrows():
    master_ingredient = row["Ingredients"]  # This is the standardized name
    variations = row.dropna()[
        1:
    ].tolist()  # The variations are in the following columns

    if master_ingredient not in mapping_lists:
        mapping_lists[master_ingredient] = []

    for item in variations:
        # Append all variations to the master ingredient's list
        mapping_lists[master_ingredient].extend(mapping_lists[item])
        del mapping_lists[item]

# Output the resulting mapping lists
mapping_lists
# Out:
# {'Chili Pepper': ['ichimi togarashi Japanese chili pepper',
#   'small green chili',
#   'dried chili pepper',
#   'dried red chilies',
#   'cubed chili pepper',
#   'Thai chili pepper or serrano pepper chopped',
#   'Thai chili pepper',
#   'Green Chili Peppers',
#   'dry Kashmiri red chilies',
#   'green chili pepper',
#   'jalapeno or Thai chili',
#   'fresh red chilies',
#   'dried red chili',
#   'Thai chilis',
#   'Sliced hot chili pepper for garnish',
#   'prik chi fa chili',
#   'serrano peppers',
#   'gochukaru',
#   'Chinese long chili pepper',
#   'whole dried chili peppers',
#   'fresh red or green chili pepper',
#   'green chilies or jalapeo',
#   'green chilis',
#   'bird eye chili pepper',
#   'dried whole red chilies',
#   'chilies to taste',
#   'Thai chilies',
#   'Dried chili peppers',
#   'dried Chinese chili peppers',
#   'red chilies',
#   'fresh Thai chili peppers',
#   'Thinly sliced chili peppers',
#   'thai red chili',
#   'red chili pepper',
#   'red chilis',
#   'red chili',
#   'red spur chili',
#   'fresh red chilis',
#   'birds eye chili',
#   'long red Asian chili pepper',
#   'dried Chinese chili pepper',
#   'kashmiri red chili',
#   'Korean green chili peppers',
#   'red dried Chinese chili peppers',
#   'whole dried red Sichuan chilies',
#   'chili pepper',
#   'Thai chili',
#   'green chilies',
#   'dried chili peppers',
#   'dried red chili pepper',
#   'Thai chili pepper or  serrano pepper chopped',
#   'chilies',
#   'birds eye chilis',
#   'chili peppers',
#   'chili oil or fresh diced red chili peppers',
#   ' Thai chili peppers or jalapeo',
#   'Thai birds eye chilis',
#   'fresh chili peppers',
#   'large red chilies',
#   'fresh chilies',
#   'hot green chilies',
#   'large chilies',
#   'Chinese dried chili peppers',
#   'chopped green chili peppers',
#   'green chili',
#   'to Thai chili peppers for garnish',
#   'chilis',
#   'fresh Korean green chili peppers or  dried red chili pepper',
#   'small green chilies',
#   'Korean green chili peppersAnnaheim or Jalapeno peppers',
#   'Green chili peppers optional',
#   'red chili peppers',
#   'hot chili peppers',
#   'red spur chilies',
#   'large red spur chilies',
#   ' to  Thai chili peppers for garnish',
#   'green chilies or  jalapeo',
#   'dried red chilis',
#   'Chinese chili peppers',
#   'dried chilies',
#   'red chile peppers',
#   'small green chiles',
#   'dry red spur chilies',
#   'Thai chillies',
#   'fried dried chilies',
#   'red chili pepper powder',
#   'a handful of green chilies',
#   'green chilies   long chilies',
#   'crushed green chilies',
#   'green chilies chopped',
#   'green chillies jalapeo',
#   'green chillies',
#   'green chili paste',
#   'Jalapeno or Korean Green Chili',
#   'chili',
#   'hot green chili',
#   'dried chilis',
#   'green chilli',
#   'Indian green chilies',
#   'dry chilies',
#   'a handful of chilies',
#   'prik chi fa',
#   'kashmiri',
#   ' Thai chili pepper or  serrano pepper chopped'],
#  'Mayonnaise': ['Mayonnaise',
#   'Kewpie mayonnaise',
#   'kewpie mayo',
#   'mayonnaise ketchup or mustard',
#   'mayonnaise',
#   'WAFU Spicy Mayonaizu',
#   'Japanese mayonnaise',
#   'Homemade Spicy Mayo',
#   'Japanese Kewpie mayonnaise'],
#  'Peanuts': ['peanuts',
#   'Roasted peanuts',
#   'coarsely ground roasted peanuts',
#   'roasted cashews or peanuts',
#   'finely chopped peanuts',
#   'roasted ground peanuts',
#   'Chopped peanuts for garnish',
#   'scant cup salted roasted peanuts',
#   'crushed peanuts',
#   'raw peanuts',
#   'fried peanuts',
#   'a handful of roasted peanuts',
#   'toasted peanuts',
#   'crushed roasted peanuts',
#   'raw skinon peanuts',
#   'shelled peanut',
#   'ground peanuts',
#   'roasted peanuts',
#   'Roasted peanut',
#   'Crushed roasted peanuts',
#   'Crushed roasted peanuts or roasted sesame seeds'],
#  'Jalapeno Peppers': ['jalapenos',
#   'jalapeno pepper',
#   'anaheim peppers',
#   'jalapeno sliced into  wedges',
#   'jalapeno minced',
#   'jalapeos',
#   'jalapeno',
#   'Jalapeno Pepper',
#   'jalapeo pepper',
#   'Jalapeno peppers'],
#  'Miso Paste': ['miso paste',
#   'hatcho miso',
#   'white miso paste',
#   'Mnute Miso liquid miso',
#   'miso',
#   'Homemade AllPurpose Miso Sauce',
#   'dashiincluded miso',
#   'Homemade Ume Miso',
#   'white miso',
#   'Hikari Organic White Miso   mg sodium g',
#   'Homemade Negi Miso',
#   'Saikyo miso Kyotostyle white miso'],
#  'Green Peas': ['green peas', 'fresh or frozen green peas'],
#  'Lotus Root': ['blanched lotus roots',
#   'lotus root',
#   'Lotus root',
#   ' grams fresh lotus root',
#   'lotus root renkon'],
#  'Sichuan Peppercorns': ['sichuan peppercorns',
#   'Szechuan peppercorns',
#   'freshly ground Sichuan peppercorns',
#   'ground Sichuan peppercorns',
#   'freshly coarsely ground Sichuan peppercorns',
#   'Sichuan peppercorn',
#   ' teaspoon Sichuan peppercorn',
#   'ground toasted Sichuan peppercorn',
#   'whole Sichuan peppercorn',
#   'ground Sichuan peppercorn',
#   'freshly ground Sichuan peppercorn',
#   'ground toasted Sichuan peppercorns',
#   'Sichuan peppercorn powder',
#   'Sichuan peppercorns'],
#  'NaN': ['FoodSaver FM Vacuum Sealing System',
#   'Optional Garnish',
#   'Reynolds Wrap NonStick Foil',
#   'Chinese',
#   'flat plate or smooth metal or stone surface',
#   'dry rub of your choice',
#   'Chrysanthemum leaves or Crown Daisies',
#   'block',
#   'reserved shiitake soaking liquid',
#   'whole bonein',
#   'soboro don',
#   'lily bulb',
#   'codonopsis root',
#   'homemade kansui',
#   'rosdee flavor seasoning',
#   'Spicy Bean Sprout Salad',
#   'precooked muthia',
#   'flavor seasoning',
#   'Pocky',
#   'yanang',
#   'dalgona mold or cookie cutter molds',
#   'Japanese milk bread',
#   'Electric Mixer',
#   'Parchment paper',
#   'atap fruit',
#   'medium grade cheesecloth',
#   'A gram Mooncake mold',
#   'Fluted pastry cutter',
#   'bird nest',
#   'a silicone or cheese cloth liner for the steamer if no pine needles',
#   'Reynolds Wrap Heavy Duty Foil',
#   'used kombu kelp',
#   'Cotton twine or narrow stalks to tie the zongzi',
#   'bamboo skewers',
#   'Dhokli',
#   'Chee Hou sauce',
#   'cigarette cookies',
#   'calabash',
#   'calcium hydroxide',
#   'Hikari Miso Shio Koji',
#   'stainless steel mixing bowl or pot',
#   'Optional Toppings',
#   'metal chopstick or a candy stick',
#   'Kitchen twine',
#   'of charcoal',
#   'Homemade Kasudoko',
#   'Dried jujubespine nutsalmonds',
#   'dried lily flowers',
#   'Sliced tomato onion and lettuce leaves for toppings',
#   'Pan drippings',
#   'gulkand',
#   'mawa  grams',
#   'steamer',
#   'kimchi liquid',
#   'green tea ice cream',
#   'tian mian jiang sweet flour sauce',
#   'loosely packed crown daisies',
#   'syrup from kuri kanroni',
#   'ravasemolina',
#   'dinner rolls',
#   'asparagus beef rolls',
#   'Bamboo skewers',
#   'crown daisies',
#   'Lao Gan Ma Spicy Chili Crisp',
#   'Sui Mi Ya Cai',
#   'gulkandrose preserve',
#   'Baijiu',
#   'awamori Okinawan distilled liquor',
#   'dried lily flower',
#   'saltpickled cherry blossoms',
#   'green leaf',
#   'toppings of your choice',
#   'proteins',
#   'FoodSaver Sousvide Vacuum Seal Bags',
#   'Vegan',
#   'ssukat',
#   'hot pot bases',
#   'reserved blanching liquid',
#   'milk bread',
#   'golden mountain sauce',
#   'acacia leaves',
#   'Sousvide precision cooker',
#   'Rice Kheer',
#   'fine ravasemolina',
#   'yukari rice seasoning',
#   'Water Dropwort',
#   'Toppings',
#   'look chin',
#   'pumpkin pie spice',
#   'segment',
#   'peanut bar',
#   'twine',
#   'Mugwort Ssuk',
#   'sausage casing',
#   'kuchinashi no mi dried gardenia pods',
#   'small silicon spatula or spoon for scraping',
#   'condiments of your choice',
#   'Kimchi pork base mix',
#   'guk kanjang',
#   'stalks of chrysanthemum leaves',
#   'liquid smoke',
#   'spinach gomaae',
#   'rice paddy herb',
#   'thin bamboo sticks',
#   'Sansai Mix Sansai Mizuni',
#   'braising liquid',
#   'Garnish',
#   'Serving options',
#   'cut in wedges',
#   'Pav',
#   'thandai powder',
#   'white lotus seeds',
#   'kalbi bones with meat',
#   'gosari reconstituted',
#   'Small Chinese rolling pin',
#   'green',
#   'Sushi rolling mat',
#   'Sauce',
#   ' oz   g block firm',
#   'nonoil aojiso dressing',
#   'Egg tart mold',
#   'ladle or large spoon',
#   'gajar halwa',
#   'shochu',
#   'outer layers of the Tokyo negis white stalk',
#   'rosdee seasoning powder',
#   'Naan',
#   'pie crust'],
#  'Ginger': ['large slices ginger',
#   'finely minced ginger',
#   'Sliced ginger for garnish',
#   'thinly sliced ginger',
#   'grated fresh ginger',
#   'thumb ginger',
#   'ground ginger',
#   'miced ginger',
#   'chopped ginger',
#   'thick slices of ginger',
#   'finely grated ginger',
#   'fresh ginger grated',
#   'thumbnail ginger',
#   'minced ginger',
#   'small thumb ginger',
#   'ginger juice',
#   'fresh grated ginger',
#   'chopped fresh ginger',
#   'thumbs ginger',
#   'ginger grated',
#   'sushi ginger gari',
#   'grated ginger juice',
#   'sushi ginger',
#   'ginger powder',
#   'large pieces ginger',
#   'fresh ginger',
#   'young ginger',
#   'large thumb ginger',
#   'large piece ginger',
#   'ginger',
#   'grated ginger',
#   'fresh ginger  in thick slice',
#   'Ginger Paste',
#   'ginger slices',
#   'ginger paste',
#   'ginger slice',
#   'grated or chopped fresh ginger',
#   'chopped fresh ginger or  t ginger powder',
#   'myoga ginger',
#   'big thumb ginger',
#   'big slice ginger'],
#  'Yogurt': ['plain regular or low fat yogurt',
#   'Greek yogurt',
#   'fullfat plain yogurt',
#   'yogurt',
#   'regular plain yogurt',
#   'Greek Yogurt',
#   'full fat or Greek yogurt',
#   'plain yogurt',
#   'greek yogurt',
#   'full fat yogurt',
#   'Greek yogurt for garnish',
#   'plain Greek yogurt'],
#  'Sauce': ['Yakiniku Sauce',
#   'Chili Garlic Sauce',
#   'yakisoba sauce',
#   'red sauce',
#   'Shacha sauce',
#   'unagi eel sauce',
#   'Chinese dumpling sauce',
#   'chili garlic sauce'],
#  'Chicken': ['cornish hen or chicken carcass',
#   'bonein chicken',
#   'chicken breasts or thighs',
#   'boneless skinless chicken breasts or thighs',
#   'chicken tenders',
#   'boneless chicken breast or thighs',
#   'boneless skinless breast or chicken thigh',
#   'bonein skinon thigh',
#   'chicken teriyaki',
#   'shio koji karaage',
#   'leftover chicken',
#   'Chicken breast or thigh',
#   'chicken leg quarters',
#   'boneless skinless chicken thigh or breast',
#   'whole rotisserie chicken',
#   'chicken knuckles',
#   'chicken tenderstenderloins',
#   'fried chicken',
#   'boneless skinless chicken thighs or breasts',
#   'boneless skinless chicken breast or  chicken thighs',
#   'chicken pcs with bone',
#   'cornish game hen',
#   'chicken legs',
#   'skinless boneless chicken breasts',
#   'Chicken drumsticks skinned',
#   'chicken drumsticks',
#   'ground chicken thigh',
#   'Ootoyas sweet and sour chicken',
#   'chicken thighs or  breast',
#   'chicken breasts cut into cubes',
#   ' to  lbs   to  kg whole chicken',
#   'drumsticks',
#   'chicken thigh or breast',
#   'chicken thighs',
#   'chicken thigh',
#   'chicken katsu',
#   'chicken backs and necks',
#   'chicken breasts',
#   'whole bone in chicken',
#   'frozen bonein skinon chicken thighs',
#   'garlic miso chicken',
#   'cornish hen',
#   'honey soy sauce chicken',
#   'chicken breast or thigh',
#   'silkie chicken',
#   'chicken wings flatsdrumettes',
#   'boneless skinless chicken thighs',
#   'chicken bonein skinon chicken thigh chicken leg or boneless skinless thigh',
#   'boneless skinless chicken thigh',
#   'whole chicken',
#   'raw chicken wings',
#   'chicken thighs or breast',
#   'chicken meat dark and white',
#   'teriyaki chicken meatballs',
#   'karaage',
#   'chicken breast or boneless thighs',
#   'Chicken Chashu',
#   'chicken',
#   'bonein chicken legandthigh portions',
#   'whole chicken Footnote ',
#   'chicken drumettes',
#   'Rotisserie chicken or other leftover meat shredded',
#   'boneless skinless chicken breast or  boneless skinless chicken thighs',
#   'skinless boneless breast',
#   'pork loin or chicken breast',
#   'chicken breast',
#   'boneless skinless chicken breasts',
#   'large boneless skinless chicken breast',
#   'total small boneless skinless chicken breasts',
#   'boneless skinless chicken breast or thighs',
#   'skinless chicken breast',
#   'thin chicken breasts',
#   'chicken breasts cut into  inch pieces',
#   'boneless skinless chicken breast or boneless skinless chicken thighs',
#   'chicken thighs or chicken breast',
#   'boneless chicken breast or boneless chicken leg',
#   'chicken thighs skinless',
#   'boneless skinless chicken breast',
#   'boneless skinon chicken breast',
#   'rendered chicken fat',
#   'chicken fat from the drippings',
#   'chicken feet',
#   'bonein skinon chicken legs',
#   'bonein skinon chicken leg quarters',
#   'bonein chicken legs and thighs',
#   'bonein chicken leg quarters',
#   'chicken skin',
#   'skinless boneless chicken thigh',
#   'bonein skinon chicken thigh',
#   'chicken thigh about  thigh',
#   'bonein skinon chicken thighs',
#   'boneless skinon chicken thighs',
#   'chicken thighs cut into pieces',
#   'chicken wings',
#   'chicken wings or drummetts',
#   'ground chicken or ground turkey',
#   'ground chicken',
#   'chicken ground',
#   'chicken meatballs',
#   'Chicken meatballs'],
#  'Dressing': ['Japanese sesame dressing', 'Japanese Sesame Dressing'],
#  'Tofu': ['Tofu sheets',
#   'deepfried firm tofu cutlet atsuage',
#   'pack soft tofu',
#   'Fermented tofu',
#   'oz  g block extra firm tofu',
#   'unpressed soft tofu  oz g',
#   'firm or medium firm tofu',
#   'mediumfirm tofu momen dofu',
#   'homemade tofu pudding',
#   'baked tofu',
#   'silken tofu',
#   'pack of  oz extra firm tofu',
#   'extra soft tofu  Soondubu',
#   'koyadofu freezedried tofu',
#   'tofu puffs',
#   'firm tofu',
#   'Fermented Tofu',
#   'Tofu knots',
#   'sliced tofu',
#   'pack of extra firm tofu',
#   'Blocks of tofu firm or extra firm',
#   'tofu sheet',
#   'soft tofu  ounces   g per block',
#   'block tofu',
#   'soft tofu',
#   'fermented tofu',
#   'Tofu sticks',
#   'extrafirm tofu',
#   'red bean curd plus  teaspoon juice',
#   'firm tofu  oz   g per block',
#   'deep fried tofu puffs',
#   'block firm tofu',
#   'block soft tofu',
#   'organic firm tofu',
#   'extrafirm or firm tofu',
#   'firm tofu  oz   g',
#   'firm silken tofu',
#   'Frozen tofu',
#   'broiled tofu yaki dofu',
#   'tofu',
#   'soft or medium firm tofu',
#   'Deep fried tofu puffs',
#   'extra firm tofu',
#   'extra soft tofu  sundubu',
#   'dried tofu',
#   'softsilken tofu kinugoshi dofu',
#   'egg tofu',
#   'ganmodoki Japanese fried tofu patties',
#   'sliced firm tofu',
#   'block fried tofu or baked tofu',
#   'aburaage deepfried tofu pouch',
#   'House Foods extra firm tofu',
#   'fried tofu',
#   ' pack of extra firm tofu'],
#  'Rice': ['leftover white rice',
#   'Jasmine Rice',
#   'overnight jasmine rice or other medium grain rice',
#   'sliced sticky rice cakes',
#   'of leftover cooked jasmine rice',
#   'cold steamed rice',
#   'sweet riceglutinous rice mochigome',
#   'uncooked sticky rice',
#   'uncooked Jasmine rice',
#   'OR steamed rice',
#   'short grain rice',
#   'Steamed white rice to serve with',
#   'uncooked short grain white rice',
#   'long grain white rice',
#   'cold dayold rice',
#   'bubu arare crispy puffed rice pellets',
#   'black rice',
#   'Basmati rice',
#   'dayold long grain rice',
#   'white glutinous rice',
#   'uncooked Japanese shortgrain brown rice',
#   'leftover cooked rice',
#   'short grain sweet rice',
#   'shortgrain rice',
#   'Short Grain Rice',
#   'glutinous rice',
#   'jasmine rice',
#   'Extra long grain Basmati rice',
#   'Basmati Rice',
#   'cooked white rice',
#   'leftover rice',
#   'uncooked short grain rice',
#   'brown rice',
#   'leftover cooked white rice',
#   'black glutinous rice',
#   'short grain white rice',
#   'leftover steamed rice',
#   'rice',
#   'Jasmine rice',
#   'white rice',
#   'cooked rice',
#   'Steamed rice',
#   'cooked jasmine rice',
#   'long grain basmati rice',
#   'uncooked Japanese shortgrain white rice',
#   'cooked jasmine rice or other medium grain rice',
#   'jasmine rice rinsed and drained',
#   'sweet rice',
#   'steamed rice',
#   'cold dayold jasmine rice',
#   'forbidden rice',
#   'overnight jasmine rice',
#   'brown basmati rice',
#   'extra long grain Basmati rice',
#   'idli rice',
#   'basmati rice or any white rice',
#   'basmati rice',
#   'raw white rice',
#   'steamed jasmine rice',
#   'short grain sticky rice',
#   'cooked short grain rice',
#   'cooked Japanese shortgrain rice',
#   'longgrain basmati rice',
#   'uncooked jasmine rice',
#   'sushi rice pillows',
#   'sushi rice cooked and seasoned',
#   'chirashi sushi mix',
#   'soaked sweet rice',
#   'poha',
#   'thin poha'],
#  'Fava beans': ['fresh broad beans'],
#  'Gochugaru': ['Korean chili thread',
#   'Korean red pepper powder',
#   'Korean red chili powder Gochukaru',
#   'Korean red chili powder'],
#  'Chrysanthemum': ['dried chrysanthemum buds',
#   'bunch Chrysanthemum leaves',
#   'chrysanthemum leaves',
#   'Chrysanthemum leaves'],
#  'Vinegar': ['Japanese black vinegar kurozu',
#   'rice vinegar or whiteapple cider vinegar',
#   'Chinkiang vinegar',
#   'Vinegar',
#   'balsamic vinegar',
#   'rice or apple vinegar',
#   'ume plum vinegar',
#   'vinegar',
#   'distilled white vinegar',
#   'white wine vinegar',
#   'white vinegar',
#   'seasoned rice vinegar sushi vinegar',
#   'rice vinegar unseasoned',
#   'black rice vinegar',
#   'Chinese white rice vinegar',
#   'rice vinegar',
#   'cooking rice wine or sake',
#   'mirin or rice wine or sake',
#   'cooking sake rice wine',
#   'Korean rice wine mirim ',
#   'cooking rice wine',
#   'rice wine',
#   'sake or rice wine',
#   'shaoxing rice wine',
#   'cooking rice wine or mirin',
#   'cooking sake or rice wine',
#   'sweet rice wine',
#   'apple cider vinegar',
#   'chinkiang vinegar',
#   'black vinegar',
#   'Chinese black vinegar'],
#  'Bracken starch': ['warabi mochiko or warabiko bracken starch'],
#  'Pork': ['ground pork',
#   'Char Siu Chinese BBQ pork',
#   'shogayaki ginger pork',
#   'pork meat and bone for braising',
#   'pork balls',
#   'Pork and napa cabbage',
#   'minced pork',
#   'char siu pork',
#   'pork ribs',
#   'pork neck bones',
#   'pork ribs  to  lbs',
#   'ground pork leanfat ratio ',
#   'pork tenderloin or loin',
#   'Kimchi Pork Mix Base',
#   'fatty ground pork',
#   'ground lean pork',
#   'pork chops',
#   'pork',
#   'Pork Belly',
#   'boneless pork sirloin',
#   'pork belly or shoulder',
#   'pork spare ribs',
#   'boneless   cm thick pork chops',
#   'pork loin or tenderloin',
#   'Homemade Shogayaki Ginger Pork',
#   'thinly sliced pork',
#   'pork collar',
#   'Pork loin sirloin shoulder or pork belly',
#   'pork belly beef stew meat chicken breast or thighs',
#   'pork meat',
#   'pork shoulder pork butt',
#   'thinly sliced pork neck buttlegshoulder',
#   'Pork with shiitake mushrooms',
#   'pork belly slices',
#   'of pork belly',
#   'fatty pork pork belly chop or loin with fat attached',
#   'thinlysliced pork belly',
#   'pork belly',
#   'sliced pork belly',
#   'pork belly block',
#   'Braised Pork Belly Kakuni',
#   'Homemade Chashu Japanese Braised Pork Belly',
#   'crispy pork belly',
#   'pork belly samgyeopsal',
#   'beef stew meat or pork belly cubed',
#   'whole slab of skinon pork belly',
#   'boneless pork chops',
#   'bonein thin cut pork chops',
#   'boneless pork loin chops  inch thick',
#   'thinsliced bonein or boneless pork rib chops',
#   'in total boneless thin pork chops',
#   'pork leg',
#   'pork loin',
#   'thinly sliced pork loin',
#   'boneless pork loin chops inch thick',
#   'sliced pork loin',
#   'bonein pork loin chops  inch thick',
#   'pork baby back ribs',
#   'pork spare ribs strips',
#   'St Louis ribs or baby back ribs',
#   'braised pork ribs',
#   'wellmarbled pork ribs',
#   'pork ribs about  kg   lbs',
#   'pork shoulder',
#   'pork tenderloin',
#   'pork skin',
#   'pork skin with fat'],
#  'Cauliflower': ['cauliflower head',
#   'Chinese cauliflower',
#   'medium or small head cauliflower',
#   'Chinese cauliflower or regular cauliflower',
#   'cauliflower florets',
#   'cauliflower',
#   'riced cauliflower',
#   'Chinese cauliflower florets',
#   'cauliflower rice'],
#  'Coconut': ['frozen fresh coconut',
#   'unsweetened coconut',
#   'unsweetened coconut frozen or dry',
#   'freshly grated coconut',
#   'unsweetened shredded coconut',
#   'shredded dry coconut',
#   'dry shredded coconut',
#   'grated unsweetened coconut',
#   'shredded coconut',
#   'grated coconut',
#   'young coconut',
#   'coconut meat',
#   'grated fresh coconut',
#   'dry unsweetened grated coconut',
#   'coconut frozen',
#   'grated dry coconut',
#   'coconut',
#   'dry unsweetened coconut',
#   'shredded unsweetened coconut',
#   'frozen grated coconut',
#   'young coconut meat',
#   'roasted grated coconut',
#   'roasted coconut shreds',
#   'thin dry sliced coconut',
#   'fresh grated coconut',
#   'grated coconut meat',
#   'fresh coconut',
#   'desiccated coconut'],
#  'Pistachios': ['sliced pistachios',
#   'Thinly sliced pistachios',
#   'pistachios',
#   'thinly sliced pistachios',
#   'shelled pistachios',
#   'Rose petals  pistachios for garnish',
#   'raw unsalted pistachios',
#   'roasted pistachios',
#   'pistachios sliced',
#   'chopped pistachios'],
#  'Salmon': ['Homemade Japanese Salted Salmon',
#   'salmon',
#   'skinon salmon fillet',
#   'smoked salmon',
#   'bonein halibut or Salmon',
#   'Salmon',
#   'salmon filet',
#   'salmon fillets',
#   'wild salmon fillet',
#   'salmon fillet wild caught',
#   'skinon salmon fillets',
#   'skinon Japanesestyle salmon fillets',
#   'skinless salmon fillet',
#   'sashimigrade salmon',
#   'wild salmon',
#   'cooked salmon',
#   'salmon fillet',
#   'Homemade Salmon Flakes',
#   'salmon scraps',
#   'broiled salmon',
#   'teriyaki salmon'],
#  'Bellflower Root': ['reconstituted bellflower roots'],
#  'Broccoli': ['broccoli rabe or  big head broccoli',
#   'Chinese broccoli baby bok choy or chopped broccoli',
#   'broccoli',
#   'Chinese broccoli',
#   'big head broccoli',
#   'head broccoli',
#   'broccolini',
#   'small head broccoli',
#   'large head of broccoli',
#   'broccoli florets',
#   'stalks Chinese broccoli',
#   'gai lan',
#   'Chinese broccoli Gai Lan'],
#  'Gelatin': ['gelatin sheet', 'gelatin', 'gelatin sheets'],
#  'Canola Oil': ['canola oil'],
#  'Buckwheat Flour': ['buckwheat flour'],
#  'Pine Nuts': ['pine nutsdried jujubescitron syrupmint leaves',
#   'pine nuts chopped',
#   'chopped pine nuts',
#   'pine nuts'],
#  'Syrup': ['rice syrup',
#   'Syrup to taste',
#   'Green plum syrup maesil syrup',
#   'osmanthus syrup',
#   'plum syrup',
#   'green plum syrup',
#   'ume plum syrup',
#   'kuromitsu black sugar syrup',
#   'flavored syrup',
#   'mizuame syrup glutinous starch syrup',
#   'homemade golden syrup',
#   'maesil green plum syrup'],
#  'Radish': ['Korean radish',
#   'radish',
#   'Korean Radish',
#   'medium size radish',
#   'white radish',
#   'pickled radish',
#   'sliced Korean radish',
#   'small daikon radish',
#   'Daikon radish',
#   'red radish',
#   'sweet preserved radish',
#   'julienned Korean radish',
#   'dried radish strips mumalleangi',
#   'Korean radish or Daikon',
#   'small radish',
#   'Daikon radish or other radishes',
#   'radishes',
#   'red radishes',
#   'daikon radish peeled and chopped generates  cups',
#   'kiriboshi daikon dried daikon strips',
#   'daikon leaves and stems',
#   'daikon',
#   'daikon radish',
#   'Korean radish daikon also works',
#   'daikon radish peeled and chopped generates cups',
#   ' daikon radish peeled and chopped generates  cups'],
#  'Coriander': ['coriander',
#   'ground coriander',
#   'coriander seeds',
#   'handful of coriander',
#   'a small handful of coriander',
#   'ground corinader',
#   'whole coriander seeds',
#   'bunches of coriander root',
#   'coriander root',
#   'to tablespoons chopped cilantro for garnish',
#   'Chopped cilantro',
#   'loosely packed cilantro',
#   'small batch cilantro',
#   'cilantro chopped for garnish',
#   'finely chopped cilantro',
#   'Chopped cilantro andor green onions',
#   'chopped fresh cilantro',
#   'coriander leaves',
#   'Cilantro',
#   'cilantro for garnish',
#   'cilantro',
#   'cilantro chopped',
#   'cilantro leaves',
#   'Cilantro leaves',
#   ' tablespoons chopped cilantro for garnish',
#   'chopped cilantro for garnish',
#   'cilantro handful',
#   'Chopped cilantro or green onion for garnish',
#   'chopped cilantro',
#   'loosely packed chopped cilantro',
#   'cilantro finely chopped',
#   'cilantro for garnishing',
#   'fresh cilantro',
#   'cilantro to garnish',
#   'cilantro packed',
#   'cilantro coriander',
#   'Chopped cilantro for garnish',
#   'cilantro stems',
#   'cilantro leaves chopped for garnish',
#   'Chopped cilantro leaves',
#   'to  tablespoons chopped cilantro for garnish',
#   'Chopped cilantro and chopped green onion for garnish',
#   ' to  tablespoons chopped cilantro for garnish',
#   'culantro',
#   'of culantro'],
#  'Rice Water': ['leftover rice water', 'rice water'],
#  'Melon': ['bitter melon bitter gourd or goya',
#   'Winter melon',
#   'winter melon',
#   'large bitter melon',
#   'bitter melon',
#   'bitter melons'],
#  'Water': ['reserved tomato blanching water',
#   'water for stove top',
#   'warm water F  C',
#   'cold tap water',
#   'water for soaking lentils',
#   'roomtemperature water',
#   'ice cold water',
#   'cold water',
#   'reserved water from soaking kiriboshi daikon',
#   'water or milk',
#   'tap water',
#   'ice bath',
#   'room temperature water',
#   '  tsp water',
#   'hot boiling water',
#   'reserved pasta water',
#   'Water',
#   '  Tbsp water',
#   'soaking water from the lily flower and mushroom',
#   'noodle boiling water',
#   'water',
#   'hot water',
#   'of water',
#   'sparkling water',
#   'mushroom soaking water',
#   'filtered water',
#   'icecold water',
#   'slightly less than  cup water room temperature',
#   'rice water or water',
#   'alkaline water',
#   'a large bowl lukewarm water',
#   ' cup   tablespoons cool water',
#   'mushroom soaking liquid',
#   'milk or water',
#   'warm water',
#   'x water',
#   'boiling water',
#   'iced water',
#   'ice water',
#   'cold water bath',
#   'cool water'],
#  'Eggplant': ['long eggplants',
#   'Chinese eggplant',
#   'Chinese long eggplant',
#   'chinese eggplant',
#   'Chinese eggplant about  oz   g',
#   'small baby eggplants',
#   'Chinese eggplants about  small',
#   'Thai eggplants',
#   'baby eggplants',
#   'Japanese or Chinese eggplants',
#   'pea eggplant',
#   'eggplants',
#   'pea eggplants',
#   'eggplant',
#   'thai eggplant',
#   'Japanese eggplants',
#   'Japanese eggplant',
#   'Chinese eggplants',
#   'baby eggplant',
#   'Japanese or Chinese eggplant',
#   'Chinese eggplant or regular eggplant',
#   'Thai eggplant',
#   'eggplants about  large Chinese eggplant or  American eggplant',
#   'a handful of pea eggplants'],
#  'Lettuce': ['head Boston lettuce or iceberg lettuce',
#   'romaine lettuce',
#   'Lettuce',
#   'Lettuce leaves',
#   'lettuce',
#   'red leaf lettuce',
#   'small head romaine lettuce',
#   'lettuce leaves',
#   'head bibb',
#   'green or red leaf lettuce leaves',
#   'green leaf lettuce',
#   'butter lettuce leaves',
#   'butter lettuce',
#   'iceberg lettuce'],
#  'Mushrooms': ['dried Shitake mushrooms',
#   'chopped mushrooms',
#   'button mushrooms',
#   'white shimeji mushrooms',
#   'mushrooms',
#   'King oyster mushrooms',
#   'king oyster mushrooms',
#   'dried woodear mushrooms',
#   'Shimeji',
#   'dried shiitake mushrooms about  oz   g',
#   'mushrooms of your choice',
#   'oyster mushrooms',
#   'mushrooms sliced',
#   'cremini mushrooms',
#   'assorted mushrooms',
#   'nameko mushrooms',
#   'white mushrooms',
#   'seasoned shiitake and kanpyo',
#   'dried shitake mushroom',
#   'dried shiitake',
#   'shitake mushrooms',
#   'shimeji mushroom',
#   'enoki',
#   'batch enoki mushrooms',
#   'straw mushrooms',
#   'shiitake mushrooms',
#   'dried shitake mushrooms',
#   'mediumsized dried shiitake mushrooms',
#   'large dried shitake mushrooms',
#   'dried shiitake mushrooms',
#   'large dried or fresh shitake mushrooms',
#   'maitake mushrooms',
#   'matsutake mushroom',
#   'matsutake mushrooms',
#   'enoki mushrooms',
#   'Enoki golden needle mushrooms',
#   'king oyster mushroom',
#   'assortment of Japanese mushrooms',
#   'brown mushrooms',
#   'shiitake mushroom',
#   'golden needle mushrooms',
#   'Asian mushrooms',
#   'dried shiitake mushroom',
#   'Shiitake mushrooms',
#   'pack of white or brown mushrooms',
#   'king oyster mushrooms eringi',
#   'king oyster mushroom eringi',
#   'Oyster mushrooms',
#   'shimeji mushrooms',
#   'dried wood ear mushroom',
#   'cloud ear mushrooms',
#   'Wood ear mushrooms',
#   'dried wood ear mushrooms',
#   'wood ear mushrooms',
#   'dried wood ear',
#   'A small pinch of dried wood ear mushrooms'],
#  'Dumpling Wrappers': ['Hong Kong Style dumpling wrappers',
#   'pack dumpling wrappers',
#   'package of dumpling wrappers',
#   'frozen dumpling wrappers',
#   'homemade dumpling wrappers',
#   'homemade dumplings wrappers',
#   'gyoza wrappers',
#   'dumpling wrappers'],
#  'Mascarpone Cheese': ['mascarpone cheese', 'container of mascarpone cheese'],
#  'Oil': ['oil',
#   'Peanut oil or olive oil',
#   'oil or ghee',
#   'oil spray',
#   'cooking spray',
#   'chili oil',
#   'ghee or oil',
#   'butter or oil',
#   'cooking oil',
#   'oil for frying',
#   'green Sichuan pepper oil',
#   'Butter or neutral oil',
#   'neutral oil',
#   'ghee or neutral oil',
#   'oil for basting',
#   'oil for cooking',
#   'Oil spray',
#   'Oil or ghee for frying',
#   'Vegetable or Canola Oil for frying',
#   'canola oil or vegetable oil',
#   'vegetable oil',
#   'vegetable oil for brushing',
#   'vegetable oil if deep frying',
#   'Vegetable oil for deepfrying',
#   'vegetable oil or other neutral oil',
#   'Vegetable oil for pan frying',
#   'vegetable oil for frying',
#   'vegetable oil for deep frying',
#   'vegetable oil for pan frying',
#   'Vegetable oil for deep frying',
#   'peanut oil or vegetable oil',
#   'Oil for frying',
#   'Oil for deep frying',
#   'lots of vegetable oil for frying',
#   'Vegetable oil',
#   'neutral vegetable oil',
#   'and  tablespoons vegetable oil',
#   'vegetable oil if pan frying',
#   'Vegetable oil for frying',
#   'vegetable oilolive oil',
#   'olive  oil',
#   'extra virgin olive oil',
#   'olive oil',
#   ' tablespoon vegetable oil and a pinch of salt',
#   'olive or other vegetable oil'],
#  'Squid': ['small calamari',
#   'Squid or cuttlefish',
#   'dried squid strips ojingeochae',
#   'squid about  medium sized',
#   'squid tubes',
#   'spear squid',
#   'squid',
#   'sliced squid',
#   'baby squid',
#   'large or  small squid'],
#  'Cabbage': ['purple cabbage thinly sliced and chopped',
#   'cabbage leaves',
#   'red cabbage',
#   'head red cabbage',
#   'regular cabbage or  head Taiwanese flat cabbage',
#   'Seoul cabbage',
#   'small head cabbage',
#   'shredded cabbage',
#   'shredded green cabbage',
#   'head cabbage',
#   'small head napa cabbage',
#   'Napa cabbage',
#   'purple cabbage',
#   'small green cabbage',
#   'green cabbage',
#   'white cabbage',
#   'large Korean cabbage',
#   'small seoul green cabbage',
#   'chopped napa cabbage',
#   'chopped green cabbage',
#   'cabbage',
#   'napa cabbage',
#   'sliced napa cabbage',
#   'large napa cabbage leaves',
#   'Chinese cabbage',
#   'Korean small cabbage',
#   'sliced purple cabbage'],
#  'Kelp': ['Dried Kelp Dasima or Kombu',
#   'dried kelp one x sheet',
#   'in square dried kelp  Dashima for broth',
#   'Dried Kelp',
#   'Kelp Dasima or Kombu',
#   'large piece kelp',
#   'in square dried kelp Dashima for broth',
#   ' in square dried kelp  Dashima for broth',
#   'dried kombu kelp or dashima ',
#   'tororo kombu',
#   'kombu dried kelp',
#   'kombu',
#   'dried knotted kombu',
#   'hidaka kombu',
#   'shio kombu'],
#  'Zucchini': ['Korean baby zucchini',
#   'zucchinis',
#   'large Korean Zucchini',
#   'large Korean or Italian zucchini',
#   'medium zucchini',
#   'baby zucchinis',
#   'dried zucchini slice',
#   'Italian Zucchini or Aehobak Korean baby squash',
#   'zucchini or  pound russet potato',
#   'zucchini'],
#  'Kimchi': ['cabbage kimchi',
#   'Kimchi  with liquid',
#   'kimchi',
#   'ripe kimchi',
#   'chopped sour kimchi or aged kimchi',
#   'napa cabbage kimchi',
#   'kimchi juice',
#   'kimchi juice drained from jar'],
#  'Bok Choy': ['heads baby bok choy',
#   'Baby bok choy',
#   'Shanghai bok choy',
#   'bok choy flower',
#   'batches little bok choy',
#   'baby bok choy about  small heads',
#   'baby bok choy',
#   'bok choy'],
#  'Holy Basil': ['holy basil'],
#  'Green Onions': ['bunches green onions',
#   'Chopped green onions',
#   'green onions chopped',
#   'green onions  cut  green onions into  inch',
#   'handful of green onions',
#   'stalks green onion',
#   'Chopped green onion',
#   'green onions  coriander mixed',
#   'green onions coarsely sliced to fill the marinade Footnote  reserve green parts for garnish',
#   'green onionsscallions',
#   'chopped green onions',
#   'Chopped green onion for garnish',
#   'finely chopped green onion green part',
#   'Reserved green onion',
#   'Sliced green onion and  or fried garlic',
#   'Chopped green onion and  or toasted sesame seeds',
#   'chopped green onion',
#   'dried or fresh green onion roots',
#   'green onions for cooking broth',
#   'bunch green onions',
#   'Sliced green onion',
#   'Sliced green onion for garnish',
#   'a handful of green onions',
#   'garlic chives or  green onions',
#   'green onions or  Korean leek',
#   'rakkyo Japanese pickled scallion',
#   'Green onions for garnish',
#   'green onions',
#   'some dark green tops of the Tokyo negi',
#   'light green leaves of the Tokyo negi',
#   'green onions or korean leek',
#   'spring onions',
#   'green onion for garnish',
#   'young green onions',
#   'green onionscallion',
#   'Tokyo negi naga negi',
#   'Chinese scallions',
#   'Korean or Chinese Chives',
#   'green scallions',
#   'Chinese scallions or regular scallion',
#   'green onions or  korean leek',
#   'Chinese scallion',
#   'chopped scallion',
#   'scallion',
#   'mix of scallions'],
#  'Turmeric': ['ground turmeric',
#   'turmeric',
#   'turmeric powder',
#   'turmeric ground',
#   'fresh yellow turmeric roots',
#   'ground turmeric powder'],
#  'Snow Peas': ['snow peas',
#   'fresh or frozen snow peas',
#   'snow pea shoots',
#   'Snow pea shoots'],
#  'Seafood Sauce': ['reserved seafood sauce'],
#  'Glass Noodles': ['dried glass noodles',
#   'Malony glass noodles',
#   'Korean glass noodles or cellophane noodles',
#   'dry Korean Glass Noodles  Dangmyeon  doesnt have to be exact'],
#  'Buns': ['burger buns',
#   'New England style splittop hot dog buns',
#   'hot dog buns',
#   'Soft Buns',
#   'brioche buns or burger buns',
#   'Portuguese bread rolls'],
#  'Soy Sauce': ['seasoned soy sauce for seafood',
#   'Guk ganjang Soup Soy Sauce',
#   'mushroom soy sauce',
#   'guk ganjang Korean soup soy sauce',
#   'Guk Ganjang Korean Soup Soy Sauce',
#   'Jin Ganjang  Regular Soy Sauce Regular like Kikkoman or Sempio',
#   'soup soy sauce',
#   'Korean Soy Sauce',
#   'Korean Soup Soy Sauce',
#   'Guk Kanjang',
#   'regular soy sauce',
#   'and  tablespoons light soy sauce',
#   'black soy sauce',
#   'Jin Ganjang',
#   'Korean soy sauce',
#   'Light soy sauce',
#   'homemade sweet soy sauce',
#   'Homemade Shiso Garlic Soy Sauce',
#   'dark soy sauce',
#   'Korean soy sauce for Soup',
#   'soy sauce',
#   'guk ganjang',
#   'dark soy soy',
#   'soy sauce Jin Ganjang',
#   'Guk Ganjang Korean soup soy sacue',
#   'Apple Lemon Soy Sauce',
#   'ponzu or soy sauce',
#   'soy sauce jin ganjang',
#   'jin kanjang',
#   'Kikkoman soy sauce',
#   'usukuchi lightcolored soy sauce',
#   'light soy sauce',
#   'Korean soy sauce for soup',
#   'Deonjang',
#   'Guk Ganjang Soup soy sauce',
#   'Doenjang Korean Soy Bean Paste',
#   'Korean soup soy sauce',
#   'Soy sauce',
#   'dark soy',
#   'glutenfree soy sauce',
#   'Homemade Smoked Soy Sauce',
#   'Korean soup soy sauce guk ganjang',
#   'Dark soy sauce',
#   'shoyu soy sauce',
#   'Guk Ganjang',
#   'soy sauce or to taste',
#   'Soy Sauce',
#   'Korean gook kanjang',
#   'jin ganjang',
#   'soy dipping sauce',
#   'dashi soy sauce',
#   'low sodium soy sauce',
#   'light soy sauce or soy sauce',
#   'soy sauce or tamari',
#   'Guk Ganjang  Korean soup soy sacue',
#   'homemade flavored sweet soy sauce',
#   'chosun or gook kanjang',
#   'or tamari for glutenfree'],
#  'Eggs': ['large or extra large Pete and Gerrys Organic Eggs',
#   'boiled and shelled eggs',
#   'chicken eggs',
#   'Poached or boiled eggs',
#   'hard boiled eggs',
#   'eggs',
#   'fried eggs',
#   'optional  eggs',
#   'Ramen Eggs Ajitsuke Tamago',
#   'large eggs',
#   'Fried eggs',
#   'eggs for topping',
#   'large Pete and Gerrys Organic Eggs',
#   'Tamagoyaki Japanese Rolled Omelette',
#   'large eggs  g each wo shell',
#   'big eggs',
#   'Carrot and eggs',
#   'quail eggs',
#   'soft or hardboiled eggs',
#   'Salted Duck Eggs',
#   'eggs to fry on top',
#   'Tamagoyaki Easy Version',
#   'Pete  Gerrys large eggs',
#   'Boiled or fried eggs',
#   'hardboiled eggs',
#   'Pete and Gerrys Organic Eggs',
#   'Pete  Gerrys eggs',
#   'Soft boiled',
#   'fried egg',
#   'half to one dozen fresh eggs',
#   'Fried egg',
#   'beaten egg',
#   'large egg  g each wo shell',
#   'Pete and Gerrys Organic Egg',
#   'hardboiled egg',
#   'Homemade soy sauce egg',
#   'softboiled egg',
#   'large egg',
#   'egg',
#   'Tobiko eggs',
#   'duck egg',
#   'Ramen Egg Ajitsuke Tamago',
#   'onsen tamago',
#   'kinshi tamago shredded egg crepe',
#   'soft or hardboiled egg',
#   'century eggs',
#   'large yolks',
#   'cooked salted duck egg yolks',
#   'large egg yolk',
#   'Raw egg yolks',
#   'egg yolks',
#   'salted duck egg yolks',
#   'salty duck egg yolks',
#   'large egg yolks',
#   'Pete and Gerrys Organic Egg yolks',
#   'salted duck yolks',
#   'large egg whites',
#   'egg whites',
#   'large egg white',
#   'egg white',
#   'masago eggs'],
#  'Poha': ['thick poha'],
#  'Cheese': ['pepper jack cheese',
#   'Mexicanstyle shredded cheese',
#   'Parmesan cheese',
#   'cheese',
#   'shredded cheese',
#   'mozzarella cheese',
#   'provolone cheese',
#   'burrata cheese',
#   'Cheese',
#   'shredded cheddar and mozzarella cheese',
#   'Gruyere cheese',
#   'Mozzarella cheese',
#   'Romano cheese',
#   'shredded sharp cheddar cheese',
#   'cheddar cheese',
#   'shredded mozzarella cheese'],
#  'Asafoetida': ['hing asafetida',
#   'asafetida',
#   'asafetida powder',
#   'hing',
#   'asafetida hing',
#   'asafetida '],
#  'Flour': ['whole wheat flour',
#   'crispy flour mix',
#   'Wheat Flour',
#   'lowgluten flour',
#   'fine gram flour',
#   'wheat flour',
#   'handwa flour',
#   'flour for dusting',
#   'gluten free flour',
#   'Gluten Free flour or regular flour',
#   'almond flour',
#   'allpurpose flour',
#   'Sorghum flour',
#   'allpurpose flour plain flour',
#   'flour allpurpose',
#   'almond  flour',
#   ' ounces allpurpose flour',
#   'crispy flour',
#   'medium protein flour or pastry flour',
#   'flour',
#   'bread flour',
#   'handvo flour',
#   'AP flour',
#   'whole wheat flour for rolling parathas',
#   'glutenfree flour',
#   ' ounces allpurpose flour see conversion to cups',
#   'all purpose flour',
#   'dangoko Japanese rice dumpling flour',
#   'regular flour',
#   'maida allpurpose flour',
#   'maidaall purpose flour',
#   '  ounces allpurpose flour',
#   'almond meal',
#   'cake flour',
#   'gram flourbesan',
#   ' oz gram flour sifted',
#   'oz besan gram flour  sifted',
#   'besan',
#   'gram flour',
#   'Besan',
#   'fine besan  gram flour',
#   ' oz besan gram flour  sifted',
#   'oats flour'],
#  'Steak': ['beef ribeye steak',
#   'ribeye steak',
#   'sirloin flap steak',
#   'thick  cm steak',
#   'tenderloin steak',
#   'strip or ribeye steak',
#   'flank steak or skirt steak',
#   'boneless flank steak',
#   'beef flank steak or skirt steak',
#   'flank steak'],
#  'Salt': ['Salt',
#   'sea salt for sprinkling between cabbage leaves',
#   'Sea salt and black pepper to taste',
#   'Sea salt to taste',
#   'salt flower',
#   'sea salt for radish',
#   'sea salt flakes',
#   'Korean Cheonilyeom Sea salt',
#   'coarse sea salt',
#   'kosher salt and black pepper',
#   'Salt to taste',
#   'Diamond Crystal kosher salt',
#   'black salt',
#   'Kosher salt',
#   'kosher',
#   'Korean cheonilyeom salt crystals',
#   'and  teaspoons salt',
#   'Salt and Pepper',
#   'Salt and pepper',
#   'of salt',
#   'sea salt for pickling',
#   'Salt and black pepper to taste',
#   'Sea Salt Trader Joes',
#   'sea salt',
#   'black salt or regular salt',
#   'Kosher Salt',
#   'garlic salt with dried parsley',
#   'pinch of salt',
#   'kosher Salt',
#   'salt',
#   'Himalayan pink salt',
#   'salt or to taste',
#   'salt to taste',
#   'Pinch of salt',
#   'Sea salt',
#   'sea salt and freshly ground black pepper',
#   'fine sea salt',
#   'flake sea salt',
#   'sea salt trader joes',
#   'Korean sea salt cheonilyeom',
#   'fine kosher salt',
#   'fine salt',
#   'sea salt or more to taste',
#   'salt and white pepper',
#   'good quality sea salt or kosher salt',
#   'kosher salt',
#   'Korean sea salt',
#   'sea salt for brine',
#   'salt and vegetable oil',
#   'salt and pepper',
#   'Salt  pepper',
#   'salt  pepper to taste'],
#  'Noodles': ['ramen noodles',
#   'dried alkaline noodles',
#   'instant noodles',
#   'fresh Hong Kong pan fried noodles',
#   'homemade handpulled noodles',
#   'Handpulled noodles or other fresh noodles',
#   'dried egg noodles',
#   'hiyashi chuka noodles',
#   'mung bean vermicelli noodles',
#   'dried rice noodles',
#   'Korean sweet potato glass noodles dangmyeon',
#   'thin noodles somyeon ',
#   'dried noodles',
#   'Instant noodles',
#   'fresh ramen noodles',
#   'fresh noodles',
#   'fresh lo mein noodles',
#   'servings noodles',
#   'fresh potato noodles',
#   'fresh Alkaline noodle',
#   'glass noodles',
#   'fresh chow mein noodles',
#   'thin wheat noodles',
#   'yellow noodles',
#   'udon noodles',
#   'fresh sweet potato noodles',
#   'Dan Dan noodles',
#   'Packaged dried noodles',
#   'packages instant mama noodles',
#   'dan dan noodles',
#   'dried noodles of your choice',
#   'Hong Kong style pan fried noodles',
#   'fresh Lanzhou noodles',
#   'yakisoba noodles',
#   'potato noodles',
#   'dried glasscellophane noodles harusame',
#   'deepfried crispy noodles',
#   'shirataki noodles',
#   'dried mung bean vermicelli noodles',
#   'egg noodles',
#   'thin egg noodles',
#   'noodles',
#   'fresh Hong Kong pan fry noodles',
#   'dried wheat noodles',
#   'dried thin wheat noodles or somen noodles',
#   'dried soba noodles buckwheat noodles',
#   'fresh Hong Kong Pan Fried Noodles',
#   'thin Chinese wheat noodles',
#   'fresh flat rice noodles',
#   'chow mein noodles',
#   'wheat noodles or rice noodles for glutenfree',
#   'fresh wheat noodles',
#   'dried knife shaved noodles',
#   'lo mein noodles',
#   'hoto noodles uncooked',
#   'fresh alkaline noodles',
#   'dried sweet potato noodles',
#   'fresh wheat noodles or  oz   g dried noodles',
#   'Cooked noodles for noodle soup',
#   'packages of instant noodles',
#   'cooked Japchae noodles',
#   'champon noodles',
#   'dried somen noodles',
#   'mediumthick fresh wheat noodles',
#   'dry vermicelli noodles',
#   'Rice noodles',
#   'Okinawa soba noodles',
#   'wheat noodles',
#   'fresh thin wheat noodles',
#   'instant ramen',
#   'package of instant ramen noodles',
#   'instant ramen noodles',
#   'rice noodles',
#   'dry rice noodles',
#   'dried wide rice noodles',
#   'fresh thick rice noodles',
#   'dried thin rice vermicelli noodles',
#   'wide dried rice noodles',
#   'handfuls of rice noodles',
#   'fresh wide rice noodles',
#   'Boiled soba noodles',
#   'somen noodles bundles',
#   'somen noodles  bundles',
#   'udon noodles total oz   g',
#   'thin vermicelli',
#   'dry thin rice vermicelli',
#   'fresh rice vermicelli',
#   'vermicelli',
#   'rice vermicelli',
#   'dried rice vermicelli',
#   'mung bean vermicelli',
#   'thin seviyanvermicelli',
#   'Hong Kong style wonton noodles',
#   'frozen udon',
#   'crunchy chow mein noodles',
#   'Shirataki noodles konnyaku',
#   'mung bean noodles'],
#  'Grapefruit': ['grapefruit', ' grapefruit'],
#  'Cream Cheese': ['blueberry cream cheese', 'cream cheese'],
#  'Pear': ['Asian Pear',
#   'Asian pear',
#   'Asian pears',
#   'Asian Korean Pear',
#   'pear puree'],
#  'Scallops': ['baby scallops',
#   'bay scallops andor chopped clams',
#   'sushigrade scallops',
#   'dried scallops',
#   'sea scallops',
#   'sashimigrade scallop',
#   'boiled baby scallop',
#   'bay scallops',
#   'Scallops',
#   'dried scallop'],
#  'Ice Cream': ['vanilla andor strawberry ice cream',
#   'scoops vanilla ice cream',
#   'ice cream of your choice',
#   'chocolate or vanilla ice cream',
#   'vanilla ice cream'],
#  'Agar Agar': ['agaragar powder',
#   'powdered agar agar',
#   'agar agar powder',
#   'kanten agar powder'],
#  'Dates': ['jujube dates',
#   'dried jujube dates Daechu',
#   'dried dates',
#   'pitted dates',
#   'dried jujube dates',
#   'jujubes',
#   'dried Chinese jujubes',
#   'dried jujubes'],
#  'Peppercorns': ['freshly ground Sichuan peppercorn powder',
#   'whole black peppercorns',
#   'peppercorns',
#   'fresh peppercorns',
#   'whole peppercorns',
#   'whole Sichuan peppercorns',
#   'stalks of fresh green peppercorns'],
#  'Shrimp Paste': ['shrimp paste',
#   'minced saewoojeot',
#   'fermented salted shrimp',
#   'fermented shrimp',
#   'saewoojeot'],
#  'Rice Paper': ['rice papers',
#   'package of Vietnamese rice paper',
#   'Round rice paper wrappers',
#   'rice paper wrappers'],
#  'Oysters': ['oysters', 'small shucked oysters'],
#  'Astragalus': ['astragalus'],
#  'Gochujang': ['Korean Gochujang',
#   'Gochujang Korean red chili paste',
#   'gook kanjang',
#   'gochujang Korean chili paste',
#   'korean red chili paste',
#   'Gochujang',
#   'gochujang',
#   'Korean red pepper bean paste',
#   'gochussi'],
#  'Toor Dal': ['toor dal'],
#  'Choy Sum': ['choy sum', 'heads choy sum', 'yu choy', 'Yu choy'],
#  'Anchovies': ['shirasu boiled salted baby anchovies',
#   'irikoniboshi boiled and dried anchovies',
#   'tazukuri dried anchovies',
#   'dried anchovies for soup',
#   'handful dried anchovies',
#   'handful of dried Korean anchovies',
#   'dried anchovies',
#   'small dried anchovies for stir fry',
#   'anchovy sauce myeolchi aekjeot',
#   'dried big anchovies for stock',
#   'dried anchovies for soups',
#   'dried soup anchovies'],
#  'Fish Sauce': ['fish sauce',
#   'fermented fish sauce',
#   'anchovy sauce fermented',
#   'Fermented Anchovy Sauce',
#   'anchovy sauce'],
#  'Cashews': ['coarsely chopped raw cashews',
#   'raw unsalted Cashews',
#   'chopped cashews',
#   'whole raw cashews',
#   'fried cashew nuts',
#   'raw unsalted cashews',
#   'cashews raw and unsalted',
#   'cashew nuts',
#   'raw cashews',
#   'cashews halved',
#   'roasted cashews',
#   'cashews',
#   'whole cashews',
#   'raw whole cashews',
#   'cashew',
#   'cashews broken into pieces',
#   'roasted unsalted cashews'],
#  'Paneer': ['cubed paneer', 'paneer'],
#  'Basil': ['thai basil',
#   'Thai basil leaves',
#   'packed Thai basil leaves',
#   'dried basil',
#   ' batch basil for garnish',
#   'lemon basil',
#   'Thai basil',
#   'Thai holy basil',
#   'cilantro or Thai basil leaves',
#   'sweet basil',
#   'bunch basil',
#   'basil leaves',
#   'Thai sweet basil',
#   'dry basil',
#   'basil'],
#  'Pumpkin': ['pumpkin',
#   'peeled pumpkin or winter squash',
#   'pumpkin puree',
#   'pumpkin seeds'],
#  'Mugwort': ['yomogi mugwort'],
#  'Butter': ['butter or ghee',
#   'unsalted butter',
#   'butter',
#   'Butter',
#   'clarified butter',
#   'ghee',
#   'melted butter or vegetable oil',
#   'chilled unsalted butter',
#   ' grams butter',
#   'unsalted butter room temperature',
#   'melted butter',
#   'salted butter',
#   'ghee or butter',
#   'butter andor chicken fat from the chicken',
#   'melted butter or  Tbsp veg oil',
#   'hot ghee'],
#  'Garlic': ['Garlic powder',
#   'granulated garlic',
#   'garlic cloves optional',
#   'large clove garlic',
#   'chopped garlic or  whole cloves',
#   'fresh garlic',
#   'finely grated garlic',
#   'fresh chopped garlic',
#   'garlic pressed',
#   'Garlic Paste',
#   'big cloves garlic',
#   'garlic chopped',
#   'garlic paste',
#   'Garlic',
#   'garlic',
#   'garlic clove',
#   'cloves of garlic',
#   'crushed garlic',
#   'head garlic',
#   'garlic minced',
#   'crispy fried garlic',
#   'garlic cloves peeled',
#   'garlic cloves',
#   'Minced garlic',
#   'head of garlic',
#   'of garlic',
#   'garlic grated',
#   'chopped garlic',
#   'garlic powder',
#   'large cloves garlic',
#   'whole head of garlic',
#   'garlic Powder',
#   'minced garlic',
#   'heads of garlic'],
#  'Pancetta': ['chopped pancetta'],
#  'Corn': ['small corn on the cob',
#   'ears corn on the cob',
#   'canned or frozen corn',
#   'baby corn',
#   'canned corn',
#   'corns on the cob',
#   'frozen corn',
#   'Corn on the cob',
#   'corn on the cob',
#   'corn',
#   'creamstyle sweet corn',
#   'sweet corn',
#   'whole kernel corn',
#   'frozen or canned corn',
#   'ear corn on the cob'],
#  'Lamb': ['pounds lamb spare ribs contains rack and bonein breast',
#   'Lamb with carrot and zucchini',
#   'lamb stew meat or lamb leg',
#   'ground lamb',
#   'ground lamb leg',
#   'Lamb or mutton shoulder leg or any well marbled cut',
#   'lamb meat',
#   'lamb',
#   'ground lamb meat',
#   'lamb spare ribs',
#   'lamb leg',
#   'lamb leg or ground lamb',
#   'whole lamb leg',
#   'lamb shanks',
#   ' pounds lamb spare ribs contains rack and bonein breast'],
#  'Garlic Oil': ['garlic oil'],
#  'Mustard': ['dry oriental mustard',
#   'oriental hot mustard',
#   'Golden Mustard',
#   'Pickled mustard tube',
#   'Pickled Chinese mustard tube',
#   'Japanese karashi hot mustard',
#   'wasabi or Chinese hot mustard',
#   'Mustard',
#   'Dijon mustard',
#   'Japanese Karashi hot mustard'],
#  'Bean Liquid': ['cooking liquid from beans'],
#  'Peas': ['frozen green peas',
#   'frozen peas',
#   'Frozen peas',
#   'dry yellow peas white Vatana',
#   'Green peas and chopped cherry tomatoes'],
#  'Chives': ['Chinese yellow chives',
#   'garlic chives',
#   'chinese chives chopped',
#   'Korean or Chinese chives  makes about  cups',
#   'chives',
#   'chinese chives',
#   'chives or parsley',
#   'stalks garlic chives',
#   'Chinese chives',
#   'stalks Chinese chives',
#   'garlic chive',
#   'garlic chives Chinese chives or Nira',
#   'garlic chives korean buchu',
#   'garlic chives Chinese chives or nira'],
#  'Sev': ['thin sev',
#   'sev or bhujia',
#   'fine sev',
#   'sev farsan',
# ...
#  'Agave Syrup': ['agave syrup'],
#  'Honey': ['hot honey', 'honey', 'swirl of honey'],
#  'Paprika': ['paprika',
#   'smoked paprika powder',
#   'smoked paprika',
#   'cayenne powder',
#   'cayenne',
#   'cayenne pepper'],
#  'Oyster Sauce': ['oyster sauce',
#   'Oyster Sauce',
#   'Lee Kum Kee Premium Oyster Sauce',
#   'vegetarian oyster sauce'],
#  'Barley': ['mochi mugi barley', 'barley'],
#  'Fish Balls': ['meatballs  fish balls', 'Fish balls', 'fish balls'],
#  'Figs': ['dried figs'],
#  'Takoyaki Sauce': ['takoyaki sauce'],
#  'Bhel': ['bhel mix'],
#  'Dumplings': ['packaged frozen dumpling wrappers',
#   'frozen Korean dumplings mandu',
#   'Frozen dumplings'],
#  'Spice Blend': ['chat masala',
#   'gochu yangnyeom for sundubu jjigae',
#   'coriander and cumin powder',
#   'Garam Masala',
#   'shichimi togarashi Japanese seven spice',
#   'package of Thai soup spice set',
#   'spice powder'],
#  'Spring Roll Wrappers': ['package of spring roll wrappers',
#   'spring roll wrappers',
#   'pack spring roll wrappers'],
#  'Almond Milk': ['unsweetened almond milk', 'almond milk'],
#  'Quinoa': ['white organic quinoa', 'uncooked white quinoa', 'quinoa'],
#  'Pickled Ginger': ['pickled red ginger beni shoga or kizami beni shoga'],
#  'Avocado': ['avocados', 'Avocado', 'avocado'],
#  'Food Colouring': ['food coloring',
#   'red food coloring',
#   'drops red food coloring'],
#  'Ajwain': ['ajwain seeds', 'ajwain carom seeds', 'ajwain'],
#  'Masoor Dal': ['masoor dal'],
#  'Parsley': ['parsley',
#   'Optional Chopped fresh or dried parsley to garnish',
#   'mitsuba Japanese parsley',
#   'Italian parsley'],
#  'Corn Flakes': ['cornflakes'],
#  'Mangoes': ['ripe mangoes',
#   'mangos',
#   'raw mangoes',
#   'mango',
#   'ripe mango',
#   'mango peeled and diced',
#   'big mangoes',
#   'Alphonso or Kesar mango canned pulp',
#   'Mango pulp',
#   'ataulfo mangoes',
#   'fresh mango',
#   'diced mango'],
#  'Blood': ['cooked chicken blood', 'pork blood'],
#  'Chicken Nanban': ['chicken nanban'],
#  'Pickles': ['Chinese pickles or fermented tofu',
#   'Pickled vegetables',
#   'pickles',
#   'sweet gherkins',
#   'pickle',
#   'cornichons or gherkins'],
#  'Gravy': ['Gravy'],
#  'Duck Egg': ['duck eggs'],
#  'Thai Basil': ['Handful Thai basil leaves'],
#  'Minari': ['minari water dropwart',
#   'minari',
#   'minari or water dropwort or water cress'],
#  'Natto': ['natto fermented soybean'],
#  'Soybean Powder': ['roasted soybean powder'],
#  'Nutella': ['Nutella'],
#  'Kelp Broth': ['kelp broth'],
#  'Beetroot': ['small beetroot', 'medium beet', 'small beet'],
#  'Shrimp Fritters': ['ebi fry'],
#  'Teriyaki Sauce': ['Homemade Teriyaki Sauce'],
#  'Pickle Masala': ['pickle masala'],
#  'Kombucha': ['kobucha kombucha'],
#  'Rice Syrup': ['rice syrup Jocheong',
#   'rice syrup jocheong ',
#   'rice malt syrup'],
#  'Bamboo Leaves': ['bamboo leaves',
#   'sheets dried or fresh bamboo leaves',
#   'dried bamboo leaves'],
#  'Wonton': ['wontons'],
#  'Leeks': ['leek', 'leeks', 'Daepa Korean Leek'],
#  'Shrimp Juice': ['juice from cooking shrimp'],
#  'Salad Greens': ['mixed green salad to serve with',
#   'salad mix',
#   'leafy green vegetables'],
#  'Ramen': ['Instant ramen'],
#  'Pigeon Peas': ['dried split yellow pigeon peas'],
#  'Swiss Chard': ['bunch swiss chard', 'large swiss chard'],
#  'Kumquat': ['kumquats'],
#  'Sea Bream': ['cooked sea bream bone and head',
#   'sashimigrade sea bream tai',
#   'sea bream meat',
#   'red sea bream'],
#  'Bay Leaves': ['bay leaves', 'bay leave', 'bay leaf', 'Indian bay leaf'],
#  'Naan': ['mini naan'],
#  'Sprite': ['sprite or Korean cider'],
#  'Tofu Skin': ['yuba Japanesestyle soft tofu skin',
#   'Yuba sheet',
#   'fresh yuba sheets or  semidried yuba sheet'],
#  'Kiwi': ['kiwis', 'kiwi'],
#  'Seasoning Powder': ['RosDee seasoning powder',
#   'furikake rice seasoning',
#   'Chuka Dashi Chinese seasoning',
#   'Furikake rice seasoning',
#   'misugaru',
#   'Seasoning packages from your instant ramen',
#   'taco seasoning'],
#  'Sprinkles': ['sprinkles of your choice'],
#  'Fruit': ['fruits of your choice', 'mixed fruits'],
#  'Shallots': ['fried shallots',
#   'shallot',
#   'small shallots',
#   'Fried shallot for garnish',
#   'shallots',
#   'Fried shallots for garnish',
#   'Shallot'],
#  'Oxtail': ['oxtails', 'oxtail'],
#  'Potato Salad': ['Japanese potato salad'],
#  'Kanpyo': ['dried kanpyo gourd strips'],
#  'Tomato Ketchup': ['tomato ketchup', 'ketchup'],
#  'Fennel Seeds': ['fennel seeds', 'fennel seed'],
#  'Garam Masala': ['moms garam masala',
#   'Garam masala powder',
#   'garam masala powder',
#   'garam Masala',
#   'Moms Garam Masala',
#   'garam masala'],
#  'Liver': ['liver', 'chicken liver', 'pork liver'],
#  'Croquettes': ['baked croquettes', 'korokke Japanese croquette'],
#  'Sage': ['sage'],
#  'Citric Acid': ['citric acid powder'],
#  'Duck Pancakes': ['Homemade duck pancakes',
#   'Moo shu pancakes',
#   'homemade Beijing duck pancakes'],
#  'Paratha': ['Kawan parathas',
#   'Kawan Parathas',
#   'frozen Kawan parathas',
#   'frozen Kawan Parathas',
#   'kawan parathas '],
#  'Soy Flour': ['kinako roasted soybean flour'],
#  'Sour Cream': ['sour cream'],
#  'Chocolate Syrup': ['chocolate syrup'],
#  'Tapioca Starch': ['tapioca flour', 'tapioca starch'],
#  'Buckwheat Sprouts': ['handful buckwheat sprouts'],
#  'Oregano': ['dried oregano'],
#  'Tobiko': ['yuzuflavored tobiko flying fish roe', 'tobiko flying fish roe'],
#  'Barbecue Sauce': ['Homemade Chinese Barbecue Sauce'],
#  'Perilla Leaves': ['perilla leaves',
#   'Perilla leaves',
#   'perilla leaves sliced'],
#  'Thyme': ['fresh thyme', 'thyme', 'dried thyme'],
#  'Tamarind Sauce': ['tamarind sauce',
#   'tamarind puree',
#   'tamarind pulp',
#   'fresh tamarind',
#   'tamarind paste',
#   'Tamarind Chutney',
#   'tamarind chutney'],
#  'Peaches': ['peaches'],
#  'Wonton Wrapper': ['wonton wrapper or mandupi ',
#   'Wonton Wrappers',
#   'wonton wrappers',
#   'fried wonton wrappers',
#   'Fried wonton wrapper',
#   'package of wonton wrappers',
#   'pack super thin wonton wrappers'],
#  'Pickled Leaves': ['saltpickled cherry blossom leaves'],
#  'Condensed Milk': ['fullfat condensed milk', 'sweetened condensed milk'],
#  'Hoisin Sauce': ['Hoisin sauce', 'hoisin sauce', 'Homemade hoisin sauce'],
#  'Butterfly Pea Flower': ['butterfly pea'],
#  'Lima Beans': ['dried lima beans'],
#  'Perilla Oil': ['perilla oil'],
#  'Yellowtail': ['yellowtail hamachi buri',
#   'sashimigrade yellowtail hamachi',
#   'sashimigrade yellowtail',
#   'hamachi kama yellowtail collar'],
#  'Puff Pastry': ['frozen puff pastry', 'pack frozen puff pastry sheets'],
#  'Nigella Seeds': ['nigella seeds or onions seeds'],
#  'Flowers': ['butterfly pea flowers',
#   'bunch of your favorite edible flowers',
#   'A small handful of dried lily flowers yields  cup after rehydration',
#   'dried lily flower buds',
#   'handful dried lily flowers',
#   'handfuls dried lily flowers',
#   'Fresh edible flowers or leaves',
#   ' kinds of herbsgreens of your choice',
#   'loosely packed dried lily bulbs'],
#  'Yard Long Beans': ['stink beans', 'yard long beans'],
#  'Pan Drippings': ['pan drippings'],
#  'Rose Essence': ['rose essence', 'rose syrup'],
#  'Beets': ['small beets', 'beets'],
#  'Abalone': ['baby abalone', 'abalone'],
#  'Baking Powder': ['baking powder'],
#  'Yam': ['dried Chinese wild yam',
#   'diced violet Indian yam',
#   'Chinese wild yam',
#   'nagaimoyamaimo mountain yam'],
#  'Lemongrass': ['lemongrass',
#   'lemongrass stalks',
#   'lemon grass',
#   'stalks of lemongrass'],
#  'Sesame Paste': ['Chinese sesame paste',
#   'Japanese sesame paste neri goma',
#   'black sesame paste'],
#  'Fish Flakes': ['sakura denbu seasoned cod fish flakes'],
#  'Fried Tofu Pouch': ['Inari age seasoned fried tofu pouch'],
#  'Ponzu': ['ponzu', 'marinade sauce', 'Ponzu'],
#  'Rice Powder': ['toasted rice powder', 'tteok rice powder'],
#  'Dried Fruit': ['dried fruit mix'],
#  'Onions': ['bag of red pearl onions',
#   'pickled onions',
#   'medium yellow onion',
#   'sliced yellow onion',
#   'Chopped green onions for garnish',
#   'yellow onion with skin on if possible',
#   'shallots or  onion',
#   'big onion',
#   'Onion',
#   'purple onion',
#   'medium size onion',
#   'small onion',
#   'red onion',
#   'whole onion',
#   'large onion',
#   'green onion',
#   'Shiraga Negi julienned long green onions',
#   'shallots or  small onion',
#   'minced onion',
#   'yellow onion with skin on',
#   'mediumsized yellow onion',
#   'small red onion finely diced',
#   'large red onion',
#   'scallions',
#   'yellow onion sliced',
#   'Green onion',
#   'chopped green onion for garnish',
#   'large yellow onion',
#   'white onion',
#   'medium onion chopped fine',
#   'onion powder',
#   'sliced onion',
#   'green onion white part',
#   'yellow onions',
#   'sweet onion',
#   'red onions',
#   'large purple onion',
#   'large white onion',
#   'medium onion finely diced',
#   'medium onion',
#   'small red onion',
#   'small yellow onion',
#   'Sliced green onions',
#   'medium yellow onions',
#   'onion',
#   'chopped white onions',
#   'yellow onion',
#   'small white onion',
#   'large onions',
#   'white onions',
#   'onions',
#   'medium red onion',
#   'long green onion'],
#  'Gluten Balls': ['fried gluten balls'],
#  'Pickled Pepper': ['Sichuan pickled pepper pao jiao or Cajun pickled pepper',
#   'Chinese pickled peppers'],
#  'Ricotta Cheese': ['ricotta cheese',
#   'full fat ricotta cheese',
#   'fullfat ricotta cheese'],
#  'Chicken Katsu': ['baked chicken katsu',
#   'your choice of katsu cutlet',
#   'the leftover Japanese curry of your choice',
#   'Japanese curry roux',
#   'your choice of Japanese curry',
#   'Japanese curry of your choice'],
#  'Shiso Leaves': ['shiso leaves',
#   'red shiso leaves perilla',
#   'shiso leaves perillaooba'],
#  'Sea Bass': ['whole sea bass', 'MSCcertified Chilean sea bass'],
#  'Cornmeal': ['cornmeal'],
#  'Okonomiyaki Sauce': ['okonomiyaki sauce'],
#  'Red Beans': ['canned sweet red beans or sweet red bean paste',
#   'dry red beans',
#   'sweet red beans',
#   'dried red beans'],
#  'Kanom Jeen': ['kanom jeen'],
#  'Banana Leaves': ['large banana leaves'],
#  'Kale': ['curly green or purple kale', 'kale'],
#  'Curry Sauce': ['Korean Curry Sauce Mix'],
#  'Grass Jelly': ['grass jelly'],
#  'Lobster Tails': ['lobster tails with shell'],
#  'Hoba Leaves': ['dried hoba leaves'],
#  'Demiglace Sauce': ['Homemade DemiGlace Sauce'],
#  'Chinese Olive Vegetables': ['heaping tablespoons Chinese olive vegetables'],
#  'Orange Zest': ['orange zest',
#   'loosely packed orange zest',
#   'mandarin orange peel'],
#  'Plums': ['plums',
#   'pickled plums ko ume',
#   'umeboshi Japanese pickled plum',
#   'ume from ume miso',
#   'umeboshi Japanese pickled plums',
#   'ume plums'],
#  'Coconut Oil': ['coconut oil'],
#  'Fingerroot': ['fingerroot', 'finger root', 'fingerroots'],
#  'Chili Pepper Flakes': ['chili pepper flakes',
#   'red pepper flakes',
#   'gochugaru Korean pepper flakes',
#   'red pepper seeds or red pepper flakes',
#   'dash of red pepper powder',
#   'Korean red chili pepper',
#   'red chili pepper flakes',
#   'Chinese red pepper flakes',
#   'crushed red pepper red pepper flakes',
#   'chili flakes',
#   'Korean hot pepper flakes',
#   'thai chili flakes',
#   'red chili flakes',
#   'Sichuan chili flakes',
#   'dried chili flakes',
#   'Thai chili flakes',
#   'Chinese chili flakes',
#   'dried Kashmiri red chillies'],
#  'Mussels': ['mussel meat', 'mussels'],
#  'Apple Juice': ['apple juice'],
#  'Prik Nam Som': ['prik nam som'],
#  'Pickled Radish': ['Chinese pickled radish',
#   'danmuji Korean pickled radish',
#   'takuan pickled daikon radish'],
#  'Clams': ['Manila clams',
#   'giant little neck clams',
#   'manila clams',
#   'cooked surf clam hokkigai'],
#  'Seasoning Sauce': ['golden mountain seasoning sauce',
#   'a few drops of Maggi seasoning sauce',
#   'Maggi seasoning sauce'],
#  'Chana Dal': ['chana dal'],
#  'Dabeli Masala': ['dabeli masala'],
#  'Brownies': ['brownies'],
#  'Egg Roll Wrappers': ['egg roll wrappers', 'egg roll harumaki wrappers'],
#  'Wheat Gluten': ['fu wheat gluten', 'Temari Fu wheat gluten'],
#  'Moth Beans': ['sprouted moth beans'],
#  'Cooking Wine': ['Chinese cooking wine',
#   'marsala wine',
#   'red wine',
#   'rice cooking wine or red wine',
#   'shaoxing wine',
#   ' tablespoon Shaoxing wine',
#   'Shaoxing wine',
#   'Shaoxing Chinese wine',
#   'mirin or white wine',
#   'Shaoxing Wine',
#   'white wine',
#   'wine',
#   'dry sherry',
#   'dry white wine',
#   'Shaoxing wine or dry sherry or chicken stock',
#   'rice wine or white wine',
#   'mirin or sake',
#   'mirin or cooking sake',
#   'cooking sake rice wine or mirin',
#   'rice wine or mirin',
#   'rice cooking wine',
#   'mirin'],
#  'Oats': ['rolled oats', 'Bobs Red Mill Quick Cooking Rolled Oats'],
#  'Soy Milk': ['soy milk', 'unsweetened soy milk'],
#  'Wasabi': ['wasabi'],
#  'Tempura Flour': ['Korean Tempura Mix', 'tempura flour'],
#  'Morning Glory': ['morning glory'],
#  'Mung Dal': ['mung dal'],
#  'Brisket': ['brisket', 'beef brisket'],
#  'Galangal': ['galangal'],
#  'Curry Leaves': ['fresh curry leaves', 'curry leaves'],
#  'Gold Leaf': ['edible gold leaf flakes'],
#  'Bonito Flakes': ['katsuobushi dried bonito flakes'],
#  'Pickled Vegetables': ['fukujinzuke Japanese red pickled vegetables'],
#  'Tempura': ['vegetable tempura', 'tenkasuagedama tempura scraps'],
#  'Cloves': ['cloves', 'whole cloves'],
#  'Arugula': ['arugula'],
#  'Jackfruit': ['jackfruit'],
#  'Dried Sardine': ['chirimen jako dried baby sardine'],
#  'Persimmons': ['dried persimmons'],
#  'Yeotkireum': ['yeotkireum'],
#  'Oranges': ['oranges',
#   'mandarin orange',
#   'mandarin oranges',
#   'freshly squeezed mandarin orange juice'],
#  'Nutty Sauce': ['Homemade nutty sauce'],
#  'Almond Extract': ['almond extract'],
#  'Molasses': ['molasses'],
#  'Rose Water': ['rose water'],
#  'Poppy Seeds': ['white poppy seeds', 'poppy seeds'],
#  'Radish Sprouts': ['kaiware daikon radish sprouts',
#   'handful of Daikon Sprouts'],
#  'Coconut Water': ['coconut water'],
#  'Beef Chuck Roast': ['beef chuck roast  to  lbs   to  kg'],
#  'Plum Sauce': ['plum sauce', 'ume plum compote'],
#  'Puri': ['Puri'],
#  'Sea Urchin': ['uni sea urchin'],
#  'Egg Noodles': ['fresh egg noodles'],
#  'Baguette': ['French baguette'],
#  'Bulgogi': ['marinated bulgogi'],
#  'Kinome': ['kinome leaves'],
#  'MSG': ['MSG'],
#  'Jam': ['apricot jam'],
#  'Ribs': ['spare ribs', 'baby back ribs', 'thinly sliced short rib'],
#  'Matcha Powder': ['Matcha',
#   'matcha green tea powder',
#   'matcha powder',
#   'matcha tea powder',
#   'matcha'],
#  'Broccoli Rabe': ['stalks broccoli rabe'],
#  'Lemons': ['Lemon wedges',
#   'lemon or lime wedges',
#   'lemon slices',
#   'lemon wedges',
#   'Meyer lemon',
#   'lemon',
#   'Meyer lemons',
#   'lemons juiced',
#   'meyer lemon juice',
#   'fresh lemon juice',
#   'lemon juice',
#   'lemon zest',
#   'citrus fruits'],
#  'Curry Powder': ['Japanese curry powder', 'yellow curry powder'],
#  'Crab Salad': ['Japanese kani salad'],
#  'Sambar Powder': ['sambar powder'],
#  'Sago': ['sago pearls'],
#  'Calamari': ['calamari'],
#  'Five Spice': ['five spice',
#   'Chinese five spice powder',
#   'fivespice powder',
#   'five spice powder',
#   'set of Chinese fivespice set'],
#  'Soup': ['soup'],
#  'Shio Koji': ['shio koji'],
#  'Beef Bowl': ['gyudon'],
#  'Acorn Powder': ['dried acorn powder dotorimuk garu'],
#  'Beef Short Ribs': ['boneless beef short ribs'],
#  'Noodle Soup Base': ['mentsuyu concentrated noodle soup base',
#   'spicy Sichuan hot pot base  cup  g'],
#  'Konjac': ['konnyaku konjac'],
#  'Sesame Sauce': ['Beijingstyle sesame dipping sauce'],
#  'Phyllo Dough': ['phyllo shells'],
#  'Tonkatsu': ['tonkatsu', 'tonkatsu sauce'],
#  'Stew Mix': ['Japanese Cream Stew Mix'],
#  'Tartar Sauce': ['Homemade Tartar Sauce'],
#  'Sichuan Peppercorn Oil': ['green Sichuan peppercorn oil'],
#  'Garlic Juice': ['pickled garlic juice'],
#  'Coriander Powder': ['coriander powder'],
#  'Catfish': ['catfish filets'],
#  'Cherries': ['cherries', 'maraschino cherries'],
#  'Watermelon Juice': ['watermelon juice'],
#  'Apricots': ['dried apricots'],
#  'Cream of Tartar': ['cream of tartar'],
#  'Orange Syrup': ['syrup from the mandarin oranges can'],
#  'Carom Seeds': ['carom seeds'],
#  'Yuzu': ['yuzu', 'yuzu juice extract', 'yuzu zest', 'yuzu peel'],
#  'Kashiwa Oak Leaves': ['saltpickled kashiwa oak leaves'],
#  'Omelette': ['Tamagoyaki Sweet Rolled Omelette',
#   'kinshi tamago shredded thin egg crepe'],
#  'Tom Yum Paste': ['tom yum paste'],
#  'Allspice': ['allspice'],
#  'Kanten Jelly': ['kanten jelly'],
#  'Black Eyed Peas': ['dry black eyed peas']}

# %% [markdown]
# ----

# %%
def clean_ingredients_in_string(ingredient):
    return re.sub(r"[^a-zA-Z\s]", "", ingredient).strip()


# Clean the entire ingredients list before processing
df_recipes["cleaned_ingredients"] = df_recipes["ingredients"].apply(
    lambda x: [clean_ingredients_in_string(ingredient) for ingredient in x.split(";")]
)


# Normalize ingredients based on the mapping dictionary
def normalize_ingredient(ingredient):
    for standard_name, variations in mapping_lists.items():
        if ingredient in [var for var in variations]:
            return standard_name
    return "NaN"  # Return NaN as some ingredients may have failed going through the LLM or the key changed and it cant be found


# Create a new column 'normalised_ingredients' based on the mapping
df_recipes["normalised_ingredients"] = df_recipes["cleaned_ingredients"].apply(
    lambda x: [normalize_ingredient(ingredient) for ingredient in x]
)

# %%
# Count the number of rows where 'NaN' is found in the 'normalised_ingredients' column
nan_count = df_recipes[
    df_recipes["normalised_ingredients"].apply(lambda x: "NaN" in str(x))
].shape[0]

print("Number of rows with a NaN value in the normalised ingredients list:", nan_count)
# Out:
# Number of rows with a NaN value in the normalised ingredients list: 290

# %%
# Filter rows where 'normalised_ingredients' does not contain 'NaN'
df_no_nan = df_recipes[
    df_recipes["normalised_ingredients"].apply(lambda x: "NaN" not in str(x))
].reset_index()

# %%
# Updated function to handle days, hours, and minutes (including plural forms)
def convert_to_minutes_extended(time_str):
    # Handle None or NaN values
    if not isinstance(time_str, str):
        return None  # Or 0, if you want to return 0 minutes for invalid entries

    time_str = time_str.lower()
    days = 0
    hours = 0
    minutes = 0

    # Extract days
    if "day" in time_str:
        days_match = re.search(r"(\d+)\s*day", time_str)
        if days_match:
            days = int(days_match.group(1))

    # Extract hours
    if "hour" in time_str:
        hours_match = re.search(r"(\d+)\s*hour", time_str)
        if hours_match:
            hours = int(hours_match.group(1))

    # Extract minutes
    if "minute" in time_str:
        minutes_match = re.search(r"(\d+)\s*minute", time_str)
        if minutes_match:
            minutes = int(minutes_match.group(1))

    # Convert to total minutes
    return days * 1440 + hours * 60 + minutes  # 1 day = 1440 minutes


# Apply the updated function to the total_time column
df_no_nan["total_time_minutes"] = df_no_nan["total_time"].apply(
    convert_to_minutes_extended
)

df_no_nan = df_no_nan.drop("image_data", axis=1)
df_no_nan = df_no_nan.drop("index", axis=1)
df_no_nan = df_no_nan.drop("cleaned_ingredients", axis=1)


df_no_nan
# Out:
#                                                title  \
# 0                     Japanese Milk Bread (Shokupan)
# 1                                     Chicken Chashu
# 2                   Gyudon (Japanese Beef Rice Bowl)
# 3                                Japanese Beef Curry
# 4                                Japanese Cheesecake
# ...                                              ...
# 1828                  Thai Vegetable Soup (Tom Jued)
# 1829  Tom Kha Gai Recipe (Thai Coconut Chicken Soup)
# 1830    Tom Yum Kung Recipe (Spicy Thai Shrimp Soup)
# 1831           Thai Chicken Glass Noodle Soup Recipe
# 1832             Tom Yum Pla (Thai Fish Soup Recipe)
#
#                                                    link  \
# 0     https://www.justonecookbook.com/japanese-milk-...
# 1       https://www.justonecookbook.com/chicken-chashu/
# 2               https://www.justonecookbook.com/gyudon/
# 3     https://www.justonecookbook.com/japanese-beef-...
# 4     https://www.justonecookbook.com/souffle-japane...
# ...                                                 ...
# 1828  https://hungryinthailand.com/thai-vegetable-so...
# 1829          https://hungryinthailand.com/tom-kha-gai/
# 1830         https://hungryinthailand.com/tom-yum-kung/
# 1831  https://hungryinthailand.com/thai-chicken-glas...
# 1832          https://hungryinthailand.com/tom-yum-pla/
#
#                                               image_url  \
# 0     https://www.justonecookbook.com/wp-content/upl...
# 1     https://www.justonecookbook.com/wp-content/upl...
# 2     https://www.justonecookbook.com/wp-content/upl...
# 3     https://www.justonecookbook.com/wp-content/upl...
# 4     https://www.justonecookbook.com/wp-content/upl...
# ...                                                 ...
# 1828  https://hungryinthailand.com/wp-content/upload...
# 1829  https://hungryinthailand.com/wp-content/upload...
# 1830  https://hungryinthailand.com/wp-content/upload...
# 1831  https://hungryinthailand.com/wp-content/upload...
# 1832  https://hungryinthailand.com/wp-content/upload...
#
#                                             description  total_time  \
# 0     Japanese Milk Bread is possibly the best versi...     3 hours
# 1     Juicy and tender Chicken Chashu is a lighter v...      1 hour
# 2     With thinly sliced beef and tender onions simm...  20 minutes
# 3     With tender chunks of beef, potatoes, carrots,...     3 hours
# 4     Jiggly and fluffy Japanese Cheesecake is a cro...      1 hour
# ...                                                 ...         ...
# 1828  Tom jued is a healthy Thai vegetable soup reci...  40 minutes
# 1829  Try this tom kha gai recipe—a healthy and quic...  20 minutes
# 1830  This tom yum kung recipe is an authentic Thai ...  25 minutes
# 1831  Enjoy a quick and easy Thai chicken glass nood...  30 minutes
# 1832  Tom yum pla is a healthy Thai fish soup recipe...  35 minutes
#
#                  course   cuisine  \
# 0             Breakfast  Japanese
# 1           Main Course  Japanese
# 2           Main Course  Japanese
# 3           Main Course  Japanese
# 4               Dessert  Japanese
# ...                 ...       ...
# 1828  Main Course, Soup      Thai
# 1829  Main Course, Soup      Thai
# 1830  Main Course, Soup      Thai
# 1831               Soup      Thai
# 1832  Main Course, Soup      Thai
#
#                                             ingredients   calories  \
# 0     warm water; sugar; Diamond Crystal kosher salt...  1645 kcal
# 1     boneless, skin-on chicken thighs; green onions...       None
# 2     onion; green onion/scallion; thinly sliced bee...   657 kcal
# 3     onions; unsalted butter; neutral oil; russet p...   426 kcal
# 4     unsalted butter; large eggs (50 g each w/o she...  3560 kcal
# ...                                                 ...        ...
# 1828  garlic; coriander root; black peppercorns; bou...    63 kcal
# 1829  water; coconut milk; lemongrass; galangal; kaf...   451 kcal
# 1830  shrimp; Asian mushrooms; lemongrass; shallots;...   198 kcal
# 1831  glass noodles; dried chilies; chilies; shallot...   644 kcal
# 1832  fish; water; lemongrass; galangal; garlic; sha...   309 kcal
#
#                                  normalised_ingredients  total_time_minutes
# 0     [Water, Sugar, Salt, Honey, Yeast, Flour, Milk...               180.0
# 1     [Chicken, Green Onions, Ginger, Oil, Water, Co...                60.0
# 2     [Onions, Green Onions, Beef, Stock, Sake, Cook...                20.0
# 3     [Onions, Butter, Oil, Potatoes, Carrots, Mushr...               180.0
# 4     [Butter, Eggs, Cream Cheese, Butter, Cream, Su...                60.0
# ...                                                 ...                 ...
# 1828  [Garlic, Coriander, Black Pepper, Stock, Oyste...                40.0
# 1829  [Water, Coconut Milk, Lemongrass, Galangal, Li...                20.0
# 1830  [Shrimps, Mushrooms, Lemongrass, Shallots, Lim...                25.0
# 1831  [Noodles, Chili Pepper, Chili Pepper, Shallots...                30.0
# 1832  [Fish, Water, Lemongrass, Galangal, Garlic, Sh...                35.0
#
# [1833 rows x 11 columns]

# %%
def count_unique_vals(df, column_name):
    # Flatten all words into a single list
    all_ingredients = [
        ingredient.strip()  # Strip any extra spaces from ingredients
        for ingredients in df[column_name]  # Iterate over the rows in the column
        for ingredient in ingredients  # Iterate over each ingredient in the list
        if ingredient is not None  # Skip None values
    ]

    # Count occurrences of each unique ingredient
    ingredient_counts = Counter(all_ingredients)

    return ingredient_counts

# %%
ingredient_count = dict(count_unique_vals(df_no_nan, "normalised_ingredients"))

names = ingredient_count.keys()

# Sort the dictionary by values in descending order
sorted_ingredient_counts = dict(
    sorted(ingredient_count.items(), key=lambda item: item[1], reverse=True)
)

# Display the sorted result
sorted_ingredient_counts
# Out:
# {'Salt': 1417,
#  'Soy Sauce': 1266,
#  'Sugar': 1261,
#  'Water': 916,
#  'Garlic': 797,
#  'Oil': 710,
#  'Ginger': 700,
#  'Cooking Wine': 687,
#  'Cornstarch': 613,
#  'Onions': 584,
#  'Green Onions': 519,
#  'Peanut Oil': 449,
#  'Eggs': 409,
#  'Sesame Oil': 365,
#  'Vinegar': 349,
#  'Black Pepper': 319,
#  'Flour': 315,
#  'Chicken': 306,
#  'Chili Pepper': 283,
#  'Sake': 278,
#  'Carrots': 271,
#  'Coriander': 263,
#  'Rice': 258,
#  'Sesame Seeds': 250,
#  'Stock': 247,
#  'Pork': 247,
#  'Mushrooms': 245,
#  'Oyster Sauce': 225,
#  'Butter': 223,
#  'White Pepper': 182,
#  'Tofu': 178,
#  'Broth': 172,
#  'Noodles': 172,
#  'Tomatoes': 134,
#  'Shrimps': 124,
#  'Fish Sauce': 117,
#  'Turmeric': 116,
#  'Milk': 114,
#  'Bean Paste': 114,
#  'Peppers': 113,
#  'Lemons': 112,
#  'Cabbage': 111,
#  'Beef': 110,
#  'Chili Powder': 108,
#  'Sichuan Peppercorns': 105,
#  'Cumin': 104,
#  'Eggplant': 99,
#  'Miso Paste': 96,
#  'Chili Oil': 91,
#  'Radish': 90,
#  'Cucumbers': 80,
#  'Coconut Milk': 79,
#  'Broccoli': 76,
#  'Rice Flour': 75,
#  'Honey': 72,
#  'Bok Choy': 72,
#  'Chili Pepper Flakes': 71,
#  'Potatoes': 68,
#  'Five Spice': 65,
#  'Kelp': 61,
#  'Garam Masala': 61,
#  'Lime': 60,
#  'Bean Sprouts': 57,
#  'Steak': 57,
#  'Cream': 56,
#  'Peanuts': 55,
#  'Breadcrumbs': 50,
#  'Tomato Ketchup': 48,
#  'Nori': 47,
#  'Spice Blend': 47,
#  'Shiso Leaves': 47,
#  'Shallots': 47,
#  'Yogurt': 47,
#  'Parsley': 45,
#  'Salmon': 45,
#  'Coconut': 45,
#  'Curry Paste': 45,
#  'Bay Leaves': 43,
#  'Fish': 43,
#  'Lime Leaves': 43,
#  'Baking Powder': 42,
#  'Mayonnaise': 41,
#  'Chives': 39,
#  'Tamarind Sauce': 39,
#  'Bonito Flakes': 37,
#  'Celery': 37,
#  'Cardamom': 37,
#  'Green Beans': 36,
#  'Seaweed': 34,
#  'Mint': 34,
#  'Cinnamon': 34,
#  'Mustard Seeds': 34,
#  'Corn': 33,
#  'Gochujang': 33,
#  'Saffron': 33,
#  'Tomato Sauce': 32,
#  'Matcha Powder': 31,
#  'Vanilla Extract': 30,
#  'Spinach': 30,
#  'Lettuce': 29,
#  'Basil': 29,
#  'Fenugreek Leaves': 29,
#  'Fish Cakes': 28,
#  'Star Anise': 28,
#  'Maple Syrup': 27,
#  'Bamboo Shoots': 27,
#  'Cashews': 27,
#  'Kimchi': 26,
#  'Chili Paste': 26,
#  'Tonkatsu': 26,
#  'Curry Leaves': 25,
#  'Mustard': 24,
#  'Tuna': 23,
#  'Ponzu': 23,
#  'Squash': 23,
#  'Cheese': 23,
#  'Chili Sauce': 23,
#  'Lemongrass': 23,
#  'Asafoetida': 23,
#  'Shishito Peppers': 22,
#  'Pasta': 21,
#  'Yuzu': 21,
#  'Burdock Root': 21,
#  'Nutmeg': 21,
#  'Tapioca Starch': 21,
#  'Worcestershire Sauce': 20,
#  'Cauliflower': 20,
#  'Baking Soda': 20,
#  'Cloves': 20,
#  'Yeast': 19,
#  'Pickled Ginger': 19,
#  'Noodle Soup Base': 19,
#  'Snow Peas': 19,
#  'Chicken Katsu': 18,
#  'Berries': 18,
#  'Dashi': 18,
#  'Lotus Root': 18,
#  'Zucchini': 18,
#  'Pistachios': 18,
#  'Pandan Leaf': 18,
#  'Sriracha': 17,
#  'Seasoning Powder': 17,
#  'Asparagus': 17,
#  'Sweet Potatoes': 17,
#  'Sauce': 16,
#  'Mustard Greens': 16,
#  'Hoisin Sauce': 16,
#  'Squid': 15,
#  'Roe': 15,
#  'Green Peas': 15,
#  'Dumpling Wrappers': 15,
#  'Bread': 15,
#  'Vegetables': 15,
#  'Anchovies': 14,
#  'Ham': 14,
#  'Syrup': 14,
#  'Peanut Butter': 14,
#  'Wonton Wrapper': 13,
#  'Strawberry': 13,
#  'Paprika': 13,
#  'Okra': 13,
#  'Bacon': 13,
#  'Konjac': 13,
#  'Mangoes': 13,
#  'Dates': 13,
#  'Jalapeno Peppers': 13,
#  'Rice Powder': 13,
#  'Curry Powder': 12,
#  'Food Colouring': 12,
#  'Gochugaru': 12,
#  'Peppercorns': 12,
#  'Lentils': 12,
#  'Black Beans': 12,
#  'Galangal': 12,
#  'Avocado': 11,
#  'Plums': 11,
#  'Soybeans': 11,
#  'Sesame Paste': 11,
#  'Raisins': 11,
#  'Wasabi': 11,
#  'Peas': 11,
#  'Almonds': 11,
#  'Water Chestnuts': 11,
#  'Apple': 10,
#  'Ice': 10,
#  'Mochi': 10,
#  'Melon': 10,
#  'Scallops': 10,
#  'Agar Agar': 10,
#  'Nuts': 10,
#  'Pine Nuts': 10,
#  'Lamb': 10,
#  'Sausage': 9,
#  'Banana': 9,
#  'Shio Koji': 9,
#  'Clams': 9,
#  'Taro': 9,
#  'Chocolate': 9,
#  'Beans': 9,
#  'Pineapple': 9,
#  'Rice Cakes': 9,
#  'Tempura Flour': 9,
#  'Semolina': 9,
#  'Chickpeas': 9,
#  'Chestnuts': 8,
#  'Edamame': 8,
#  'Komatsuna': 8,
#  'Shungiku': 8,
#  'Crab': 8,
#  'Gelatin': 8,
#  'Yellowtail': 8,
#  'Seafood': 8,
#  'Rose Petals': 8,
#  'Dipping Sauce': 7,
#  'Tea': 7,
#  'Parmesan Cheese': 7,
#  'Glass Noodles': 7,
#  'Buns': 7,
#  'Walnuts': 7,
#  'Choy Sum': 7,
#  'Black Bean Sauce': 7,
#  'Mushroom Powder': 7,
#  'Sev': 7,
#  'Carom Seeds': 7,
#  'Milk Powder': 6,
#  'Pickled Vegetables': 6,
#  'Eel': 6,
#  'Tempura': 6,
#  'Pear': 6,
#  'Thyme': 6,
#  'Pickles': 6,
#  'Chutney': 6,
#  'SPAM': 6,
#  'Brisket': 6,
#  'Mung Beans': 6,
#  'Shrimp Paste': 6,
#  'Flowers': 6,
#  'Fennel Seeds': 6,
#  'Chaat Masala': 6,
#  'Paneer': 6,
#  'Holy Basil': 6,
#  'Cream Cheese': 5,
#  'Tobiko': 5,
#  'Octopus': 5,
#  'Watermelon': 5,
#  'Pork Bones': 5,
#  'Pomegranate': 5,
#  'Leeks': 5,
#  'Turkey': 5,
#  'Rice Paper': 5,
#  'Puff Pastry': 5,
#  'Oxtail': 5,
#  'Perilla Leaves': 5,
#  'Orange Juice': 5,
#  'Duck': 5,
#  'Liver': 5,
#  'Spring Roll Wrappers': 5,
#  'Pumpkin': 5,
#  'Bottle Gourd': 5,
#  'Urad Dal': 5,
#  'Yard Long Beans': 5,
#  'Nutella': 4,
#  'Soy Flour': 4,
#  'Snap Peas': 4,
#  'Condensed Milk': 4,
#  'Beef Short Ribs': 4,
#  'Soy Milk': 4,
#  'Sea Urchin': 4,
#  'Sea Bream': 4,
#  'Cocoa Powder': 4,
#  'Turnip': 4,
#  'Egg Roll Wrappers': 4,
#  'Ice Cream': 4,
#  'Tapioca Pearls': 4,
#  'Fiddleheads': 4,
#  'Chrysanthemum': 4,
#  'Minari': 4,
#  'Garlic Scapes': 4,
#  'Greens': 4,
#  'Perilla Oil': 4,
#  'Red Beans': 4,
#  'Orange Zest': 4,
#  'Quinoa': 4,
#  'Canola Oil': 4,
#  'Kale': 4,
#  'Chana Dal': 4,
#  'Aamchur': 4,
#  'Poppy Seeds': 4,
#  'Seasoning Sauce': 4,
#  'Morning Glory': 4,
#  'MSG': 4,
#  'Jam': 3,
#  'Natto': 3,
#  'Yam': 3,
#  'Watermelon Radish': 3,
#  'Gold Leaf': 3,
#  'Kombucha': 3,
#  'Fish Flakes': 3,
#  'Kanpyo': 3,
#  'Monkfish': 3,
#  'Tartar Sauce': 3,
#  'Gyoza': 3,
#  'Oysters': 3,
#  'Fruit': 3,
#  'Oranges': 3,
#  'Rosemary': 3,
#  'Raspberries': 3,
#  'Grapes': 3,
#  'Radish Sprouts': 3,
#  'Abalone': 3,
#  'Soju': 3,
#  'Fish Balls': 3,
#  'Coconut Oil': 3,
#  'Shortening': 3,
#  'Chickpea Flour': 3,
#  'Agave Syrup': 3,
#  'Ricotta Cheese': 3,
#  'Paratha': 3,
#  'Mango Puree': 3,
#  'Dill': 3,
#  'Papaya': 3,
#  'Garlic Oil': 3,
#  'Dressing': 2,
#  'Pickled Radish': 2,
#  'Omelette': 2,
#  'Oregano': 2,
#  'Potato Salad': 2,
#  'Tofu Skin': 2,
#  'Wheat Gluten': 2,
#  'Fried Tofu Pouch': 2,
#  'Half and Half': 2,
#  'Stew Mix': 2,
#  'Plum Sauce': 2,
#  'Ribs': 2,
#  'Marmalade': 2,
#  'Liquor': 2,
#  'Whipped Cream': 2,
#  'Salad Greens': 2,
#  'Almond Extract': 2,
#  'Rum': 2,
#  'Kiwi': 2,
#  'Buttermilk': 2,
#  'Sea Bass': 2,
#  'Cherries': 2,
#  'Korean Ginseng': 2,
#  'Dumplings': 2,
#  'Acorn Powder': 2,
#  'Pickled Pepper': 2,
#  'Beer': 2,
#  'Pineapple Juice': 2,
#  'Watercress': 2,
#  'Almond Milk': 2,
#  'Molasses': 2,
#  'XO Sauce': 2,
#  'Duck Pancakes': 2,
#  'Orange Sauce': 2,
#  'Oats': 2,
#  'Swiss Chard': 2,
#  'Millet': 2,
#  'Ajwain': 2,
#  'Poha': 2,
#  'Beets': 2,
#  'Rose Essence': 2,
#  'Coriander Powder': 2,
#  'Beetroot': 2,
#  'Arrowroot': 2,
#  'Watermelon Juice': 2,
#  'Garlic Juice': 2,
#  'Fingerroot': 2,
#  'Fermented Bean Curd': 2,
#  'Jackfruit': 2,
#  'Coconut Water': 2,
#  'Chocolate Syrup': 1,
#  'Rice Ball': 1,
#  'Mugwort': 1,
#  'Kinome': 1,
#  'Pesto': 1,
#  'Kashiwa Oak Leaves': 1,
#  'Sudachi': 1,
#  'Sage': 1,
#  'Gruyere Cheese': 1,
#  'Safflower Oil': 1,
#  'Dried Sardine': 1,
#  'Lima Beans': 1,
#  'Shrimp Juice': 1,
#  'Demiglace Sauce': 1,
#  'Mascarpone Cheese': 1,
#  'Lady Fingers': 1,
#  'Baguette': 1,
#  'Arugula': 1,
#  'Calamari': 1,
#  'Takoyaki Sauce': 1,
#  'Bracken starch': 1,
#  'Tortilla': 1,
#  'Sour Cream': 1,
#  'Seafood Sauce': 1,
#  'Orange Syrup': 1,
#  'Hoba Leaves': 1,
#  'Lobster Tails': 1,
#  'Crab Salad': 1,
#  'Sprinkles': 1,
#  'Teriyaki Sauce': 1,
#  'Beef Bowl': 1,
#  'Shrimp Fritters': 1,
#  'Croquettes': 1,
#  'Allspice': 1,
#  'Chicken Nanban': 1,
#  'Salad Dressing': 1,
#  'Beef Tongue': 1,
#  'Kumquat': 1,
#  'Dried Fruit': 1,
#  'Doenjang': 1,
#  'Curry Sauce': 1,
#  'Coffee': 1,
#  'Apple Juice': 1,
#  'Bellflower Root': 1,
#  'Perilla Seeds': 1,
#  'Bean Liquid': 1,
#  'Sprite': 1,
#  'Soybean Powder': 1,
#  'Persimmons': 1,
#  'Yeotkireum': 1,
#  'Cream of Tartar': 1,
#  'Catfish': 1,
#  'Sichuan Peppercorn Oil': 1,
#  'Beef Chuck Roast': 1,
#  'Beef Bones': 1,
#  'Pork Trotters': 1,
#  'Tangerine Peel': 1,
#  'CocaCola': 1,
#  'Wonton': 1,
#  'Shichimi Togarashi': 1,
#  'Sauerkraut': 1,
#  'Cornmeal': 1,
#  'Broccoli Rabe': 1,
#  'Celtuce': 1,
#  'Ramen': 1,
#  'Pan Drippings': 1,
#  'Nutty Sauce': 1,
#  'Tofu Water': 1,
#  'Barley': 1,
#  'Pecans': 1,
#  'Gluten Balls': 1,
#  'Grapefruit': 1,
#  'Artichoke Heart': 1,
#  'Longan': 1,
#  'Codonopsis': 1,
#  'Astragalus': 1,
#  'Mussels': 1,
#  'Fava beans': 1,
#  'Dabeli Masala': 1,
#  'Biryani Spice': 1,
#  'Naan': 1,
#  'Toor Dal': 1,
#  'Sambar Powder': 1,
#  'Pickle Masala': 1,
#  'Bhel': 1,
#  'Kidney Bean': 1,
#  'Rose Water': 1,
#  'Masoor Dal': 1,
#  'Idli Batter': 1,
#  'Cooking Spray': 1,
#  'Black Eyed Peas': 1,
#  'Citric Acid': 1,
#  'Nigella Seeds': 1,
#  'Figs': 1,
#  'Basil Seeds': 1,
#  'Mung Dal': 1,
#  'Moth Beans': 1,
#  'Tindora': 1,
#  'Fox Nut': 1,
#  'Besan': 1,
#  'Thai Basil': 1,
#  'Pigeon Peas': 1,
#  'Gravy': 1,
#  'Avocado Oil': 1,
#  'Pepper Leaves': 1,
#  'Butterfly Pea Flower': 1,
#  'Rice Water': 1,
#  'Egg Noodles': 1,
#  'Suki Sauce': 1,
#  'Soup': 1,
#  'Sago': 1,
#  'Duck Egg': 1,
#  'Onion Stem': 1}

# %%
# Convert lists to strings
if "normalised_ingredients" in df_no_nan.columns:
    df_no_nan["normalised_ingredients"] = df_no_nan["normalised_ingredients"].apply(
        lambda x: "; ".join(x) if isinstance(x, list) else x
    )

if "cleaned_ingredients" in df_no_nan.columns:
    df_no_nan["cleaned_ingredients"] = df_no_nan["cleaned_ingredients"].apply(
        lambda x: "; ".join(x) if isinstance(x, list) else x
    )

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("standardised_recipes.db")

# Save DataFrame to SQL database
df_no_nan.to_sql("recipes", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

print("Data saved to database!")
# Out:
# Data saved to database!
