# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3

# %% [markdown]
# ## Scraping Japanese Recipes
# 'www.justonecookbook.com'

# %%
recipes = []

# URL for the recipe index
base_url = "https://www.justonecookbook.com/recipes/page/{}/"

# Loop through all pages
for page in range(1, 20):  # Iterate through all pages
    url = base_url.format(page)
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract recipe cards
    recipe_cards = soup.find_all("article", class_="post-filter post-sm post-abbr")
    # recipe_cards = soup.find_all('h3', class_='article-title')
    for card in recipe_cards:
        information = card.find("h3", class_="article-title")
        title = information.text.strip()
        link_tag = information.find("a")
        link = link_tag["href"]

        # Extract image URL
        image_tag = card.find("img")  # Assuming <img> tag exists in the card
        if image_tag and "src" in image_tag.attrs:
            image_url = image_tag["src"]
            # Download the image content
            image_response = requests.get(image_url)
            if image_response.status_code == 200:
                image_data = image_response.content  # Binary image data
            else:
                print(f"Failed to fetch image for {title}")
                image_data = None
        else:
            image_url = None
            image_data = None

        # Append to recipes list
        recipes.append(
            {
                "title": title,
                "link": link,
                "image_url": image_url,
                "image_data": image_data,
            }
        )

    print(f"Page {page} scraped successfully!")
# Out:
# Page 1 scraped successfully!
# Page 2 scraped successfully!
# Page 3 scraped successfully!
# Page 4 scraped successfully!
# Page 5 scraped successfully!
# Page 6 scraped successfully!
# Page 7 scraped successfully!
# Page 8 scraped successfully!
# Page 9 scraped successfully!
# Page 10 scraped successfully!
# Page 11 scraped successfully!
# Page 12 scraped successfully!
# Page 13 scraped successfully!
# Page 14 scraped successfully!
# Page 15 scraped successfully!
# Page 16 scraped successfully!
# Page 17 scraped successfully!
# Page 18 scraped successfully!
# Page 19 scraped successfully!

# %%
# Create an empty DataFrame to store all recipes from japanese recipes
japanese_recipes = []

for i in range(len(recipes)):  # len(recipes)
    current_recipe = recipes[i]
    url = current_recipe["link"]

    print(f"\rProgress: {i}, url:{url}", end="")

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract recipe cards, 2 checks, one checks the hyperlink breakdcrumsb and the other checks if there is a jump to recipe button
    recipe_cards = soup.find("span", class_="jump-text")
    recipe_exists = soup.find("div", class_="breadcrumbs").text.strip()
    recipe_exists2 = recipe_cards.text.strip()

    # recipe_exists == 'Jump to Recipe' and
    if (
        ("How-Tos" not in recipe_exists)
        and ("Recipe Collection" not in recipe_exists)
        and recipe_exists2 == "Jump to Recipe"
    ):
        # if recipe_exists2 == 'Jump to Recipe':

        # Get Professional title
        current_recipe["title"] = soup.find(
            "h2", class_="wprm-recipe-name wprm-block-text-bold"
        ).text.strip()

        # Get recipe description
        current_recipe["description"] = soup.find(
            "div", class_="wprm-recipe-summary wprm-block-text-normal"
        ).text.strip()

        # Get times
        time_block = soup.find("div", class_="wprm-recipe-total-time-container")
        if time_block:
            time_list = time_block.text.strip().split()
            label = " ".join(time_list[0:2])
            value = " ".join(time_list[2:4])
            current_recipe[label] = value

        # Get type of food
        type_food = soup.find(
            "div",
            class_="wprm-recipe-meta-container wprm-recipe-tags-container wprm-recipe-details-container wprm-recipe-details-container-inline wprm-block-text-normal",
        )
        if type_food:
            type_cards = type_food.find_all("div", class_="wprm-recipe-tag-container")
            for card in type_cards:
                label_element = card.find("span", class_="wprm-recipe-tag-label")
                value_element = card.find("span", class_="wprm-block-text-normal")
                if label_element and value_element:
                    current_recipe[label_element.text.strip()] = (
                        value_element.text.strip()
                    )

        # Extract ingredients
        ingredients = []
        ingredient_cards = soup.find_all("li", class_="wprm-recipe-ingredient")
        for card in ingredient_cards:
            ingredient_block = card.find("span", class_="wprm-recipe-ingredient-name")
            if ingredient_block:
                name = ingredient_block.text.strip()
                ingredients.append(name)
        current_recipe["ingredients"] = ingredients

        # Get nutrition values
        nutrition_cards = soup.find_all(
            "span", class_="wprm-nutrition-label-text-nutrition-container"
        )
        for card in nutrition_cards:
            label_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-label"
            )
            value_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-value"
            )
            unit_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-unit"
            )
            if label_element and value_element and unit_element:
                current_recipe[label_element.text.strip()] = " ".join(
                    [value_element.text.strip(), unit_element.text.strip()]
                )

        # Get instructions
        instructions_block = soup.find(
            "div", class_="wprm-recipe-instructions-container"
        ).text.strip()
        current_recipe["instructions"] = instructions_block

        # Add to list
        japanese_recipes.append(current_recipe)

df_japanese_recipes = pd.DataFrame(japanese_recipes)
# Out:
# Progress: 1124, url:https://www.justonecookbook.com/how-to-make-shiraga-negi/ki-with-yuzu-kosho/and-stocks/inelli/wok-with-ray/

# %%
# Convert lists to strings
if "ingredients" in df_japanese_recipes.columns:
    df_japanese_recipes["ingredients"] = df_japanese_recipes["ingredients"].apply(
        lambda x: "; ".join(x) if isinstance(x, list) else x
    )

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("japanese_recipes.db")

# Save DataFrame to SQL database
df_japanese_recipes.to_sql("recipes", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

print("Data saved to database!")

df_japanese_recipes
# Out:
# Data saved to database!
#                                              title  \
# 0                            Yuzu Cha (Citron Tea)
# 1                   Japanese Milk Bread (Shokupan)
# 2                                   Chicken Chashu
# 3                 Gyudon (Japanese Beef Rice Bowl)
# 4                              Japanese Beef Curry
# ..                                             ...
# 943      Taiwanese Hot Pot with Homemade Meatballs
# 944           Oyakodon (Chicken and Egg Rice Bowl)
# 945  Hamachi (Yellowtail) Teriyaki with Yuzu Kosho
# 946                            Teriyaki Pork Balls
# 947           Kinmedai Nitsuke (Braised Alfonsino)
#
#                                                   link  \
# 0            https://www.justonecookbook.com/yuzu-cha/
# 1    https://www.justonecookbook.com/japanese-milk-...
# 2      https://www.justonecookbook.com/chicken-chashu/
# 3              https://www.justonecookbook.com/gyudon/
# 4    https://www.justonecookbook.com/japanese-beef-...
# ..                                                 ...
# 943  https://www.justonecookbook.com/taiwanese-hot-...
# 944          https://www.justonecookbook.com/oyakodon/
# 945  https://www.justonecookbook.com/hamachi-yellow...
# 946  https://www.justonecookbook.com/teriyaki-pork-...
# 947  https://www.justonecookbook.com/kinmedai-nitsuke/
#
#                                              image_url  \
# 0    https://www.justonecookbook.com/wp-content/upl...
# 1    https://www.justonecookbook.com/wp-content/upl...
# 2    https://www.justonecookbook.com/wp-content/upl...
# 3    https://www.justonecookbook.com/wp-content/upl...
# 4    https://www.justonecookbook.com/wp-content/upl...
# ..                                                 ...
# 943  https://www.justonecookbook.com/wp-content/upl...
# 944  https://www.justonecookbook.com/wp-content/upl...
# 945  https://www.justonecookbook.com/wp-content/upl...
# 946  https://www.justonecookbook.com/wp-content/upl...
# 947  https://www.justonecookbook.com/wp-content/upl...
#
#                                             image_data  \
# 0    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 1    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 2    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 3    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 4    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# ..                                                 ...
# 943  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 944  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 945  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 946  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 947  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
#
#                                            description Total Time:  \
# 0    Try my easy homemade recipe for Yuzu Cha (Citr...      1 hour
# 1    Japanese Milk Bread is possibly the best versi...     3 hours
# 2    Juicy and tender Chicken Chashu is a lighter v...      1 hour
# 3    With thinly sliced beef and tender onions simm...  20 minutes
# 4    With tender chunks of beef, potatoes, carrots,...     3 hours
# ..                                                 ...         ...
# 943  Delicious Taiwanese Hot Pot and Homemade Meatb...  30 minutes
# 944  Oyakodon is a classic comfort food of Japanese...  25 minutes
# 945  Growing up, I had enjoyed eating Hamachi Teriy...  20 minutes
# 946  My Teriyaki Pork Balls recipe uses thin slices...  30 minutes
# 947  Kinmedai Nitsuke (Braised Alfonsino) is a clas...  30 minutes
#
#          Course:   Cuisine:                                   Keyword:  \
# 0         How to   Japanese                                       yuzu
# 1      Breakfast   Japanese                             japanese bread
# 2    Main Course   Japanese                                    chicken
# 3    Main Course   Japanese                   beef, donburi, rice bowl
# 4    Main Course   Japanese                                beef, curry
# ..           ...        ...                                        ...
# 943  Main Course  Taiwanese                              hot pot, nabe
# 944  Main Course   Japanese                         donburi, over rice
# 945  Main Course   Japanese  hamachi, teriyaki, yellowtail, yuzu kosho
# 946  Main Course   Japanese                                       pork
# 947  Main Course   Japanese                            Alfonsino, fish
#
#                                            ingredients  ... Trans Fat:  \
# 0                       yuzu; white rock sugar; shochu  ...        NaN
# 1    warm water; sugar; Diamond Crystal kosher salt...  ...        1 g
# 2    boneless, skin-on chicken thighs; green onions...  ...        NaN
# 3    onion; green onion/scallion; thinly sliced bee...  ...        NaN
# 4    onions; unsalted butter; neutral oil; russet p...  ...        1 g
# ..                                                 ...  ...        ...
# 943  ground pork; green onion/scallion; Tokyo negi ...  ...        1 g
# 944  onion; boneless, skinless chicken thighs; sake...  ...      0.1 g
# 945  yellowtail (hamachi, buri); freshly ground bla...  ...        1 g
# 946  sake; potato starch or cornstarch; thinly slic...  ...        NaN
# 947  kinmedai (alfonsino); sake; mirin; sugar; soy ...  ...        NaN
#
#     Cholesterol:  Sodium: Potassium: Fiber: Sugar: Vitamin A: Vitamin C:  \
# 0            NaN      NaN        NaN    NaN    NaN        NaN        NaN
# 1          58 mg  1355 mg     786 mg   10 g   40 g    1068 IU       1 mg
# 2            NaN      NaN        NaN    NaN    NaN        NaN        NaN
# 3          69 mg    65 mg     468 mg    1 g   10 g      23 IU       4 mg
# 4          73 mg   938 mg     873 mg    4 g   10 g    3992 IU      13 mg
# ..           ...      ...        ...    ...    ...        ...        ...
# 943       233 mg   812 mg    1735 mg    8 g   26 g    5975 IU      48 mg
# 944       414 mg  1197 mg     586 mg    1 g   11 g     442 IU       4 mg
# 945        70 mg   591 mg     725 mg    1 g    4 g     273 IU       3 mg
# 946       107 mg   769 mg     874 mg    1 g    7 g      75 IU       3 mg
# 947        57 mg   539 mg     351 mg    1 g    5 g        NaN       1 mg
#
#     Calcium: Iron:
# 0        NaN   NaN
# 1     348 mg  3 mg
# 2        NaN   NaN
# 3      25 mg  6 mg
# 4      66 mg  3 mg
# ..       ...   ...
# 943   348 mg  7 mg
# 944    71 mg  4 mg
# 945    61 mg  1 mg
# 946    35 mg  1 mg
# 947    12 mg  1 mg
#
# [948 rows x 29 columns]

# %%
# Find null values in each column
null_counts = df_japanese_recipes.isnull().sum()

print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# title                     0
# link                      0
# image_url                 0
# image_data                0
# description               0
# Total Time:              18
# Course:                   8
# Cuisine:                  8
# Keyword:                  8
# ingredients               0
# instructions              0
# Serving:                838
# Calories:                22
# Carbohydrates:           28
# Protein:                 27
# Fat:                     56
# Saturated Fat:           62
# Polyunsaturated Fat:    260
# Monounsaturated Fat:    271
# Trans Fat:              463
# Cholesterol:            298
# Sodium:                  18
# Potassium:               28
# Fiber:                   70
# Sugar:                   41
# Vitamin A:               80
# Vitamin C:              142
# Calcium:                 22
# Iron:                    30
# dtype: int64

# %%
# Check for duplicate rows
duplicates = df_japanese_recipes.duplicated()

print("Duplicate rows:")
print(df_japanese_recipes[duplicates])
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [title, link, image_url, image_data, description, Total Time:, Course:, Cuisine:, Keyword:, ingredients, instructions, Serving:, Calories:, Carbohydrates:, Protein:, Fat:, Saturated Fat:, Polyunsaturated Fat:, Monounsaturated Fat:, Trans Fat:, Cholesterol:, Sodium:, Potassium:, Fiber:, Sugar:, Vitamin A:, Vitamin C:, Calcium:, Iron:]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ----
#
# ## Chinese Recipes
#
# https://omnivorescookbook.com/recipe-filter/

# %%
recipes = []

# URL for the recipe index
base_url = "https://omnivorescookbook.com/recipe-filter/page/{}/"

# Loop through all pages
for page in range(1, 37):  # Iterate through all pages
    url = base_url.format(page)
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract recipe cards
    recipe_cards = soup.find_all("article", class_="post-sm post-abbr")
    for card in recipe_cards:
        # print(card)
        information = card.find("h3", class_="entry-title")
        # print(information)
        title = information.text.strip()
        link_tag = information.find("a")
        link = link_tag["href"]

        # Extract image URL
        image_tag = card.find("img")  # Assuming <img> tag exists in the card
        if image_tag and "src" in image_tag.attrs:
            image_url = image_tag["src"]
            # Download the image content
            image_response = requests.get(image_url)
            if image_response.status_code == 200:
                image_data = image_response.content  # Binary image data
            else:
                print(f"Failed to fetch image for {title}")
                image_data = None
        else:
            image_url = None
            image_data = None

        # Append to recipes list
        recipes.append(
            {
                "title": title,
                "link": link,
                "image_url": image_url,
                "image_data": image_data,
            }
        )

    print(f"Page {page} scraped successfully!")
# Out:
# Page 1 scraped successfully!
# Page 2 scraped successfully!
# Page 3 scraped successfully!
# Page 4 scraped successfully!
# Page 5 scraped successfully!
# Page 6 scraped successfully!
# Page 7 scraped successfully!
# Page 8 scraped successfully!
# Page 9 scraped successfully!
# Page 10 scraped successfully!
# Page 11 scraped successfully!
# Page 12 scraped successfully!
# Page 13 scraped successfully!
# Page 14 scraped successfully!
# Page 15 scraped successfully!
# Page 16 scraped successfully!
# Page 17 scraped successfully!
# Page 18 scraped successfully!
# Page 19 scraped successfully!
# Page 20 scraped successfully!
# Page 21 scraped successfully!
# Page 22 scraped successfully!
# Page 23 scraped successfully!
# Page 24 scraped successfully!
# Page 25 scraped successfully!
# Page 26 scraped successfully!
# Page 27 scraped successfully!
# Page 28 scraped successfully!
# Page 29 scraped successfully!
# Page 30 scraped successfully!
# Page 31 scraped successfully!
# Page 32 scraped successfully!
# Page 33 scraped successfully!
# Page 34 scraped successfully!
# Page 35 scraped successfully!
# Page 36 scraped successfully!

# %%
# Create an empty DataFrame to store all recipes from japanese recipes
chinese_recipes = []

for i in range(len(recipes)):  # len(recipes)
    current_recipe = recipes[i]
    url = current_recipe["link"]

    print(f"\rProgress: {i}, url:{url}", end="")

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract recipe cards, 2 checks, one checks the hyperlink breakdcrumsb and the other checks if there is a jump to recipe button
    recipe_cards = soup.find("a", class_="recipe-jump")
    # recipe_exists = recipe_cards.text.strip()

    if recipe_cards:

        # Get Professional title
        current_recipe["title"] = soup.find(
            "h2", class_="wprm-recipe-name wprm-block-text-bold"
        ).text.strip()

        # Get recipe description
        description_block = soup.find(
            "div", class_="wprm-recipe-summary wprm-block-text-normal"
        )
        if description_block:
            current_recipe["description"] = description_block.text.strip()

        # Get times
        time_block = soup.find("div", class_="wprm-recipe-total-time-container")
        if time_block:
            time_list = time_block.text.strip().split()
            label = " ".join(time_list[0:2])
            value = " ".join(time_list[2:4])
            current_recipe[label] = value

        # Get type of food
        type_food = soup.find(
            "div",
            class_="wprm-recipe-meta-container wprm-recipe-tags-container wprm-recipe-details-container wprm-recipe-details-container-inline wprm-block-text-normal",
        )
        if type_food:
            type_cards = type_food.find_all("div", class_="wprm-recipe-tag-container")
            for card in type_cards:
                label_element = card.find("span", class_="wprm-recipe-tag-label")
                value_element = card.find("span", class_="wprm-block-text-normal")
                if label_element and value_element:
                    current_recipe[label_element.text.strip()] = (
                        value_element.text.strip()
                    )

        # Extract ingredients
        ingredients = []
        ingredient_cards = soup.find_all("li", class_="wprm-recipe-ingredient")
        for card in ingredient_cards:
            ingredient_block = card.find("span", class_="wprm-recipe-ingredient-name")
            if ingredient_block:
                name = ingredient_block.text.strip()
                ingredients.append(name)
        current_recipe["ingredients"] = ingredients

        # Get nutrition values
        nutrition_cards = soup.find_all(
            "span", class_="wprm-nutrition-label-text-nutrition-container"
        )
        for card in nutrition_cards:
            label_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-label"
            )
            value_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-value"
            )
            unit_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-unit"
            )
            if label_element and value_element and unit_element:
                current_recipe[label_element.text.strip()] = " ".join(
                    [value_element.text.strip(), unit_element.text.strip()]
                )

        # Get instructions
        instructions_block = soup.find(
            "div", class_="wprm-recipe-instructions-container"
        ).text.strip()
        current_recipe["instructions"] = instructions_block

        # Add to list
        chinese_recipes.append(current_recipe)
        # print(current_recipe)

df_chinese_recipes = pd.DataFrame(chinese_recipes)
# Out:
# Progress: 928, url:https://omnivorescookbook.com/chinese-eggplant-with-garlic-sauceiata-sauce/-and-rice/ke-mushroom

# %%
# Convert lists to strings
if "ingredients" in df_chinese_recipes.columns:
    df_chinese_recipes["ingredients"] = df_chinese_recipes["ingredients"].apply(
        lambda x: "; ".join(x) if isinstance(x, list) else x
    )

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("chinese_recipes.db")

# Save DataFrame to SQL database
df_chinese_recipes.to_sql("recipes", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

print("Data saved to database!")

df_chinese_recipes
# Out:
# Data saved to database!
#                                             title  \
# 0                   Easy Oyster Mushroom Stir Fry
# 1                             Honey Glazed Salmon
# 2                                    Shrimp Toast
# 3                               Garlic Fried Rice
# 4                       Chicken with Garlic Sauce
# ..                                            ...
# 900                     Barter-Worthy Spam Musubi
# 901                    Authentic Mapo Tofu (麻婆豆腐)
# 902               Chinese Scallion Pancakes (葱油饼)
# 903  Chicken and Broccoli (Chinese Takeout Style)
# 904     Chinese Eggplant with Garlic Sauce (红烧茄子)
#
#                                                   link  \
# 0    https://omnivorescookbook.com/easy-oyster-mush...
# 1    https://omnivorescookbook.com/honey-soy-sauce-...
# 2          https://omnivorescookbook.com/shrimp-toast/
# 3     https://omnivorescookbook.com/garlic-fried-rice/
# 4    https://omnivorescookbook.com/chicken-with-gar...
# ..                                                 ...
# 900         https://omnivorescookbook.com/spam-musubi/
# 901  https://omnivorescookbook.com/authentic-mapo-t...
# 902  https://omnivorescookbook.com/chinese-scallion...
# 903  https://omnivorescookbook.com/chicken-and-broc...
# 904  https://omnivorescookbook.com/chinese-eggplant...
#
#                                              image_url  \
# 0    https://omnivorescookbook.com/wp-content/uploa...
# 1    https://omnivorescookbook.com/wp-content/uploa...
# 2    https://omnivorescookbook.com/wp-content/uploa...
# 3    https://omnivorescookbook.com/wp-content/uploa...
# 4    https://omnivorescookbook.com/wp-content/uploa...
# ..                                                 ...
# 900  https://omnivorescookbook.com/wp-content/uploa...
# 901  https://omnivorescookbook.com/wp-content/uploa...
# 902  https://omnivorescookbook.com/wp-content/uploa...
# 903  https://omnivorescookbook.com/wp-content/uploa...
# 904  https://omnivorescookbook.com/wp-content/uploa...
#
#                                             image_data  \
# 0    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 1    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 2    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 3    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 4    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# ..                                                 ...
# 900  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 901  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 902  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 903  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 904  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
#
#                                            description Total Time:  \
# 0    A super quick and easy oyster mushroom stir fr...  15 minutes
# 1    A simple yet rich tasting honey glazed salmon ...  55 minutes
# 2    Make these crispy savory shrimp toasts as an a...  40 minutes
# 3    A Chinese style garlic fried rice featuring cr...  25 minutes
# 4    Chicken with garlic sauce is a super easy take...  30 minutes
# ..                                                 ...         ...
# 900  The spam is grilled until crispy, perfectly ca...  45 minutes
# 901  An easy mapo tofu recipe that creates the auth...  25 minutes
# 902  Super crispy and flaky on the outside and slig...      1 hour
# 903  An easy chicken and broccoli stir fry recipe t...  25 minutes
# 904  The eggplant is grilled until crispy and smoky...  40 minutes
#
#              Course:        Cuisine:                     Keyword:  \
# 0          Side Dish         Chinese                    homestyle
# 1               Main  Chinese Fusion               weekday dinner
# 2          Appetizer         Chinese             restaurant-style
# 3               Side         Chinese                      takeout
# 4               Main         Chinese                      takeout
# ..               ...             ...                          ...
# 900  Appetizer, Main          hawaii             restaurant-style
# 901             Main         Chinese  homestyle, restaurant-style
# 902        Appetizer         Chinese             restaurant-style
# 903             Main         Chinese                      takeout
# 904       Main, Side         Chinese                      takeout
#
#                                            ingredients  ... Potassium: Fiber:  \
# 0    oyster mushrooms; peanut oil; garlic; sugar; s...  ...     609 mg  1.9 g
# 1    salmon filets; salt; sugar; honey; Shaoxing wi...  ...     743 mg  0.6 g
# 2    shrimp; egg white; ginger; garlic; light soy s...  ...     138 mg    1 g
# 3    of leftover cooked jasmine rice; soy sauce; oy...  ...     143 mg  1.7 g
# 4    chicken breasts or thighs; Shaoxing wine; salt...  ...     306 mg  0.9 g
# ..                                                 ...  ...        ...    ...
# 900  vegetable oil; low-sodium Spam (12 oz. / 340 g...  ...     271 mg  0.5 g
# 901  ground pork; Shaoxing wine; light soy sauce; m...  ...     173 mg    1 g
# 902  all-purpose flour; salt; boiling water; cool w...  ...      58 mg  1.1 g
# 903  boneless skinless chicken breast; Shaoxing win...  ...     512 mg  0.8 g
# 904  Chinese eggplant; salt; cornstarch; light soy ...  ...     252 mg  3.7 g
#
#      Sugar: Calcium:   Iron:  \
# 0     3.5 g     4 mg    5 mg
# 1    37.3 g    71 mg    2 mg
# 2     1.7 g   101 mg    2 mg
# 3     1.4 g    50 mg    2 mg
# 4     7.3 g    30 mg    2 mg
# ..      ...      ...     ...
# 900   3.1 g    10 mg    2 mg
# 901   2.6 g   206 mg    2 mg
# 902   0.3 g    11 mg    2 mg
# 903   3.5 g    25 mg    1 mg
# 904   5.1 g    10 mg  0.4 mg
#
#                                           instructions Cholesterol:  \
# 0    InstructionsHeat the oil in a large skillet ov...          NaN
# 1    InstructionsTo cure the salmon (Optional): Mix...        78 mg
# 2    InstructionsTo prepare the shrimp spread(Optio...        90 mg
# 3    InstructionsFluff day old rice in a bowl with ...       186 mg
# 4    InstructionsCombine chicken, Shaoxing wine, sa...        62 mg
# ..                                                 ...          ...
# 900  InstructionsStart making steamed rice (or sush...        30 mg
# 901  InstructionsCombine ground meat, cooking wine,...        19 mg
# 902  InstructionsMake the doughOPTION 1 – USING YOU...          NaN
# 903  InstructionsSlice the chicken against the grai...        73 mg
# 904  Instructions(Option 1) Place eggplant in a lar...          NaN
#
#     Vitamin C: Vitamin A: Trans Fat:
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2          NaN        NaN        NaN
# 3          NaN        NaN        NaN
# 4          NaN        NaN        NaN
# ..         ...        ...        ...
# 900        NaN        NaN        NaN
# 901        NaN        NaN        NaN
# 902        NaN        NaN        NaN
# 903        NaN        NaN        NaN
# 904     4.1 mg        NaN        NaN
#
# [905 rows x 27 columns]

# %% [markdown]
# ----
#
# ## Scraping Thai Recipes
#
# https://hungryinthailand.com/

# %%
# Gather all urls from thai recipes website

categories = [
    "thai-appetizers/",
    "thai-salads/",
    "thai-side-dish-recipes/",
    "thai-dinner/",
    "thai-desserts/",
    "thai-soups/",
]
pages = [2, 1, 1, 4, 1, 1]

all_urls = []

for i in range(len(categories)):
    page_count = pages[i]
    for j in range(page_count):
        url = f"https://hungryinthailand.com/category/{categories[i]}/page/{j+1}/"
        all_urls.append(url)

# %%
recipes = []

# Loop through all pages
for url in all_urls:  # Iterate through all pages
    print(url)
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract recipe cards
    recipe_cards = soup.find_all("article", class_="status-publish")
    for card in recipe_cards:
        information = card.find("h2", class_="entry-title")
        # print(information)
        title = information.text.strip()
        link_tag = information.find("a")
        link = link_tag["href"]

        # Extract image URL
        image_tag = card.find(
            "div", class_="post-thumbnail-inner"
        )  # Assuming <img> tag exists in the card
        image_tag = image_tag.find("img")
        if image_tag and "src" in image_tag.attrs:
            image_url = image_tag["data-lzl-src"]
            # Download the image content
            image_response = requests.get(image_url)
            if image_response.status_code == 200:
                image_data = image_response.content  # Binary image data
            else:
                print(f"Failed to fetch image for {title}")
                image_data = None
        else:
            image_url = None
            image_data = None

        # Append to recipes list
        recipes.append(
            {
                "title": title,
                "link": link,
                "image_url": image_url,
                "image_data": image_data,
            }
        )

print(f"Pages scraped successfully!")
# Out:
# https://hungryinthailand.com/category/thai-appetizers//page/1/
# https://hungryinthailand.com/category/thai-appetizers//page/2/
# https://hungryinthailand.com/category/thai-salads//page/1/
# https://hungryinthailand.com/category/thai-side-dish-recipes//page/1/
# https://hungryinthailand.com/category/thai-dinner//page/1/
# https://hungryinthailand.com/category/thai-dinner//page/2/
# https://hungryinthailand.com/category/thai-dinner//page/3/
# https://hungryinthailand.com/category/thai-dinner//page/4/
# https://hungryinthailand.com/category/thai-desserts//page/1/
# https://hungryinthailand.com/category/thai-soups//page/1/
# Pages scraped successfully!

# %%
# Create an empty DataFrame to store all recipes from japanese recipes
thai_recipes = []

for i in range(len(recipes)):  # len(recipes)
    current_recipe = recipes[i]
    url = current_recipe["link"]

    print(f"\rProgress: {i}, url:{url}", end="")

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Checks if recipe exists on page
    recipe_cards = soup.find("a", class_="wprm-recipe-jump")

    if recipe_cards:

        # Get Professional title
        current_recipe["title"] = soup.find(
            "h2", class_="wprm-recipe-name wprm-block-text-bold"
        ).text.strip()

        # Get recipe description
        description_block = soup.find(
            "div", class_="wprm-recipe-summary wprm-block-text-normal"
        )
        if description_block:
            current_recipe["description"] = description_block.text.strip()

        # Get times
        time_block = soup.find("div", class_="wprm-recipe-total-time-container")
        if time_block:
            time_list = time_block.text.strip().split()
            label = " ".join(time_list[0:2])
            value = " ".join(time_list[2:4])
            current_recipe[label] = value

        # Get type of food
        type_food = soup.find("div", class_="wprm-recipe-custom-container")
        if type_food:
            type_cards = type_food.find_all("div", class_="wprm-recipe-tag-container")
            for card in type_cards:
                label_element = card.find("span", class_="wprm-recipe-tag-label")
                value_element = card.find("span", class_="wprm-block-text-normal")
                if label_element and value_element:
                    current_recipe[label_element.text.strip()] = (
                        value_element.text.strip()
                    )

        # Extract ingredients
        ingredients = []
        ingredient_cards = soup.find_all("li", class_="wprm-recipe-ingredient")
        for card in ingredient_cards:
            ingredient_block = card.find("span", class_="wprm-recipe-ingredient-name")
            if ingredient_block:
                name = ingredient_block.text.strip()
                ingredients.append(name)
        current_recipe["ingredients"] = ingredients

        # Get nutrition values
        nutrition_cards = soup.find_all(
            "span", class_="wprm-nutrition-label-text-nutrition-container"
        )
        for card in nutrition_cards:
            label_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-label"
            )
            value_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-value"
            )
            unit_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-unit"
            )
            if label_element and value_element and unit_element:
                current_recipe[label_element.text.strip()] = " ".join(
                    [value_element.text.strip(), unit_element.text.strip()]
                )

        # Get instructions
        instructions_block = soup.find(
            "div", class_="wprm-recipe-instructions-container"
        ).text.strip()
        current_recipe["instructions"] = instructions_block

        # Add to list
        thai_recipes.append(current_recipe)
        # print(current_recipe)

df_thai_recipes = pd.DataFrame(thai_recipes)
# Out:
# Progress: 308, url:https://hungryinthailand.com/tom-yum-pla/-glass-noodle-soup/od-soup//sauce/

# %%
# Convert lists to strings
if "ingredients" in df_thai_recipes.columns:
    df_thai_recipes["ingredients"] = df_thai_recipes["ingredients"].apply(
        lambda x: "; ".join(x) if isinstance(x, list) else x
    )

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("thai_recipes.db")

# Save DataFrame to SQL database
df_thai_recipes.to_sql("recipes", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

print("Data saved to database!")

df_thai_recipes
# Out:
# Data saved to database!
#                                                  title  \
# 0    Authentic Thai Beef Satay Recipe With Peanut S...
# 1                    Easy Thai Fish Sauce Wings Recipe
# 2                        Sweet Thai Chili Wings Recipe
# 3           Shrimp Satay Recipe With Thai Peanut Sauce
# 4                   Pork Gyoza Recipe (Pork Dumplings)
# ..                                                 ...
# 304                     Thai Vegetable Soup (Tom Jued)
# 305     Tom Kha Gai Recipe (Thai Coconut Chicken Soup)
# 306       Tom Yum Kung Recipe (Spicy Thai Shrimp Soup)
# 307              Thai Chicken Glass Noodle Soup Recipe
# 308                Tom Yum Pla (Thai Fish Soup Recipe)
#
#                                                   link  \
# 0    https://hungryinthailand.com/thai-beef-satay-r...
# 1       https://hungryinthailand.com/fish-sauce-wings/
# 2    https://hungryinthailand.com/sweet-thai-chili-...
# 3    https://hungryinthailand.com/shrimp-satay-with...
# 4      https://hungryinthailand.com/pork-gyoza-recipe/
# ..                                                 ...
# 304  https://hungryinthailand.com/thai-vegetable-so...
# 305          https://hungryinthailand.com/tom-kha-gai/
# 306         https://hungryinthailand.com/tom-yum-kung/
# 307  https://hungryinthailand.com/thai-chicken-glas...
# 308          https://hungryinthailand.com/tom-yum-pla/
#
#                                              image_url  \
# 0    https://hungryinthailand.com/wp-content/upload...
# 1    https://hungryinthailand.com/wp-content/upload...
# 2    https://hungryinthailand.com/wp-content/upload...
# 3    https://hungryinthailand.com/wp-content/upload...
# 4    https://hungryinthailand.com/wp-content/upload...
# ..                                                 ...
# 304  https://hungryinthailand.com/wp-content/upload...
# 305  https://hungryinthailand.com/wp-content/upload...
# 306  https://hungryinthailand.com/wp-content/upload...
# 307  https://hungryinthailand.com/wp-content/upload...
# 308  https://hungryinthailand.com/wp-content/upload...
#
#                                             image_data  \
# 0    b'RIFFd"\x02\x00WEBPVP8X\n\x00\x00\x00 \x00\x0...
# 1    b'RIFF\xca\xbb\x01\x00WEBPVP8X\n\x00\x00\x00 \...
# 2    b'RIFF\xc6\x91\x02\x00WEBPVP8X\n\x00\x00\x00 \...
# 3    b'RIFFL!\x01\x00WEBPVP8X\n\x00\x00\x00 \x00\x0...
# 4    b'RIFF\xf2Z\x01\x00WEBPVP8X\n\x00\x00\x00 \x00...
# ..                                                 ...
# 304  b'RIFF\xa4\x83\x01\x00WEBPVP8X\n\x00\x00\x00 \...
# 305  b'RIFF\xfa\x9f\x01\x00WEBPVP8X\n\x00\x00\x00 \...
# 306  b'RIFF$\x1f\x02\x00WEBPVP8X\n\x00\x00\x00 \x00...
# 307  b'RIFF\xd8+\x02\x00WEBPVP8X\n\x00\x00\x00 \x00...
# 308  b'RIFF\xf0\xde\x01\x00WEBPVP8X\n\x00\x00\x00 \...
#
#                                            description  Total Time  \
# 0    Enjoy my family’s authentic Thai beef satay wi...     4 hours
# 1    Enjoy perfectly crispy chicken every time with...  35 minutes
# 2    Sweet Thai chili wings recipe with a sticky, s...  40 minutes
# 3    Enjoy this easy shrimp satay recipe with Thai ...  50 minutes
# 4    Make this pork gyoza recipe for easy, homemade...      1 hour
# ..                                                 ...         ...
# 304  Tom jued is a healthy Thai vegetable soup reci...  40 minutes
# 305  Try this tom kha gai recipe—a healthy and quic...  20 minutes
# 306  This tom yum kung recipe is an authentic Thai ...  25 minutes
# 307  Enjoy a quick and easy Thai chicken glass nood...  30 minutes
# 308  Tom yum pla is a healthy Thai fish soup recipe...  35 minutes
#
#          Cuisine                         Course  \
# 0           Thai  Appetizer, Main Course, Snack
# 1    Asian, Thai    Appetizer, Side Dish, Snack
# 2           Thai               Appetizer, Snack
# 3           Thai               Appetizer, Snack
# 4           Thai               Appetizer, Snack
# ..           ...                            ...
# 304         Thai              Main Course, Soup
# 305         Thai              Main Course, Soup
# 306         Thai              Main Course, Soup
# 307         Thai                           Soup
# 308         Thai              Main Course, Soup
#
#                                            ingredients Calories:  ...  Fiber:  \
# 0    beef; of garlic; lemongrass; coriander seeds; ...   83 kcal  ...   0.2 g
# 1    chicken wings; fish sauce; rosdee seasoning po...  670 kcal  ...     NaN
# 2    tempura flour; rosdee seasoning powder; ice-co...  239 kcal  ...  0.05 g
# 3    shrimp; coconut milk; yellow curry powder; Ros...  392 kcal  ...     2 g
# 4    ground pork; white pepper; sesame oil; shoyu s...  126 kcal  ...   0.1 g
# ..                                                 ...       ...  ...     ...
# 304  garlic; coriander root; black peppercorns; bou...   63 kcal  ...     2 g
# 305  water; coconut milk; lemongrass; galangal; kaf...  451 kcal  ...     3 g
# 306  shrimp; Asian mushrooms; lemongrass; shallots;...  198 kcal  ...     1 g
# 307  glass noodles; dried chilies; chilies; shallot...  644 kcal  ...     2 g
# 308  fish; water; lemongrass; galangal; garlic; sha...  309 kcal  ...     2 g
#
#      Sugar: Vitamin A: Vitamin C: Calcium: Iron:  \
# 0       4 g       3 IU       1 mg    15 mg  2 mg
# 1     0.5 g     319 IU       2 mg    32 mg  2 mg
# 2       8 g     135 IU       1 mg    18 mg  1 mg
# 3       8 g       2 IU       2 mg    94 mg  3 mg
# 4    0.01 g     116 IU       2 mg    20 mg  1 mg
# ..      ...        ...        ...      ...   ...
# 304     2 g    5695 IU       4 mg    43 mg  1 mg
# 305     6 g     769 IU      10 mg    82 mg  6 mg
# 306    14 g     164 IU      11 mg   199 mg  2 mg
# 307     5 g    1349 IU      71 mg    72 mg  3 mg
# 308     8 g     713 IU      13 mg    86 mg  3 mg
#
#                                           instructions Trans Fat:  \
# 0    InstructionsMarinate the beefIn a pan over low...        NaN
# 1    InstructionsCombine fish sauce, white pepper, ...      0.5 g
# 2    InstructionsIn a food processor, blend the gar...      0.2 g
# 3    InstructionsClean the shrimp, remove veins, an...     0.04 g
# 4    InstructionsPREPARE THE FILLINGKnead ground po...        NaN
# ..                                                 ...        ...
# 304  InstructionsSoak glass noodles (and dried shii...        NaN
# 305  InstructionsIn a wok or pot, heat water and co...      0.1 g
# 306  InstructionsPeel and devein the shrimp, set th...        NaN
# 307  InstructionsSoak the glass noodles in water as...      0.2 g
# 308  InstructionsRinse the fish under cold water an...        NaN
#
#     Cholesterol: Serving:
# 0            NaN      NaN
# 1         166 mg      NaN
# 2          71 mg      NaN
# 3         160 mg      NaN
# 4          31 mg      NaN
# ..           ...      ...
# 304       0.1 mg      NaN
# 305        64 mg      NaN
# 306        95 mg      NaN
# 307       194 mg      NaN
# 308       118 mg      NaN
#
# [309 rows x 28 columns]

# %% [markdown]
# ---
#
# ## Korean Recipes Scraping
#
# https://kimchimari.com/recipe-index/

# %%
# Gather all urls from thai recipes website

categories = [
    "soups-guk-and-stews-jjigae/",
    "appetizer-2/",
    "salads/",
    "main-dishes/",
    "side-dishes/",
    "desserts/",
]
pages = [3, 2, 2, 5, 5, 3]

all_urls = []

for i in range(len(categories)):
    page_count = pages[i]
    for j in range(page_count):
        url = f"https://kimchimari.com/category/{categories[i]}/page/{j+1}/"
        all_urls.append(url)

# %%
recipes = []

# Loop through all pages
for url in all_urls:  # Iterate through all pages
    print(url)
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract recipe cards
    recipe_cards = soup.find_all("article", class_="status-publish")
    for card in recipe_cards:
        information = card.find("h2", class_="entry-title")
        title = information.text.strip()
        link_tag = information.find("a")
        link = link_tag["href"]

        # Extract image URL
        image_tag = card.find("img")  # Assuming <img> tag exists in the card
        if image_tag and "data-lazy-src" in image_tag.attrs:
            image_url = image_tag["data-lazy-src"]
            # Download the image content
            image_response = requests.get(image_url)
            if image_response.status_code == 200:
                image_data = image_response.content  # Binary image data
            else:
                print(f"Failed to fetch image for {title}")
                image_data = None
        elif image_tag and "src" in image_tag.attrs:
            image_url = image_tag["src"]
            # Download the image content
            image_response = requests.get(image_url)
            if image_response.status_code == 200:
                image_data = image_response.content  # Binary image data
            else:
                print(f"Failed to fetch image for {title}")
                image_data = None
        else:
            image_url = None
            image_data = None

        # Append to recipes list
        recipes.append(
            {
                "title": title,
                "link": link,
                "image_url": image_url,
                "image_data": image_data,
            }
        )

print(f"Pages scraped successfully!")
# Out:
# https://kimchimari.com/category/soups-guk-and-stews-jjigae//page/1/
# https://kimchimari.com/category/soups-guk-and-stews-jjigae//page/2/
# https://kimchimari.com/category/soups-guk-and-stews-jjigae//page/3/
# https://kimchimari.com/category/appetizer-2//page/1/
# https://kimchimari.com/category/appetizer-2//page/2/
# https://kimchimari.com/category/salads//page/1/
# https://kimchimari.com/category/salads//page/2/
# https://kimchimari.com/category/main-dishes//page/1/
# https://kimchimari.com/category/main-dishes//page/2/
# https://kimchimari.com/category/main-dishes//page/3/
# https://kimchimari.com/category/main-dishes//page/4/
# https://kimchimari.com/category/main-dishes//page/5/
# https://kimchimari.com/category/side-dishes//page/1/
# https://kimchimari.com/category/side-dishes//page/2/
# https://kimchimari.com/category/side-dishes//page/3/
# https://kimchimari.com/category/side-dishes//page/4/
# https://kimchimari.com/category/side-dishes//page/5/
# https://kimchimari.com/category/desserts//page/1/
# https://kimchimari.com/category/desserts//page/2/
# https://kimchimari.com/category/desserts//page/3/
# Pages scraped successfully!

# %%
# Create an empty DataFrame to store all recipes from japanese recipes
korean_recipes = []

for i in range(len(recipes)):  # len(recipes)
    current_recipe = recipes[i]
    url = current_recipe["link"]

    print(f"\rProgress: {i}, url:{url}", end="")

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Checks if recipe exists on page
    recipe_cards = soup.find("a", class_="wprm-recipe-jump")

    if recipe_cards:

        # Get Professional title
        current_recipe["title"] = soup.find(
            "h2", class_="wprm-recipe-name"
        ).text.strip()

        # Get recipe description
        description_block = soup.find(
            "div", class_="wprm-recipe-summary wprm-block-text-normal"
        )
        if description_block:
            current_recipe["description"] = description_block.text.strip()

        # Get times
        time_block = soup.find("div", class_="wprm-recipe-total-time-container")
        if time_block:
            time_list = time_block.text.strip().split()
            label = " ".join(time_list[0:2])
            value = " ".join(time_list[2:4])
            current_recipe[label] = value

        # Get type of food
        type_food = soup.find("div", class_="wprm-recipe-tags-container")
        if type_food:
            type_cards = type_food.find_all("div", class_="wprm-recipe-tag-container")
            for card in type_cards:
                string = card.text.strip()
                str_list = string.split(":")
                if str_list:
                    current_recipe[str_list[0]] = str_list[1]

        # Extract ingredients
        ingredients = []
        ingredient_cards = soup.find_all("li", class_="wprm-recipe-ingredient")
        for card in ingredient_cards:
            ingredient_block = card.find("span", class_="wprm-recipe-ingredient-name")
            if ingredient_block:
                name = ingredient_block.text.strip()
                ingredients.append(name)
        current_recipe["ingredients"] = ingredients

        # Get nutrition values
        nutrition_cards = soup.find_all(
            "span", class_="wprm-nutrition-label-text-nutrition-container"
        )
        for card in nutrition_cards:
            label_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-label"
            )
            value_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-value"
            )
            unit_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-unit"
            )
            if label_element and value_element and unit_element:
                current_recipe[label_element.text.strip()] = " ".join(
                    [value_element.text.strip(), unit_element.text.strip()]
                )

        # Get instructions
        instructions_block = soup.find(
            "ul", class_="wprm-recipe-instructions"
        ).text.strip()
        current_recipe["instructions"] = instructions_block

        # Add to list
        korean_recipes.append(current_recipe)
        # print(current_recipe)

df_korean_recipes = pd.DataFrame(korean_recipes)
# Out:
# Progress: 307, url:https://kimchimari.com/korean-sweets-yakwa-yaksik/ssert/d-artisan/ns-%eb%b6%95%ec%96%b4%eb%b9%b5-bungeoppang/ewoo-bokeum/

# %%
# Convert lists to strings
if "ingredients" in df_korean_recipes.columns:
    df_korean_recipes["ingredients"] = df_korean_recipes["ingredients"].apply(
        lambda x: "; ".join(x) if isinstance(x, list) else x
    )

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("korean_recipes.db")

# Save DataFrame to SQL database
df_korean_recipes.to_sql("recipes", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

print("Data saved to database!")

df_korean_recipes
# Out:
# Data saved to database!
#                                                  title  \
# 0               Seolleongtang (Korean Beef Bone Broth)
# 1                     Sujebi (Hand-Pulled Noodle Soup)
# 2                                Instant Pot Gamjatang
# 3               Instant Pot Tteok Guk (Rice Cake Soup)
# 4               Tteok guk (떡국) – Korean rice cake soup
# ..                                                 ...
# 257  Gluten Free Sweet Red Bean Rice Cake (Tteok Pp...
# 258                       Sweet Rice Punch (Sikhye 식혜)
# 259         Crispy Zucchini Pancakes (Hobak buchimgae)
# 260                 Korean Sweet Rice Dessert (Yaksik)
# 261              Korean Honey Pastry (Yakgwa or Yakwa)
#
#                                                   link  \
# 0    https://kimchimari.com/seolleongtang-korean-be...
# 1    https://kimchimari.com/sujebi-hand-pulled-nood...
# 2    https://kimchimari.com/instant-pot-gamjatang-k...
# 3    https://kimchimari.com/instant-pot-tteokguk-ri...
# 4    https://kimchimari.com/rice-cake-soup-tteokguk...
# ..                                                 ...
# 257   https://kimchimari.com/sweet-red-bean-rice-cake/
# 258           https://kimchimari.com/sweet-rice-punch/
# 259           https://kimchimari.com/hobak-boochimgae/
# 260  https://kimchimari.com/yaksik-korean-sweet-ric...
# 261            https://kimchimari.com/yakgwa-or-yakwa/
#
#                                              image_url  \
# 0    https://kimchimari.com/wp-content/uploads/2024...
# 1    https://kimchimari.com/wp-content/uploads/2023...
# 2    https://kimchimari.com/wp-content/uploads/2018...
# 3    https://kimchimari.com/wp-content/uploads/2018...
# 4    https://kimchimari.com/wp-content/uploads/2011...
# ..                                                 ...
# 257  https://kimchimari.com/wp-content/uploads/2014...
# 258  https://kimchimari.com/wp-content/uploads/2013...
# 259  https://kimchimari.com/wp-content/uploads/2012...
# 260  https://kimchimari.com/wp-content/uploads/2011...
# 261  https://kimchimari.com/wp-content/uploads/2011...
#
#                                             image_data  \
# 0    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 1    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 2    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 3    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 4    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# ..                                                 ...
# 257  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 258  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 259  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 260  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 261  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
#
#                                            description Total Time:  \
# 0    Seolleontang is a bone broth made from boiling...    10 hours
# 1    Sujebi is a fun hand-pulled or hand-torn noodl...  40 minutes
# 2    Instant Pot Gamjatang recipe was a perfect rec...  50 minutes
# 3    Anchovy Broth Tteokguk is a very elegant versi...  28 minutes
# 4    Every New Year’s day,  Koreans make Dduk Guk/T...  45 minutes
# ..                                                 ...         ...
# 257  This deliciously addictive Sweet Red Bean Rice...      1 hour
# 258  Sikhye is a classic Korean dessert drink that ...     8 hours
# 259  Easy Korean Zucchini fritters that is great as...  20 minutes
# 260  A dessert filled with health-promoting ingredi...     2 hours
# 261  Yakgwa(약과) is a traditional Korean sweet pastr...      1 hour
#
#                    Course               Cuisine KoreanCategory  \
# 0                    Soup                Korean        Tang(탕)
# 1          Lunch, noodles                Korean       Myeon(면)
# 2       Main Course, Pork                Korean        Tang(탕)
# 3                    Soup                Korean        Guk (국)
# 4              rice, Soup                Korean        Guk (국)
# ..                    ...                   ...            ...
# 257        Dessert, Snack  Korean, Koreanfusion      Tteok (떡)
# 258       Dessert, Drinks                Korean    Eumryo (음료)
# 259  Appetizer, Side Dish                Korean       Jeon (전)
# 260               Dessert                Korean    Hankwa (한과)
# 261        Dessert, Snack                Korean    Hankwa (한과)
#
#                                            ingredients  ... Fiber: Sugar:  \
# 0    beef bones; water; green onions; beef brisket;...  ...  0.2 g  0.3 g
# 1    all purpose flour; sea salt; water; water; dri...  ...    4 g    1 g
# 2    pork neck bones; cooking sake; potatoes; fresh...  ...    2 g    7 g
# 3    tteokguk tteok; beef stew meat; water; sesame ...  ...    NaN    1 g
# 4    rice cake slices/ovalettes for soup; anchovy s...  ...    NaN    6 g
# ..                                                 ...  ...    ...    ...
# 257  sweet rice flour; sugar; milk; salted butter; ...  ...    1 g    3 g
# 258  yeotkireum; water; short grain rice; sugar; pi...  ...    NaN   14 g
# 259  large Korean Zucchini; onion; Green Chili Pepp...  ...    1 g    1 g
# 260  sweet rice; water; sugar; honey; soy sauce; se...  ...    2 g    1 g
# 261  all purpose flour; sesame oil; soju; honey; ch...  ...    3 g   17 g
#
#     Vitamin A: Vitamin C: Calcium:   Iron:  \
# 0        36 IU       1 mg    76 mg    1 mg
# 1       392 IU       9 mg    63 mg    6 mg
# 2       640 IU     4.5 mg    50 mg  1.8 mg
# 3       180 IU     5.5 mg    46 mg  1.6 mg
# 4      2725 IU     4.3 mg    42 mg  1.8 mg
# ..         ...        ...      ...     ...
# 257     410 IU     0.2 mg   100 mg  0.7 mg
# 258        NaN        NaN     8 mg  0.8 mg
# 259     125 IU    11.1 mg    11 mg  0.7 mg
# 260        NaN     0.4 mg    10 mg  0.6 mg
# 261        NaN        NaN    16 mg  1.3 mg
#
#                                           instructions  \
# 0    Soak beef bones in cold water for 30 min or so...
# 1    Mix flour, salt and water. Form a ball and the...
# 2    Soak pork neck bones in cold water for 30 min....
# 3    If using frozen rice cakes, soak in water for ...
# 4    Prepare the anchovy stock – see My Tips page (...
# ..                                                 ...
# 257  Preheat oven to 350°F or 180°C.In a mixing bow...
# 258  Soak the crushed milled malt barley (yeotkireu...
# 259  Cut Zucchini into 1/4 in slices and then into ...
# 260  You need: a pressure cooker (pressure rice coo...
# 261  Prepare oil for frying.  Note for Yakgwa, we w...
#
#                                                Keyword Trans Fat: Serving:
# 0                                                  NaN        NaN      NaN
# 1            anchovy broth, flour noodles, noodle soup        NaN      NaN
# 2    fall stew, instant pot, one pot meal, perilla ...        NaN      NaN
# 3    beef soup, ddukguk, lunar new year, new year’s...        NaN      NaN
# 4    chinese new year, gluten free, korean new year...        NaN      NaN
# ..                                                 ...        ...      ...
# 257             anko, gluten free, sweets, tteok ppang        NaN      NaN
# 258                  classic, cold, icy, malted barley        NaN      NaN
# 259               crispy, flour batter, squash, summer        NaN      NaN
# 260  gluten free, healthy, korean sweet snack, swee...        NaN      NaN
# 261            deep fried, ginger, sweets, traditional        NaN      NaN
#
# [262 rows x 30 columns]

# %% [markdown]
# ----
#
# ## Scraping Indian Recipes
#
# https://ministryofcurry.com/recipe-search/

# %%
recipes = []

# URL for the recipe index
base_url = "https://ministryofcurry.com/recipe-search/?_paged={}"

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/117.0"
}


# Loop through all pages
for page in range(1, 21):  # Iterate through all pages
    url = base_url.format(page)
    # print(url)
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract recipe cards
    recipe_cards = soup.find_all("div", class_="fwpl-result")
    for card in recipe_cards:
        information = card.find("div", class_="fwpl-item el-cjl7ci")
        title = information.text.strip()
        link_tag = information.find("a")
        link = link_tag["href"]

        # Extract image URL
        image_tag = card.find("img")  # Assuming <img> tag exists in the card
        if image_tag and "data-lazy-src" in image_tag.attrs:
            image_url = image_tag["data-lazy-src"]
            # Download the image content
            image_response = requests.get(image_url, headers=headers)
            if image_response.status_code == 200:
                image_data = image_response.content  # Binary image data
            else:
                print(f"Failed to fetch image for {title}")
                image_data = None
        elif image_tag and "src" in image_tag.attrs:
            image_url = image_tag["src"]
            # Download the image content
            image_response = requests.get(image_url, headers=headers)
            if image_response.status_code == 200:
                image_data = image_response.content  # Binary image data
            else:
                print(f"Failed to fetch image for {title}")
                image_data = None
        else:
            image_url = None
            image_data = None

        # Append to recipes list
        recipes.append(
            {
                "title": title,
                "link": link,
                "image_url": image_url,
                "image_data": image_data,
            }
        )

    print(f"Page {page} scraped successfully!")

print(f"Pages scraped successfully!")
# Out:
# Page 1 scraped successfully!
# Page 2 scraped successfully!
# Page 3 scraped successfully!
# Page 4 scraped successfully!
# Page 5 scraped successfully!
# Page 6 scraped successfully!
# Page 7 scraped successfully!
# Page 8 scraped successfully!
# Page 9 scraped successfully!
# Page 10 scraped successfully!
# Page 11 scraped successfully!
# Page 12 scraped successfully!
# Page 13 scraped successfully!
# Page 14 scraped successfully!
# Page 15 scraped successfully!
# Page 16 scraped successfully!
# Page 17 scraped successfully!
# Page 18 scraped successfully!
# Page 19 scraped successfully!
# Page 20 scraped successfully!
# Pages scraped successfully!

# %%
# Create an empty DataFrame to store all recipes from japanese recipes
indian_recipes = []

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/117.0"
}

for i in range(len(recipes)):  # len(recipes)
    current_recipe = recipes[i]
    url = current_recipe["link"]

    print(f"\rProgress: {i}, url:{url}", end="")

    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    # Parse HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Checks if recipe exists on page
    recipe_cards = soup.find("a", class_="wprm-recipe-jump")

    if recipe_cards:

        # Get Professional title
        current_recipe["title"] = soup.find(
            "h2", class_="wprm-recipe-name"
        ).text.strip()

        # Get recipe description
        description_block = soup.find(
            "div", class_="wprm-recipe-summary wprm-block-text-normal"
        )
        if description_block:
            current_recipe["description"] = description_block.text.strip()

        # Get times
        time_block = soup.find("div", class_="wprm-recipe-total-time-container")
        if time_block:
            time_card = time_block.find(
                "span", class_="wprm-recipe-total_time"
            ).text.strip()
            current_recipe["Total Time"] = time_card
            # time_list = time_block.text.strip()
            # print(time_list)
            # label = ' '.join(time_list[0:2])
            # value = ' '.join(time_list[2:4])
            # current_recipe[label] = value

        # Get type of food
        type_food = soup.find("div", class_="wprm-recipe-tags-container")
        if type_food:
            type_cards = type_food.find_all("div", class_="wprm-recipe-tag-container")
            for card in type_cards:
                string = card.text.strip()
                str_list = string.split(":")
                if str_list:
                    current_recipe[str_list[0]] = str_list[1]

        # Extract ingredients
        ingredients = []
        ingredient_cards = soup.find_all("li", class_="wprm-recipe-ingredient")
        for card in ingredient_cards:
            ingredient_block = card.find("span", class_="wprm-recipe-ingredient-name")
            if ingredient_block:
                name = ingredient_block.text.strip()
                ingredients.append(name)
        current_recipe["ingredients"] = ingredients

        # Get nutrition values
        nutrition_cards = soup.find_all(
            "span", class_="wprm-nutrition-label-text-nutrition-container"
        )
        for card in nutrition_cards:
            label_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-label"
            )
            value_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-value"
            )
            unit_element = card.find(
                "span", class_="wprm-nutrition-label-text-nutrition-unit"
            )
            if label_element and value_element and unit_element:
                current_recipe[label_element.text.strip()] = " ".join(
                    [value_element.text.strip(), unit_element.text.strip()]
                )

        # Get instructions
        instructions_block = soup.find(
            "ul", class_="wprm-recipe-instructions"
        ).text.strip()
        current_recipe["instructions"] = instructions_block

        # Add to list
        indian_recipes.append(current_recipe)
        # print(current_recipe)

df_indian_recipes = pd.DataFrame(indian_recipes)
# Out:
# Progress: 465, url:https://ministryofcurry.com/carrot-sheera/ots/ant/rrot-soup/ds/e/d-in-lush-yogurt/flavored-syrup/

# %%
# Convert lists to strings
if "ingredients" in df_indian_recipes.columns:
    df_indian_recipes["ingredients"] = df_indian_recipes["ingredients"].apply(
        lambda x: "; ".join(x) if isinstance(x, list) else x
    )

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("indian_recipes.db")

# Save DataFrame to SQL database
df_indian_recipes.to_sql("recipes", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

print("Data saved to database!")

df_indian_recipes
# Out:
# Data saved to database!
#                                                  title  \
# 0    Kala Chana Curry {Gujarati Rasawala Kala Chana...
# 1              Chilli Tofu {Bold Flavors, Light Twist}
# 2    Quick & Easy Khichdi: Perfect for Cozy Evening...
# 3                            Pomegranate Mojito Recipe
# 4                                     Easy Malai Laddo
# ..                                                 ...
# 425                        Stuffed Baby Eggplant Curry
# 426                                       Palak Paneer
# 427                                  Vermicelli Sheera
# 428                                  How to Cook Beets
# 429                                      Carrot Sheera
#
#                                                   link  \
# 0        https://ministryofcurry.com/kala-chana-curry/
# 1             https://ministryofcurry.com/chilli-tofu/
# 2                 https://ministryofcurry.com/khichdi/
# 3      https://ministryofcurry.com/pomegranate-mojito/
# 4             https://ministryofcurry.com/malai-laddu/
# ..                                                 ...
# 425  https://ministryofcurry.com/stuffed-baby-eggpl...
# 426          https://ministryofcurry.com/palak-paneer/
# 427     https://ministryofcurry.com/vermicelli-sheera/
# 428     https://ministryofcurry.com/roasted-beetroots/
# 429         https://ministryofcurry.com/carrot-sheera/
#
#                                              image_url  \
# 0    https://ministryofcurry.com/wp-content/uploads...
# 1    https://ministryofcurry.com/wp-content/uploads...
# 2    https://ministryofcurry.com/wp-content/uploads...
# 3    https://ministryofcurry.com/wp-content/uploads...
# 4    https://ministryofcurry.com/wp-content/uploads...
# ..                                                 ...
# 425  https://ministryofcurry.com/wp-content/uploads...
# 426  https://ministryofcurry.com/wp-content/uploads...
# 427  https://ministryofcurry.com/wp-content/uploads...
# 428  https://ministryofcurry.com/wp-content/uploads...
# 429  https://ministryofcurry.com/wp-content/uploads...
#
#                                             image_data  \
# 0    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 1    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 2    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 3    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 4    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# ..                                                 ...
# 425  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 426  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 427  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 428  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 429  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
#
#                                            description  Total Time  \
# 0    Hearty Kala Chana Curry made with black chickp...     9 hours
# 1    A light spin on Chilli Paneer by using tofu an...  30 minutes
# 2    This simple khichdi recipe makes for a nourish...  30 minutes
# 3    Twist to the classic mojito, this Pomegranate ...         NaN
# 4    Easy 5-ingredient Malai Laddu for a quick, del...  35 minutes
# ..                                                 ...         ...
# 425  Baby eggplants stuffed with finely diced onion...  30 minutes
# 426  A delicious north Indian dish with pureed spin...  25 minutes
# 427  Dessert made with thin wheat vermcelli noodles...  15 minutes
# 428  Cooking Beets 2 ways - roast in the oven or st...      1 hour
# 429  An easy and delicious Indian dessert with fine...  25 minutes
#
#              Course        Cuisine                Diet  \
# 0            dinner         Indian          Vegetarian
# 1     dinner, Lunch   Indo-Chinese   Vegan, Vegetarian
# 2            dinner         Indian         Gluten Free
# 3          Beverage       American                 NaN
# 4           Dessert         Indian                 NaN
# ..              ...            ...                 ...
# 425     Main Course         Indian                 NaN
# 426          Entree         Indian                 NaN
# 427         Dessert         Indian                 NaN
# 428           Misc.       American                 NaN
# 429         Dessert         Indian                 NaN
#
#                                            ingredients  ... Potassium:  \
# 0    dry black chana; water; oil; mustard seeds; hi...  ...     411 mg
# 1    extra firm tofu; Kashmiri red chili powder; ko...  ...     475 mg
# 2    short-grain rice; moong dal; water; kosher sal...  ...      42 mg
# 3    pomegrante juice; club soda; ice cubes; fresh ...  ...     438 mg
# 4    ricotta cheese; heavy cream; powdered sugar; c...  ...      50 mg
# ..                                                 ...  ...        ...
# 425  small baby eggplants; yellow onion; ginger; ga...  ...      49 mg
# 426  Spinach; cubed paneer; green chilies; yellow o...  ...     348 mg
# 427  vermicelli; sugar; ghee; almonds; pistachios; ...  ...      69 mg
# 428                            medium Beets; Olive oil  ...     266 mg
# 429  fine sooji; gram flour/besan; whole wheat flou...  ...     268 mg
#
#      Fiber: Sugar: Vitamin A: Vitamin C: Calcium:   Iron:  \
# 0       2 g    2 g     358 IU       2 mg   100 mg    2 mg
# 1       4 g    8 g    1641 IU      87 mg    76 mg    2 mg
# 2       4 g    1 g      50 IU    0.04 mg    20 mg    3 mg
# 3       3 g   20 g     495 IU      17 mg    65 mg    1 mg
# 4    0.02 g    6 g     244 IU     0.1 mg    95 mg  0.2 mg
# ..      ...    ...        ...        ...      ...     ...
# 425     1 g    2 g     150 IU     2.3 mg     6 mg  0.2 mg
# 426     2 g    1 g    5315 IU    19.2 mg   352 mg  1.7 mg
# 427     1 g   37 g        NaN        NaN    13 mg  0.6 mg
# 428     2 g    5 g      25 IU       4 mg    13 mg  0.6 mg
# 429     3 g   27 g    7130 IU     2.8 mg    25 mg  1.7 mg
#
#                                           instructions Cholesterol: Serving:
# 0    Rinse the kala chana thoroughly a couple of ti...          NaN      NaN
# 1    Wrap the tofu in paper towels and place a weig...          NaN      NaN
# 2    Rinse the rice and moong dal thoroughly until ...          NaN      NaN
# 3    Add 2 to 3 lime slices, mint leaves, pomegrana...          NaN      NaN
# 4    In a non-stick pan, add ricotta cheese and coo...        20 mg      NaN
# ..                                                 ...          ...      ...
# 425  Wash and trim extra stem from the baby eggplan...          NaN      NaN
# 426  Boil 3 cups of water in a medium sized pot. Ad...        41 mg      3 g
# 427  Add ghee and vermicelli in a medium pan. Roast...         9 mg      NaN
# 428  Preheat oven to 350 degrees. Wash them thoroug...          NaN      NaN
# 429  Roast sooji, besan, and wheat flour on low-med...        38 mg      NaN
#
# [430 rows x 29 columns]
