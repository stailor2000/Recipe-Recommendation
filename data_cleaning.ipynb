# %% [markdown]
# # Data Cleaning Notebook
#
# This notebook performs exploratory data analysis and cleaning on a given dataset. It includes:
# - Data loading and inspection
# - Analysis and visualisation

# %%
import pandas as pd
import sqlite3
from utils import find_unique_vals, map_to_main_category, clean_column

# %% [markdown]
# ----
#
# ## Data Loading and Initial Inspection
#
# Load the dataset and perform basic inspection.

# %%
# Connect to the SQLite database and retrieve data
conn = sqlite3.connect("./data/japanese_recipes.db")
query = "SELECT * FROM recipes"
df_japanese = pd.read_sql_query(query, conn)
conn.close()

# Columns to keep
df_japanese = df_japanese[
    [
        "title",
        "link",
        "image_url",
        "description",
        "Total Time:",
        "Course:",
        "Cuisine:",
        "ingredients",
        "Calories:",
    ]
]


# Rename columns
df_japanese = df_japanese.rename(
    columns={
        "Total Time:": "total_time",
        "Course:": "course",
        "Cuisine:": "cuisine",
        "Calories:": "calories",
    }
)

# Display basic info about the dataset
print("Dataset Info:")
df_japanese.info()

print("\nSample Data:")
df_japanese.head()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 948 entries, 0 to 947
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        948 non-null    object
#  1   link         948 non-null    object
#  2   image_url    948 non-null    object
#  3   description  948 non-null    object
#  4   total_time   930 non-null    object
#  5   course       940 non-null    object
#  6   cuisine      940 non-null    object
#  7   ingredients  948 non-null    object
#  8   calories     926 non-null    object
# dtypes: object(9)
# memory usage: 66.8+ KB
#
# Sample Data:
#                               title  \
# 0             Yuzu Cha (Citron Tea)
# 1    Japanese Milk Bread (Shokupan)
# 2                    Chicken Chashu
# 3  Gyudon (Japanese Beef Rice Bowl)
# 4               Japanese Beef Curry
#
#                                                 link  \
# 0          https://www.justonecookbook.com/yuzu-cha/
# 1  https://www.justonecookbook.com/japanese-milk-...
# 2    https://www.justonecookbook.com/chicken-chashu/
# 3            https://www.justonecookbook.com/gyudon/
# 4  https://www.justonecookbook.com/japanese-beef-...
#
#                                            image_url  \
# 0  https://www.justonecookbook.com/wp-content/upl...
# 1  https://www.justonecookbook.com/wp-content/upl...
# 2  https://www.justonecookbook.com/wp-content/upl...
# 3  https://www.justonecookbook.com/wp-content/upl...
# 4  https://www.justonecookbook.com/wp-content/upl...
#
#                                          description  total_time       course  \
# 0  Try my easy homemade recipe for Yuzu Cha (Citr...      1 hour       How to
# 1  Japanese Milk Bread is possibly the best versi...     3 hours    Breakfast
# 2  Juicy and tender Chicken Chashu is a lighter v...      1 hour  Main Course
# 3  With thinly sliced beef and tender onions simm...  20 minutes  Main Course
# 4  With tender chunks of beef, potatoes, carrots,...     3 hours  Main Course
#
#     cuisine                                        ingredients   calories
# 0  Japanese                     yuzu; white rock sugar; shochu       None
# 1  Japanese  warm water; sugar; Diamond Crystal kosher salt...  1645 kcal
# 2  Japanese  boneless, skin-on chicken thighs; green onions...       None
# 3  Japanese  onion; green onion/scallion; thinly sliced bee...   657 kcal
# 4  Japanese  onions; unsalted butter; neutral oil; russet p...   426 kcal

# %%
# Connect to the SQLite database and retrieve data
conn = sqlite3.connect("./data/chinese_recipes.db")
query = "SELECT * FROM recipes"
df_chinese = pd.read_sql_query(query, conn)
conn.close()

# Columns to keep
df_chinese = df_chinese[
    [
        "title",
        "link",
        "image_url",
        "description",
        "Total Time:",
        "Course:",
        "Cuisine:",
        "ingredients",
        "Calories:",
    ]
]


# Rename columns
df_chinese = df_chinese.rename(
    columns={
        "Total Time:": "total_time",
        "Course:": "course",
        "Cuisine:": "cuisine",
        "Calories:": "calories",
    }
)

# Display basic info about the dataset
print("Dataset Info:")
df_chinese.info()

print("\nSample Data:")
df_chinese.head()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        905 non-null    object
#  1   link         905 non-null    object
#  2   image_url    905 non-null    object
#  3   description  886 non-null    object
#  4   total_time   845 non-null    object
#  5   course       901 non-null    object
#  6   cuisine      902 non-null    object
#  7   ingredients  905 non-null    object
#  8   calories     837 non-null    object
# dtypes: object(9)
# memory usage: 63.8+ KB
#
# Sample Data:
#                            title  \
# 0  Easy Oyster Mushroom Stir Fry
# 1            Honey Glazed Salmon
# 2                   Shrimp Toast
# 3              Garlic Fried Rice
# 4      Chicken with Garlic Sauce
#
#                                                 link  \
# 0  https://omnivorescookbook.com/easy-oyster-mush...
# 1  https://omnivorescookbook.com/honey-soy-sauce-...
# 2        https://omnivorescookbook.com/shrimp-toast/
# 3   https://omnivorescookbook.com/garlic-fried-rice/
# 4  https://omnivorescookbook.com/chicken-with-gar...
#
#                                            image_url  \
# 0  https://omnivorescookbook.com/wp-content/uploa...
# 1  https://omnivorescookbook.com/wp-content/uploa...
# 2  https://omnivorescookbook.com/wp-content/uploa...
# 3  https://omnivorescookbook.com/wp-content/uploa...
# 4  https://omnivorescookbook.com/wp-content/uploa...
#
#                                          description  total_time     course  \
# 0  A super quick and easy oyster mushroom stir fr...  15 minutes  Side Dish
# 1  A simple yet rich tasting honey glazed salmon ...  55 minutes       Main
# 2  Make these crispy savory shrimp toasts as an a...  40 minutes  Appetizer
# 3  A Chinese style garlic fried rice featuring cr...  25 minutes       Side
# 4  Chicken with garlic sauce is a super easy take...  30 minutes       Main
#
#           cuisine                                        ingredients  calories
# 0         Chinese  oyster mushrooms; peanut oil; garlic; sugar; s...   85 kcal
# 1  Chinese Fusion  salmon filets; salt; sugar; honey; Shaoxing wi...  445 kcal
# 2         Chinese  shrimp; egg white; ginger; garlic; light soy s...  234 kcal
# 3         Chinese  of leftover cooked jasmine rice; soy sauce; oy...  239 kcal
# 4         Chinese  chicken breasts or thighs; Shaoxing wine; salt...  248 kcal

# %%
# Connect to the SQLite database and retrieve data
conn = sqlite3.connect("./data/indian_recipes.db")
query = "SELECT * FROM recipes"
df_indian = pd.read_sql_query(query, conn)
conn.close()

# Columns to keep
df_indian = df_indian[
    [
        "title",
        "link",
        "image_url",
        "description",
        "Total Time",
        "Course",
        "Cuisine",
        "ingredients",
        "Calories:",
    ]
]


# Rename columns
df_indian = df_indian.rename(
    columns={
        "Total Time": "total_time",
        "Course": "course",
        "Cuisine": "cuisine",
        "Calories:": "calories",
    }
)

# Display basic info about the dataset
print("Dataset Info:")
df_indian.info()

print("\nSample Data:")
df_indian.head()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        430 non-null    object
#  1   link         430 non-null    object
#  2   image_url    430 non-null    object
#  3   description  425 non-null    object
#  4   total_time   410 non-null    object
#  5   course       429 non-null    object
#  6   cuisine      429 non-null    object
#  7   ingredients  430 non-null    object
#  8   calories     420 non-null    object
# dtypes: object(9)
# memory usage: 30.4+ KB
#
# Sample Data:
#                                                title  \
# 0  Kala Chana Curry {Gujarati Rasawala Kala Chana...
# 1            Chilli Tofu {Bold Flavors, Light Twist}
# 2  Quick & Easy Khichdi: Perfect for Cozy Evening...
# 3                          Pomegranate Mojito Recipe
# 4                                   Easy Malai Laddo
#
#                                               link  \
# 0    https://ministryofcurry.com/kala-chana-curry/
# 1         https://ministryofcurry.com/chilli-tofu/
# 2             https://ministryofcurry.com/khichdi/
# 3  https://ministryofcurry.com/pomegranate-mojito/
# 4         https://ministryofcurry.com/malai-laddu/
#
#                                            image_url  \
# 0  https://ministryofcurry.com/wp-content/uploads...
# 1  https://ministryofcurry.com/wp-content/uploads...
# 2  https://ministryofcurry.com/wp-content/uploads...
# 3  https://ministryofcurry.com/wp-content/uploads...
# 4  https://ministryofcurry.com/wp-content/uploads...
#
#                                          description  total_time  \
# 0  Hearty Kala Chana Curry made with black chickp...     9 hours
# 1  A light spin on Chilli Paneer by using tofu an...  30 minutes
# 2  This simple khichdi recipe makes for a nourish...  30 minutes
# 3  Twist to the classic mojito, this Pomegranate ...        None
# 4  Easy 5-ingredient Malai Laddu for a quick, del...  35 minutes
#
#            course        cuisine  \
# 0          dinner         Indian
# 1   dinner, Lunch   Indo-Chinese
# 2          dinner         Indian
# 3        Beverage       American
# 4         Dessert         Indian
#
#                                          ingredients  calories
# 0  dry black chana; water; oil; mustard seeds; hi...  246 kcal
# 1  extra firm tofu; Kashmiri red chili powder; ko...  208 kcal
# 2  short-grain rice; moong dal; water; kosher sal...  270 kcal
# 3  pomegrante juice; club soda; ice cubes; fresh ...  110 kcal
# 4  ricotta cheese; heavy cream; powdered sugar; c...   99 kcal

# %%
# Connect to the SQLite database and retrieve data
conn = sqlite3.connect("./data/thai_recipes.db")
query = "SELECT * FROM recipes"
df_thai = pd.read_sql_query(query, conn)
conn.close()

# Columns to keep
df_thai = df_thai[
    [
        "title",
        "link",
        "image_url",
        "description",
        "Total Time",
        "Course",
        "Cuisine",
        "ingredients",
        "Calories:",
    ]
]


# Rename columns
df_thai = df_thai.rename(
    columns={
        "Total Time": "total_time",
        "Course": "course",
        "Cuisine": "cuisine",
        "Calories:": "calories",
    }
)

# Display basic info about the dataset
print("Dataset Info:")
df_thai.info()

print("\nSample Data:")
df_thai.head()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        309 non-null    object
#  1   link         309 non-null    object
#  2   image_url    309 non-null    object
#  3   description  309 non-null    object
#  4   total_time   298 non-null    object
#  5   course       309 non-null    object
#  6   cuisine      309 non-null    object
#  7   ingredients  309 non-null    object
#  8   calories     309 non-null    object
# dtypes: object(9)
# memory usage: 21.9+ KB
#
# Sample Data:
#                                                title  \
# 0  Authentic Thai Beef Satay Recipe With Peanut S...
# 1                  Easy Thai Fish Sauce Wings Recipe
# 2                      Sweet Thai Chili Wings Recipe
# 3         Shrimp Satay Recipe With Thai Peanut Sauce
# 4                 Pork Gyoza Recipe (Pork Dumplings)
#
#                                                 link  \
# 0  https://hungryinthailand.com/thai-beef-satay-r...
# 1     https://hungryinthailand.com/fish-sauce-wings/
# 2  https://hungryinthailand.com/sweet-thai-chili-...
# 3  https://hungryinthailand.com/shrimp-satay-with...
# 4    https://hungryinthailand.com/pork-gyoza-recipe/
#
#                                            image_url  \
# 0  https://hungryinthailand.com/wp-content/upload...
# 1  https://hungryinthailand.com/wp-content/upload...
# 2  https://hungryinthailand.com/wp-content/upload...
# 3  https://hungryinthailand.com/wp-content/upload...
# 4  https://hungryinthailand.com/wp-content/upload...
#
#                                          description  total_time  \
# 0  Enjoy my family’s authentic Thai beef satay wi...     4 hours
# 1  Enjoy perfectly crispy chicken every time with...  35 minutes
# 2  Sweet Thai chili wings recipe with a sticky, s...  40 minutes
# 3  Enjoy this easy shrimp satay recipe with Thai ...  50 minutes
# 4  Make this pork gyoza recipe for easy, homemade...      1 hour
#
#                           course      cuisine  \
# 0  Appetizer, Main Course, Snack         Thai
# 1    Appetizer, Side Dish, Snack  Asian, Thai
# 2               Appetizer, Snack         Thai
# 3               Appetizer, Snack         Thai
# 4               Appetizer, Snack         Thai
#
#                                          ingredients  calories
# 0  beef; of garlic; lemongrass; coriander seeds; ...   83 kcal
# 1  chicken wings; fish sauce; rosdee seasoning po...  670 kcal
# 2  tempura flour; rosdee seasoning powder; ice-co...  239 kcal
# 3  shrimp; coconut milk; yellow curry powder; Ros...  392 kcal
# 4  ground pork; white pepper; sesame oil; shoyu s...  126 kcal

# %%
# Connect to the SQLite database and retrieve data
conn = sqlite3.connect("./data/korean_recipes.db")
query = "SELECT * FROM recipes"
df_korean = pd.read_sql_query(query, conn)
conn.close()

# Columns to keep
df_korean = df_korean[
    [
        "title",
        "link",
        "image_url",
        "description",
        "Total Time:",
        "Course",
        "Cuisine",
        "ingredients",
        "Calories:",
    ]
]


# Rename columns
df_korean = df_korean.rename(
    columns={
        "Total Time:": "total_time",
        "Course": "course",
        "Cuisine": "cuisine",
        "Calories:": "calories",
    }
)

# Display basic info about the dataset
print("Dataset Info:")
df_korean.info()

print("\nSample Data:")
df_korean.head()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        262 non-null    object
#  1   link         262 non-null    object
#  2   image_url    262 non-null    object
#  3   description  260 non-null    object
#  4   total_time   258 non-null    object
#  5   course       262 non-null    object
#  6   cuisine      262 non-null    object
#  7   ingredients  262 non-null    object
#  8   calories     254 non-null    object
# dtypes: object(9)
# memory usage: 18.5+ KB
#
# Sample Data:
#                                     title  \
# 0  Seolleongtang (Korean Beef Bone Broth)
# 1        Sujebi (Hand-Pulled Noodle Soup)
# 2                   Instant Pot Gamjatang
# 3  Instant Pot Tteok Guk (Rice Cake Soup)
# 4  Tteok guk (떡국) – Korean rice cake soup
#
#                                                 link  \
# 0  https://kimchimari.com/seolleongtang-korean-be...
# 1  https://kimchimari.com/sujebi-hand-pulled-nood...
# 2  https://kimchimari.com/instant-pot-gamjatang-k...
# 3  https://kimchimari.com/instant-pot-tteokguk-ri...
# 4  https://kimchimari.com/rice-cake-soup-tteokguk...
#
#                                            image_url  \
# 0  https://kimchimari.com/wp-content/uploads/2024...
# 1  https://kimchimari.com/wp-content/uploads/2023...
# 2  https://kimchimari.com/wp-content/uploads/2018...
# 3  https://kimchimari.com/wp-content/uploads/2018...
# 4  https://kimchimari.com/wp-content/uploads/2011...
#
#                                          description  total_time  \
# 0  Seolleontang is a bone broth made from boiling...    10 hours
# 1  Sujebi is a fun hand-pulled or hand-torn noodl...  40 minutes
# 2  Instant Pot Gamjatang recipe was a perfect rec...  50 minutes
# 3  Anchovy Broth Tteokguk is a very elegant versi...  28 minutes
# 4  Every New Year’s day,  Koreans make Dduk Guk/T...  45 minutes
#
#               course cuisine  \
# 0               Soup  Korean
# 1     Lunch, noodles  Korean
# 2  Main Course, Pork  Korean
# 3               Soup  Korean
# 4         rice, Soup  Korean
#
#                                          ingredients  calories
# 0  beef bones; water; green onions; beef brisket;...   74 kcal
# 1  all purpose flour; sea salt; water; water; dri...  530 kcal
# 2  pork neck bones; cooking sake; potatoes; fresh...  363 kcal
# 3  tteokguk tteok; beef stew meat; water; sesame ...  407 kcal
# 4  rice cake slices/ovalettes for soup; anchovy s...  264 kcal

# %%
# Combine all the separate dataframes
df_combined = pd.concat(
    [df_japanese, df_korean, df_chinese, df_indian, df_thai], ignore_index=True
)

df_combined.head()
# Out:
#                               title  \
# 0             Yuzu Cha (Citron Tea)
# 1    Japanese Milk Bread (Shokupan)
# 2                    Chicken Chashu
# 3  Gyudon (Japanese Beef Rice Bowl)
# 4               Japanese Beef Curry
#
#                                                 link  \
# 0          https://www.justonecookbook.com/yuzu-cha/
# 1  https://www.justonecookbook.com/japanese-milk-...
# 2    https://www.justonecookbook.com/chicken-chashu/
# 3            https://www.justonecookbook.com/gyudon/
# 4  https://www.justonecookbook.com/japanese-beef-...
#
#                                            image_url  \
# 0  https://www.justonecookbook.com/wp-content/upl...
# 1  https://www.justonecookbook.com/wp-content/upl...
# 2  https://www.justonecookbook.com/wp-content/upl...
# 3  https://www.justonecookbook.com/wp-content/upl...
# 4  https://www.justonecookbook.com/wp-content/upl...
#
#                                          description  total_time       course  \
# 0  Try my easy homemade recipe for Yuzu Cha (Citr...      1 hour       How to
# 1  Japanese Milk Bread is possibly the best versi...     3 hours    Breakfast
# 2  Juicy and tender Chicken Chashu is a lighter v...      1 hour  Main Course
# 3  With thinly sliced beef and tender onions simm...  20 minutes  Main Course
# 4  With tender chunks of beef, potatoes, carrots,...     3 hours  Main Course
#
#     cuisine                                        ingredients   calories
# 0  Japanese                     yuzu; white rock sugar; shochu       None
# 1  Japanese  warm water; sugar; Diamond Crystal kosher salt...  1645 kcal
# 2  Japanese  boneless, skin-on chicken thighs; green onions...       None
# 3  Japanese  onion; green onion/scallion; thinly sliced bee...   657 kcal
# 4  Japanese  onions; unsalted butter; neutral oil; russet p...   426 kcal

# %% [markdown]
# ----
#
# ## Data Cleaning
#
# ##### Cleaning of 'cuisine' column

# %%
# Show the types of courses present in df
print(df_combined["cuisine"].value_counts().head(50))
# Out:
# cuisine
# Japanese                          835
# Chinese                           742
# Thai                              304
#  Indian                           285
# Korean                            253
# American                           76
#  American                          72
# hawaii                             37
#  American, Indian                  19
# Asian                              14
# Koreanfusion                       13
#  Italian                           12
# Fusion                             11
# Lao                                10
#  Mexican                           10
#  Thai                              10
# Korean, Koreanfusion                9
# Chinese Fusion                      8
# Asian Fusion                        6
# Asian, Thai                         6
# American, Japanese                  6
# French                              6
# Japanese, Korean                    5
# Taiwanese                           5
# Indian                              4
# Italian                             4
# Filipino                            4
# Vietnamese                          4
# american chinese                    3
# Filippino                           3
#  Ethiopian                          3
# asian american fusion               3
# Chinese, Japanese                   3
# Cantonese, Chinese                  2
#  Indian, Indo-Chinese               2
# Italian, Japanese                   2
#  Chinese                            2
#  Chinese, Indian                    2
#  Japanese                           2
# Mexican                             2
# Japanese, Koreanfusion              2
# Asian, Chinese, Thai                2
# Chinese inspired                    2
# chinese american                    2
# hongkong                            1
# Sichuan                             1
#  French                             1
# Mongolian                           1
#  American, Korean                   1
#  Chinese, Indian, Indo-Chinese      1
# Name: count, dtype: int64

# %%
### Remove all cuisines that aren't the specified asian ones that are being worked with

# Find all cuisines mentioned across all recipes
all_cuisines = find_unique_vals(df_combined, "cuisine")

# Define cuisines to keep
cuisines_to_keep = ["Japanese", "Chinese", "Thai", "Indian", "Korean"]

# Find cuisines to remove from the df
cuisines_to_remove = [item for item in all_cuisines if item not in cuisines_to_keep]

# Remove rows that dont have the key cuisines in it
df_combined["cuisine"] = df_combined["cuisine"].apply(
    lambda x: clean_column(x, cuisines_to_remove)
)
df_combined = df_combined.dropna(subset=["cuisine"]).reset_index(drop=True)

# %%
df_combined["cuisine"].value_counts()
# Out:
# cuisine
# Japanese    837
# Chinese     744
# Thai        314
# Indian      289
# Korean      254
# Name: count, dtype: int64

# %% [markdown]
# ##### Cleaning of 'course' column

# %%
# Show the types of courses present in df
print(df_combined["course"].value_counts().head(50))
# Out:
# course
# Main Course                      488
# Main                             358
# Side Dish                        154
# Appetizer                        147
# Dessert                          142
# Soup                              81
# Main, Side                        78
# Salad                             73
# Side                              71
#  Entree                           49
# Condiments                        39
#  Dessert                          36
# Drinks                            30
# Appetizer, Main                   29
# Appetizer, Side Dish              26
# Appetizer, Snack                  23
# Salad, Side Dish                  22
# Main Course, Soup                 22
# Appetizer, Main Course            22
# Dessert, Snack                    22
# Main Course, Salad                21
# Breakfast                         20
# Snack                             16
# Main Course, Side Dish            16
#  dinner, Lunch                    16
#  Appetizer                        12
# Bakery                            11
#  Main Course                      11
#  Side Dish                        11
# Condiments, How to                11
# Stew                              11
#  dinner, Entree                   10
#  Appetizer, Snack                  9
#  Dessert, Snack                    9
# Main Course, Pork                  8
#  dinner                            8
# Condiment                          8
# Appetizer, Side Dish, Snack        8
#  Snack                             6
# Side Dish, Snack                   6
#  Beverage                          6
# How to                             6
# Appetizer, Main Course, Snack      6
# Beef, Side Dish                    5
#  Breads                            5
# Drink                              5
#  Meal Preparation                  5
# Kimchi                             5
# Porridge                           4
# Main, Snack                        4
# Name: count, dtype: int64

# %%
# Mappings to convert similar categories into one
mapping = {
    "Appetizer": ["Appetizer", "Entree"],
    "Breakfast": ["Breakfast", "Brunch", "Porridge"],
    "Dessert": ["Dessert", "Sweets"],
    "Main Course": ["Main Course", "Main", "Main dish", "Dinner", "main dish"],
    "Side Dish": ["Side Dish", "Side"],
    "Soup": ["Soup", "Stew"],
}

# %%
# Remove rows where column 'course' has NaN
df_combined = df_combined.dropna(subset=["course"])

# Apply the mappings function to the df
df_combined["course"] = df_combined["course"].apply(
    lambda x: map_to_main_category(x, mapping)
)

# Drop rows where 'course' is None
df_combined = df_combined.dropna(subset=["course"]).reset_index(drop=True)

# Show the types of courses present in df
print(df_combined["course"].value_counts())
# Out:
# course
# Main Course                          913
# Side Dish                            289
# Appetizer                            260
# Dessert                              219
# Soup                                 104
# Main Course, Side Dish                95
# Appetizer, Main Course                67
# Breakfast                             56
# Appetizer, Side Dish                  49
# Main Course, Soup                     26
# Breakfast, Main Course                11
# Breakfast, Dessert                     7
# Appetizer, Main Course, Side Dish      5
# Breakfast, Main Course, Side Dish      4
# Appetizer, Breakfast                   2
# Appetizer, Soup                        2
# Appetizer, Main Course, Soup           2
# Breakfast, Side Dish                   2
# Breakfast, Appetizer, Main Course      2
# Appetizer, Side Dish, Soup             1
# Dessert, Side Dish                     1
# Appetizer, Dessert                     1
# Side Dish, Soup                        1
# Breakfast, Appetizer                   1
# Dessert, Appetizer                     1
# Main Course, Side Dish, Soup           1
# Breakfast, Dessert, Side Dish          1
# Name: count, dtype: int64

# %%
df_combined.head()
# Out:
#                               title  \
# 0    Japanese Milk Bread (Shokupan)
# 1                    Chicken Chashu
# 2  Gyudon (Japanese Beef Rice Bowl)
# 3               Japanese Beef Curry
# 4               Japanese Cheesecake
#
#                                                 link  \
# 0  https://www.justonecookbook.com/japanese-milk-...
# 1    https://www.justonecookbook.com/chicken-chashu/
# 2            https://www.justonecookbook.com/gyudon/
# 3  https://www.justonecookbook.com/japanese-beef-...
# 4  https://www.justonecookbook.com/souffle-japane...
#
#                                            image_url  \
# 0  https://www.justonecookbook.com/wp-content/upl...
# 1  https://www.justonecookbook.com/wp-content/upl...
# 2  https://www.justonecookbook.com/wp-content/upl...
# 3  https://www.justonecookbook.com/wp-content/upl...
# 4  https://www.justonecookbook.com/wp-content/upl...
#
#                                          description  total_time       course  \
# 0  Japanese Milk Bread is possibly the best versi...     3 hours    Breakfast
# 1  Juicy and tender Chicken Chashu is a lighter v...      1 hour  Main Course
# 2  With thinly sliced beef and tender onions simm...  20 minutes  Main Course
# 3  With tender chunks of beef, potatoes, carrots,...     3 hours  Main Course
# 4  Jiggly and fluffy Japanese Cheesecake is a cro...      1 hour      Dessert
#
#     cuisine                                        ingredients   calories
# 0  Japanese  warm water; sugar; Diamond Crystal kosher salt...  1645 kcal
# 1  Japanese  boneless, skin-on chicken thighs; green onions...       None
# 2  Japanese  onion; green onion/scallion; thinly sliced bee...   657 kcal
# 3  Japanese  onions; unsalted butter; neutral oil; russet p...   426 kcal
# 4  Japanese  unsalted butter; large eggs (50 g each w/o she...  3560 kcal

# %%
# Find all ingredients mentioned across all recipes
find_unique_vals(df_combined, "ingredients")
# Out:
# {'oranges',
#  'Homemade Oxtail Broth',
#  'rosemary',
#  'shishamo (smelt)',
#  'boneless skinless breast (or chicken thigh)',
#  'unbleached sugar',
#  'lemon zest',
#  'dried glass/cellophane noodles (harusame)',
#  'canned crushed tomatoes',
#  'coconut sugar',
#  'Sweet bean paste',
#  'la-yu (Japanese chili oil)',
#  'orange juice',
#  'skin-on Japanese-style salmon fillets',
#  'lily bulb',
#  'arugula',
#  'extra soft tofu (순두부 Soondubu)',
#  'Korean Curry Sauce Mix',
#  'low-sodium beef broth',
#  'black pepper powder',
#  'beef broth',
#  'Frozen Moist Short Grain Rice Flour',
#  'small batch cilantro',
#  'rice vinegar (unseasoned)',
#  'cardamoms',
#  'Mexican-style shredded cheese',
#  'turmeric',
#  'fresh milk',
#  'long-grain basmati rice',
#  'Moo shu pancakes',
#  'fresh lo mein noodles',
#  'Vegetable oil for deep-frying',
#  'shredded unsweetened coconut',
#  'crushed red pepper (red pepper flakes)',
#  'potato',
#  'dried squid strips (ojingeochae)',
#  'dried woodear mushrooms',
#  'cooking spray',
#  'whole milk',
#  'mango chutney',
#  'sugar or to taste',
#  'dried anchovies for soup',
#  'beef brisket, fat trimmed',
#  'sliced white bread',
#  'vegetable oil (if pan frying)',
#  'big pieces of dried seaweed for soup',
#  'fresh lemon juice',
#  'Thai holy basil',
#  'grated dry coconut',
#  'soju',
#  'a handful of bean sprouts',
#  'cashews',
#  'distilled white vinegar',
#  'cashews broken into pieces',
#  'papery shrimp',
#  'full fat or Greek yogurt',
#  'beef bones',
#  'large russet potatoes',
#  'watermelon radish',
#  'thumbnail ginger',
#  'packed Thai basil leaves',
#  'toasted bread',
#  'ripe mangoes',
#  'Hand-pulled noodles or other fresh noodles',
#  'flower-shaped ham',
#  'imitation crab legs',
#  'white onions',
#  'rock sugar',
#  'salmon',
#  'long green onion)',
#  'diced mango',
#  'toasts',
#  'red onion',
#  'button mushrooms',
#  'freshly grated nutmeg',
#  'dumpling wrappers',
#  'cubed carrot',
#  'red bell pepper',
#  'jaggery',
#  'miso',
#  'shell-on baby dried shrimps',
#  'red radishes',
#  'Kosher Salt',
#  'catfish filets',
#  'molasses',
#  'purple cabbage. thinly sliced and chopped',
#  'rava',
#  'coarsely ground roasted peanuts',
#  'small tomatoes',
#  'safflower oil',
#  'big cloves garlic',
#  'dash of black pepper',
#  'coarsely ground black pepper powder',
#  'sliced bamboo shoots',
#  'green onion white part',
#  'vanilla ice cream',
#  'bunch swiss chard',
#  'whole green cardamoms',
#  'jin kanjang',
#  'whole coriander seeds',
#  'skin-on salmon fillets',
#  'ikura (salmon roe)',
#  'yuzu',
#  'butter and/or chicken fat from the chicken',
#  'unsweetened full fat coconut milk',
#  'gochugaru (korean red chili powder)',
#  'large potato',
#  'Pete and Gerry’s Organic Eggs',
#  'wonton wrappers',
#  'plum syrup',
#  'vanilla extract',
#  'honey soy sauce chicken',
#  'Chopped walnuts and / or raw sugar',
#  'handwa flour',
#  'aburaage (deep-fried tofu pouch)',
#  'Omija (Five Flavor Berry) Tea',
#  'beef',
#  'firm silken tofu',
#  'rice cake',
#  'chopped cilantro',
#  'vine-ripe tomatoes',
#  'raw unsalted Cashews',
#  'whole rotisserie chicken',
#  'cheddar cheese',
#  'ebi fry',
#  'ghee or butter',
#  'white wine',
#  'a large bowl lukewarm water',
#  'yakisoba sauce',
#  'wontons',
#  'lemongrass stalks',
#  'prik nam som',
#  'thyme',
#  'green onions or 1 korean leek',
#  'chili sauce',
#  'cilantro (coriander)',
#  'dashi-included miso',
#  'fresh chow mein noodles',
#  'Black sesame seeds',
#  'loose black tea',
#  'sweet bean paste',
#  'white cabbage',
#  'Wonton Wrappers',
#  'unsweetened cocoa powder',
#  'Lettuce leaves',
#  'fresh lime juice',
#  'a silicone or cheese cloth liner for the steamer if no pine needles',
#  'fine besan / gram flour',
#  'hidaka kombu',
#  'Japanese sweet potatoes (Satsumaimo)',
#  'curly green or purple kale',
#  'packed dill',
#  'Chinese cabbage',
#  'Pork and napa cabbage',
#  'bunch of your favorite edible flowers',
#  'unsalted smooth peanut butter',
#  'ajwain',
#  'matcha',
#  'daikon',
#  'thai red chili',
#  'pickled garlic juice',
#  '120 fresh seaweed strips or 1 oz. dried kombu',
#  'Crushed roasted peanuts',
#  'peeled shrimp',
#  'whole dried chili peppers',
#  'Knorr® Chicken Powder',
#  'potato (1 small russet or 2 yukon potatoes)',
#  'dried anchovies',
#  'dried chrysanthemum buds',
#  'smoked paprika powder',
#  'egg white',
#  'cayenne powder',
#  'octopus',
#  'sliced almonds for garnish',
#  'Chinese white rice vinegar',
#  'flat green beans',
#  '3 to 5 lbs / 1.5 to 2 kg whole chicken',
#  'shishito/green chili peppers',
#  'block',
#  'ground toasted Sichuan peppercorn',
#  'Hikari Organic White Miso – 520 mg sodium/12 g',
#  'green peas',
#  'dash of red pepper powder',
#  'homemade kansui',
#  'split roasted chana daal',
#  'riced cauliflower',
#  'head garlic',
#  'sausage of your choice and/or Spam',
#  'wheat noodles',
#  'yellow potatoes',
#  'green chilis',
#  '2.6 pounds fresh hawthorn berries',
#  'ground turkey',
#  'roasted peanuts',
#  'medium size onion',
#  'set of Chinese five-spice set',
#  'crushed roasted peanuts',
#  'white fish',
#  'urad daal',
#  'chinese chives',
#  'real or imitation crabmeat',
#  'thick sweet potato starch',
#  'urad dal',
#  'napa cabbage leaves',
#  'Chinese chili peppers',
#  'headless shell-on shrimp',
#  'Thai red curry paste',
#  'gochujang',
#  'handvo flour',
#  'AP flour',
#  'cinnamon powder',
#  'green peppers',
#  'coarse rava',
#  'raspberries',
#  'Thai chili',
#  'chicken feet',
#  'Chinese sesame oil',
#  'chili powder and extra for grilling',
#  'golden needle mushrooms',
#  'medium yellow onion',
#  'cold milk',
#  'cream cheese',
#  'big carrots',
#  'freshly ground Sichuan peppercorns',
#  'Boiled or fried eggs',
#  'cashew',
#  'baby abalone',
#  'Peanut oil or olive oil',
#  'provolone cheese',
#  'Chrysanthemum leaves or Crown Daisies',
#  'cilantro for garnishing',
#  'dudhi',
#  'cooking sake (or mirin)',
#  'yuzu-flavored tobiko (flying fish roe)',
#  'homemade flavored sweet soy sauce',
#  'takuan (pickled daikon radish)',
#  'frozen vegetable mix',
#  'finely chopped cilantro',
#  'shredded cabbage',
#  'Idli Batter',
#  'korean red chili paste',
#  'atap fruit',
#  'Fried shallot for garnish',
#  'Garlic',
#  'acacia leaves',
#  'butter lettuce leaves',
#  'mirim or cooking sake',
#  'heads Chinese leafy greens',
#  'Greek yogurt for garnish',
#  'reserved tomato blanching water',
#  'shokupan (Japanese milk bread)',
#  'chopped green cabbage',
#  'ground lean pork',
#  'frozen tater tots',
#  'dried thin wheat noodles or somen noodles',
#  'boneless beef chuck roast',
#  'reserved seafood sauce',
#  'coarsely ground black pepper',
#  'cumin',
#  'Soy sauce',
#  'overnight jasmine rice (or other medium grain rice)',
#  'kimchi liquid',
#  'Bamboo shoot',
#  'Toasted sesame seeds',
#  'red shiso leaves (perilla)',
#  'Chinese eggplant (about 9 oz. / 270 g)',
#  'Chinese eggplant (or regular eggplant)',
#  'oysters',
#  'Tofu sheets',
#  'boneless skinless chicken breasts or thighs',
#  '1 tablespoon roasted sesame seeds for garnish',
#  'non-fat dry milk powder',
#  'a handful Chinese celery',
#  'idli rice',
#  'silkie chicken',
#  'eggplants (about 1 large Chinese eggplant or 1/2 American eggplant)',
#  'ginger',
#  'lemon juice',
#  'freshly ground  black pepper',
#  'sponge gourd',
#  'Garnish',
#  'Tamagoyaki (Easy Version)',
#  'shredded mozzarella cheese',
#  'light cream or coffee cream',
#  'Dhokli',
#  'thin egg noodles',
#  'small carrot',
#  'big eggs',
#  'tomatoes',
#  'Manila clams',
#  'julienned carrot',
#  'water',
#  'pork belly, beef stew meat, chicken breast or thighs',
#  'dried thin rice vermicelli noodles',
#  'small dried anchovies for stir fry',
#  'Hawaiian ogo seaweed',
#  'Coca-Cola (12 oz / 350 ml can)',
#  'gulkand/rose preserve',
#  'Chinkiang vinegar',
#  'handful of green onions',
#  'Sea salt to taste',
#  'Sweet Chili Sauce',
#  'unsweetened coconut frozen or dry',
#  'sliced onion',
#  'fresh mint',
#  'chopped fresh dill leaves',
#  'sweet red bean paste (anko)',
#  'uncooked Japanese short-grain brown rice',
#  'rice water',
#  'baked tofu',
#  'kimchi',
#  'fresh Thai chili peppers',
#  'bitter melons',
#  'spaghetti',
#  'split red lentils/masoor daal or mung daal',
#  'frozen seafood mix',
#  'white lotus seeds',
#  'coriander root',
#  'calcium hydroxide',
#  'mixed fruit or vanilla essence',
#  'black cumin seeds',
#  'pineapple juice',
#  'cubanelle peppers',
#  'cilantro to garnish',
#  'cinnamon stick',
#  'udon noodles (total 17-oz / 500 g)',
#  'prik chi fa chili',
#  'cranberries',
#  'whole star anise pod',
#  'sliced pistachios',
#  'small red onion finely diced',
#  'braising liquid',
#  'fresh thyme',
#  "bird's eye chili",
#  'golden mountain sauce',
#  'rum extract',
#  'soy sauce',
#  'dried mung bean vermicelli noodles',
#  'Homemade Shiso Pesto',
#  'whole raw cashews',
#  'handful of Daikon Sprouts',
#  'kinshi tamago ((shredded) thin egg crepe)',
#  'SPAM',
#  'somen noodles (2 bundles)',
#  'head of garlic',
#  'prawn',
#  'Guk Ganjang  (Korean soup soy sacue)',
#  'Shaoxing Chinese wine',
#  'natural cooking cream',
#  'baby squash',
#  'dried jujubes',
#  'A small pinch of dried wood ear mushrooms',
#  'Vegan',
#  'plum sauce',
#  'rice wine',
#  'brown sugar',
#  'all-purpose chili garlic sauce',
#  'liquid from the jar of fermented tofu',
#  'Doenjang (soybean paste)',
#  'Korean radish',
#  'fine sea salt',
#  'Korean Tempura Mix',
#  'shiso leaves (perilla/ooba)',
#  'liqueur of your choice',
#  'red or yellow pepper',
#  'of black pepper',
#  'chickpeas',
#  'rice',
#  'white sugar',
#  'dried tangerine peel',
#  'dried pink shrimp',
#  'green cabbage',
#  'Optional handful of vegetables of your choice (green beans, onion, peppers and/or tomato work great)',
#  'glass noodles',
#  'Gruyere cheese',
#  'short grain white rice',
#  'ume plum compote',
#  'sliced almonds',
#  'fine rava/semolina',
#  'small seoul green cabbage',
#  'Lotus root',
#  'pickled onions',
#  'yogurt',
#  'full fat yogurt',
#  'Spicy Bean Sprout Salad',
#  'large carrot',
#  'chocolate or vanilla ice cream',
#  'coconut frozen',
#  'lime',
#  'salmon fillet, wild caught',
#  'dried shiitake',
#  'Salmon',
#  'fresh wheat noodles, or 5 oz / 140 g dried noodles',
#  'Chili oil',
#  'moong dal',
#  'wine',
#  'Chinese chili flakes',
#  'Korean Red Chili powder',
#  'sweet onion',
#  'Dried Kelp (Dasima or Kombu)',
#  'Pork Belly',
#  'pan drippings',
#  'sea salt and freshly ground black pepper',
#  'small head broccoli',
#  'wonton wrapper or mandupi (만두피)',
#  'Saikyo miso (Kyoto-style white miso)',
#  'package of Vietnamese rice paper',
#  'broiled tofu (yaki dofu)',
#  'gyoza wrappers',
#  'Chinese cauliflower (or regular cauliflower)',
#  'Korean red pepper bean paste',
#  'vegetable oil for frying',
#  'kimchi juice',
#  'milk',
#  'salt or to taste',
#  '1 cup chicken stock (or 2 cups, if you want the soup to be extra rich)',
#  'cut in wedges',
#  'yuba (Japanese-style soft tofu skin)',
#  'big slice ginger',
#  'Fermented tofu',
#  'cashews raw and unsalted',
#  'well-marbled beef steak',
#  'good-quality dark chocolate (70% cacao)',
#  'sea salt for radish',
#  'fruits of your choice',
#  '(2 in square) dried kelp (다시마 Dashima) for broth',
#  'Shaoxing Wine',
#  'shredded dry coconut',
#  'packaged frozen dumpling wrappers',
#  'almond flour',
#  'skinless chicken breast',
#  'sautéed spinach',
#  'green plum syrup',
#  'curry powder',
#  'coriander powder',
#  'crispy flour mix',
#  'maple syrup',
#  'food coloring',
#  'Malony (glass noodles)',
#  'purple cabbage',
#  'regular cabbage (or 1/2 head Taiwanese flat cabbage)',
#  'filtered water',
#  'pistachios sliced',
#  'Round rice paper wrappers',
#  'large swiss chard',
#  'zha cai',
#  'shirasu (boiled salted baby anchovies)',
#  'all-purpose flour (plain flour)',
#  'toasted sesame oil',
#  'chicken',
#  'kelp broth',
#  'sweet potatoes',
#  'thinly sliced pistachios',
#  'hing {asafetida}',
#  'rice water or water',
#  'Korean Soy Sauce',
#  'WAFU Spicy Mayonaizu',
#  'Baby bok choy',
#  'Short Grain Rice',
#  'cilantro or Thai basil leaves',
#  'whole bone in chicken',
#  'tom yum paste',
#  'Thai bird’s eye chilis',
#  'jalapeno sliced into 8 wedges',
#  'chopped nuts',
#  'sea salt',
#  'hatcho miso',
#  'garlic pressed',
#  'Korean red chili pepper',
#  'maraschino cherries',
#  'cilantro handful',
#  'gluten-free soy sauce',
#  'gluten free flour',
#  'Seasoning packages from your instant ramen',
#  'umeboshi (Japanese pickled plum)',
#  'thinly sliced short rib',
#  'of garlic',
#  'wheat noodles or rice noodles for gluten-free',
#  'fenugreek leaves',
#  'avocado oil',
#  'tomato finely diced',
#  'steamed jasmine rice',
#  'soboro don',
#  'small grey squash or zucchini',
#  'fresh ginger',
#  'Light soy sauce',
#  'Chopped green onion for garnish',
#  'rice papers',
#  'dried kelp, one 9”x15” sheet',
#  'flour for dusting',
#  'Dried Omija (Five Flavor Berry)',
#  'black soy beans (Seoritae), soaked',
#  'unsweetened natural creamy peanut butter',
#  'unagi (freshwater eel) fillets',
#  'King oyster mushrooms',
#  'fresh berries',
#  'bamboo shoot',
#  'Salt to taste',
#  'sweet rice/glutinous rice (mochigome)',
#  'twine',
#  'dried goji berries',
#  'homemade braised beef shank',
#  'bunches green onions',
#  'tteok rice powder',
#  'shrimps',
#  'grated unsweetened coconut',
#  'celery',
#  'block tofu',
#  'white sparkling sugar',
#  'Corn on the cob',
#  'beans sprouts',
#  'dry shrimp',
#  'white fish filet (catfish, tilapia, sea bass, or sole)',
#  'Fried eggs',
#  'American cucumber',
#  'and 1/2 tablespoons vegetable oil',
#  'plain Greek yogurt',
#  'pork chops',
#  'maida all-purpose flour',
#  'fresh noodles',
#  'finely chopped nuts',
#  'white wine vinegar',
#  'servings noodles',
#  'spear squid',
#  'dried Chinese jujubes',
#  'butter or ghee',
#  'mixed green salad to serve with',
#  'Homemade Oxtail Broth and Meat',
#  'organic firm tofu',
#  'white poppy seeds',
#  'large banana leaves',
#  'vanilla and/or strawberry ice cream',
#  'dry sherry',
#  'kanten (agar) powder',
#  'palm sugar',
#  'Pork with shiitake mushrooms',
#  'natto (fermented soybean)',
#  'lime wedge',
#  'chopped scallion',
#  'dried peeled split, mung beans',
#  'chives or parsley',
#  'sesame',
#  'pickle',
#  'bread flour',
#  'fresh ripe pineapple',
#  'dried red chili pepper',
#  'tonkatsu',
#  'fresh pine needles',
#  'Sliced tomato, onion, and lettuce leaves for toppings',
#  'whole head of garlic',
#  'Kimchi  with liquid',
#  'bamboo shoots',
#  'doenjang',
#  'Date Tamarind Chutney',
#  '14 oz. / 400 g block firm',
#  'hot dog buns',
#  'steamed monk fish liver (ankimo)',
#  'boneless skinless chicken breast (or thighs)',
#  'chilled unsalted butter',
#  'desiccated coconut',
#  'ripe mango',
#  'jalapeno pepper',
#  'Pompano / Pomfret',
#  'instant yeast',
#  'potato starch',
#  'purple potatoes',
#  'chopped fresh cilantro',
#  'Rose petals & pistachios for garnish',
#  'pea eggplant',
#  'small persian cucumbers',
#  'well-marbled pork ribs',
#  'red bean paste',
#  'Korean Soup Soy Sauce',
#  'package of spring roll wrappers',
#  'medium onion',
#  'rose petals',
#  'shredded nori seaweed (kizami nori)',
#  'loosely packed orange zest',
#  'medium red onion',
#  'Packaged dried noodles',
#  'fresh mung bean sprouts',
#  'ground ginger',
#  'bottle gourd',
#  'lobster tails with shell',
#  '400 grams fresh lotus root',
#  'Reynolds Wrap® Heavy Duty Foil',
#  'a handful of green chilies',
#  'dried fruit mix',
#  'Homemade chili oil',
#  'nutmeg powder',
#  'Korean baby zucchini',
#  'sesame seeds',
#  'ice',
#  'bittersweet chocolate',
#  'of salt',
#  'homemade orange sauce',
#  'crab',
#  'graham crackers',
#  'tamarind paste',
#  'roasted sesame seeds',
#  'rice cake for ddukboki',
#  'light soy sauce',
#  'House Foods extra firm tofu',
#  'large pieces ginger',
#  'pomegranate seeds',
#  'rakkyo (Japanese pickled scallion)',
#  'green beans',
#  'rosdee flavor seasoning',
#  'baby bok choy',
#  'gluten-free pasta',
#  'flake sea salt',
#  'tomato puree',
#  'Homemade Chashu (Japanese Braised Pork Belly)',
#  'kimchi juice (drained from jar)',
#  'batch asparagus',
#  'homemade tofu pudding',
#  'squid',
#  'deep-fried firm tofu cutlet (atsuage)',
#  'gochu yangnyum (chili sauce)',
#  'Tteokguk Tteok (Korean sliced rice cakes)',
#  'boneless skinless chicken thighs',
#  'minari or water dropwort or water cress',
#  'dried scallop',
#  '1 to 2 tablespoons homemade chicken stock, or 1/2 teaspoon chicken bouillon powder',
#  'half to one dozen fresh eggs',
#  'finely minced ginger',
#  'freshly grated coconut',
#  'tteokguk tteok',
#  'white vinegar',
#  'large boneless skinless chicken breast',
#  'kaeng som curry paste',
#  'Kashmiri chili powder',
#  'fish cake',
#  'sweet bell peppers',
#  'flank steak',
#  'watercress',
#  'brownies',
#  'white ground pepper',
#  'Crispy nori sheets',
#  'garlic clove',
#  'karaage',
#  'pack of 14 oz extra firm tofu',
#  'Cooking Sake',
#  'potatoes',
#  'diced tomatoes',
#  'black tiger prawns',
#  'fried dried chilies',
#  'Sriracha sauce or homemade chili oil',
#  'whole cumin seeds',
#  'daikon radish',
#  'almonds',
#  'lamb',
#  'aamchoor powder',
#  'Oil for frying',
#  'fermented fish sauce',
#  'honey',
#  'tobiko (flying fish roe)',
#  'lemons juiced',
#  'stalks broccoli rabe',
#  'cardamom powder',
#  'anaheim pepper or other hot pepper of your choice',
#  'pork bones',
#  'white fish (sea bass, tilapia etc)',
#  'green chili',
#  'noodle boiling water',
#  'melted butter or vegetable oil',
#  'oil for cooking',
#  'chili powder',
#  'garlic powder',
#  'Shirataki noodles (konnyaku)',
#  'green onions – cut 4 green onions into 2 inch',
#  'Hikari Miso Shio Koji',
#  'Spinach',
#  'soy sauce or tamari',
#  'chickpea flour',
#  'ice cream of your choice',
#  'Kawan Parathas',
#  'squid tubes',
#  'balsamic vinegar',
#  'misugaru',
#  'low-sodium chicken broth',
#  'thin slices Spam',
#  'dried alkaline noodles',
#  'peeled and grated bottle gourd',
#  'Mustard',
#  'freshly coarsely ground Sichuan peppercorns',
#  'fermented black beans',
#  'Indian green chilies',
#  'small corn on the cob',
#  'Pete and Gerry’s Organic Egg yolks',
#  'sour cream',
#  'vegetable oil for brushing',
#  'jaggery or brown sugar',
#  'sliced firm tofu',
#  'purple onion',
#  'dried rice vermicelli',
#  'Homemade soy sauce egg',
#  'garlic salt with dried parsley',
#  'blackberries',
#  'small daikon radish',
#  'large dried or fresh shitake mushrooms',
#  'fresh wheat noodles',
#  'sliced sticky rice cakes',
#  'grated coconut',
#  'and 1/2 teaspoons salt',
#  'Onion',
#  'fresh rice vermicelli',
#  'beef ribeye steak',
#  'cabbage kimchi',
#  'big mangoes',
#  'medium carrots',
#  'long grain basmati rice',
#  'cloves of garlic',
#  'chicken thigh (about 1 thigh)',
#  'boneless skinless chicken breast (or 2 chicken thighs)',
#  'green onion',
#  'kalbi bones with meat',
#  'metal chopstick or a candy stick',
#  'chili flakes',
#  'sweet corn',
#  'ground Sichuan peppercorns',
#  'Vegetable or Canola Oil for frying',
#  'katsuobushi (dried bonito flakes)',
#  'fresh Alkaline noodle',
#  "Sea Salt (Trader Joe's)",
#  'bean sprouts',
#  'orange bell pepper',
#  'cherry tomatoes',
#  'flour tortillas',
#  'walnut half',
#  'homemade chili oil with 1 to 2 tablespoons of its “sediment”',
#  'ricotta cheese',
#  'toor daal',
#  'vanilla essence',
#  'bay leave',
#  'red chile peppers',
#  'medium-sized tomato',
#  'fermented salted shrimp',
#  'handfuls dried lily flowers',
#  'pomegranate',
#  'hot pot bases',
#  'pickles',
#  'Korean Cheonilyeom Sea salt',
#  'chili oil or fresh diced red chili peppers',
#  'dried red chilis',
#  'Sriracha sauce',
#  'soy milk',
#  'rice or apple vinegar',
#  'uncooked Japanese short-grain white rice',
#  'guk ganjang (Korean soup soy sauce)',
#  'gelatin',
#  '1 Thai chili pepper (or 1/2 serrano pepper), chopped',
#  'thin poha',
#  'green onions chopped',
#  'thin wheat noodles',
#  'seafood mix',
#  'salt',
#  'medium protein flour or pastry flour',
#  '4 to 5 Thai chili peppers for garnish',
#  'Mom’s Garam Masala',
#  'Japanese or Chinese eggplant',
#  'XO Sauce',
#  'Sous-vide precision cooker',
#  'toor dal',
#  'fresh ramen noodles',
#  'king oyster mushroom (eringi)',
#  'dried kelp',
#  'Shimeji',
#  'cardamom pods',
#  'tapioca flour',
#  'salted water for cooking',
#  'asafetida powder',
#  'dry thin rice vermicelli',
#  'salt and pepper',
#  'small shucked oysters',
#  'medium-firm tofu (momen dofu)',
#  'melted butter or 1 Tbsp veg. oil',
#  'barley',
#  'red chili pepper',
#  'sprinkles of your choice',
#  'mato',
#  'sheets dried or fresh bamboo leaves',
#  'chicken breasts (or thighs)',
#  'Chinese pickled radish',
#  'ground corinader',
#  'white pepper',
#  'Black pepper',
#  'ground raw beef',
#  'lemon wedges',
#  'chicken thighs (or chicken breast)',
#  'slivered almond',
#  '2 potatoes (or 1 daikon radish, or a few carrots)',
#  'yukari rice seasoning',
#  'Korean soy sauce for soup',
#  'Mugwort (Ssuk)',
#  'Sugar',
#  'jalapeno sliced into 4 wedges',
#  'frozen shrimp',
#  'thin Chinese wheat noodles',
#  'greek yogurt',
#  'Komatsuna',
#  'green onions, chopped',
#  'ume plum vinegar',
#  'Enoki (golden needle mushrooms)',
#  'grated ginger',
#  'zucchini',
#  'Korean soup soy sauce',
#  'condensed  milk',
#  'ginger grated',
#  'raw peanuts',
#  'Fried egg',
#  'grated coconut meat',
#  'kobucha (kombucha)',
#  'mussel meat',
#  'Chinese long eggplant',
#  'dried sea laver',
#  'black beans',
#  'menma (seasoned bamboo shoots)',
#  'pickle masala',
#  'kombu',
#  'bone-in skin-on chicken legs',
#  'baked croquettes',
#  'king oyster mushrooms',
#  'Chinese celery',
#  'Shrimp cake, fish cake, and fish tofu',
#  'roasted coconut shreds',
#  'lemon basil',
#  'sausage casing',
#  'brown mushrooms',
#  'rendered chicken fat',
#  'pine nuts/dried jujubes/citron syrup/mint leaves',
#  'yellow peppers',
#  'broccoli florets',
#  'Yukon gold potatoes',
#  'Chinese eggplant',
#  'grated ginger juice',
#  'Sichuan pickled mustard greens',
#  'dried chickpeas',
#  'salad mix',
#  'Shrimp Tempura',
#  'almond extract',
#  'can coconut milk',
#  'bouillon cube',
#  'smoked paprika',
#  'Chinese broccoli',
#  'Sea salt and black pepper to taste',
#  'peeled and deveined shrimp',
#  'Oil spray',
#  'sliced Spam',
#  'golden mountain seasoning sauce',
#  'chicken drumsticks',
#  'homemade chili oil',
#  'chili pepper flakes',
#  'Pacific Foods Organic Low Sodium Chicken Broth',
#  'kinako (roasted soybean flour)',
#  'cashew nuts',
#  'breadcrumbs',
#  'abalone',
#  'Doenjang (Korean Soy Bean Paste)',
#  'low sodium chicken broth',
#  'and 1/2 tablespoons light soy sauce',
#  'large eggs (50 g each w/o shell)',
#  'light brown sugar',
#  'thinly sliced top sirloin or other tenderloin',
#  'Korean hot pepper flakes',
#  'long eggplants',
#  'bone-in chicken leg quarters',
#  'crunchy chow mein noodles',
#  'frozen corn',
#  'Lime wedges',
#  'Pacific Foods Organic Unsweetened Coconut Original',
#  'pork ribs (2.5 to 4 lbs)',
#  'sashimi-grade scallop',
#  'minced garlic',
#  'coarsely chopped raw cashews',
#  'green tomatoes',
#  'shrimps or prawns',
#  'onion powder',
#  'mint chopped',
#  'Japanese eggplant',
#  'mirin or white wine',
#  'dried shitake mushrooms',
#  'pumpkin puree',
#  'heaping tablespoons unsalted natural peanut butter',
#  'Shredded carrots and cucumber',
#  'ice cold water',
#  'powdered milk',
#  'instant noodles',
#  'freshly grounded black pepper',
#  'a small handful of mint',
#  'meatballs / fish balls',
#  'peeled-split mung bean',
#  'bok choy flower',
#  'penne pasta',
#  'Small Red or green peppers',
#  'rice vinegar',
#  'pork ribs (about 1.8 kg / 4 lbs)',
#  'handful buckwheat sprouts',
#  'split red lentils',
#  'tamarind sauce',
#  'Spanish saffron',
#  'Ghirardelli premium white chocolate chips **',
#  'egg yolks',
#  'firm tofu (14 oz / 396 g per block)',
#  'reserved pasta water',
#  'cold water',
#  'asparagus spears',
#  'kale',
#  'Chinese broccoli (Gai Lan)',
#  'head red cabbage',
#  'Optional Chopped fresh or dried parsley to garnish',
#  'brown sesame seeds',
#  'cloud ear mushrooms',
#  'makhana',
#  'bell pepper (or sweet pepper, or both)',
#  'confectioners sugar',
#  'medium-sized yellow onion',
#  '1/8 teaspoon chili powder',
#  'Meyer lemons',
#  'mixed frozen veggies',
#  'dry oriental mustard',
#  'canola oil',
#  'full fat coconut milk',
#  'carom seeds',
#  'rice cake slices/ovalettes for soup',
#  'Salt and Pepper',
#  'black salt',
#  'crushed garlic',
#  'spicy salted pollock roe or cod roe (karashi mentaiko)',
#  'Homemade sweet chili sauce',
#  'Beef balls',
#  'a handful of chilies',
#  'canned chickpeas',
#  'fingerroot',
#  'saffron',
#  'seedless cucumber',
#  'zucchini (or 1 pound russet potato)',
#  'five spice powder',
#  'splash of sesame oil',
#  'Raw egg yolks',
#  'matsutake mushrooms',
#  'red fermented bean curd',
#  'small thumb ginger',
#  'black mustard seeds',
#  'shrimp tempura',
#  'white chocolate',
#  'overripe bananas',
#  'fresh mango',
#  'large cloves garlic',
#  'cilantro, chopped',
#  'pork belly block',
#  'anchovy stock (water is ok)',
#  'Lemon wedges',
#  'maguro tataki (chopped tuna for negitoro)',
#  'braised pork ribs',
#  'frozen Kawan parathas',
#  'red bean curd plus 1 teaspoon juice',
#  'mandarin orange peel',
#  'cucumbers',
#  'dried rosemary',
#  'Cucumber',
#  'shrimp (about 16 medium-size shrimp)',
#  'chicken breast or thigh',
#  'chocolate syrup',
#  'napa cabbage kimchi',
#  'mustard seeds',
#  'bitter melon (bitter gourd or goya)',
#  'dried basil',
#  'bone-in chicken leg-and-thigh portions',
#  'cucumbers sliced',
#  'minari',
#  'uncooked sticky rice',
#  'euryale seeds',
#  'turmeric ground',
#  'orange peppers',
#  'homemade chicken stock',
#  'dried Chinese chili peppers',
#  'ground lamb leg',
#  'cauliflower head',
#  'chicken knuckles',
#  'small russet potato',
#  'cornichons or gherkins',
#  'quinoa',
#  'allspice',
#  'powdered agar agar',
#  'round mochi (rice cake)',
#  'Roasted black sesame seeds',
#  'shiitake dashi',
#  'Chee Hou sauce',
#  'shortening',
#  'red food coloring',
#  'dry chickpeas',
#  'shredded green cabbage',
#  'sashimi-grade albacore tuna',
#  'fingerroots',
#  'black sesame seeds',
#  'cucumber',
#  'kinome leaves',
#  'hot green chilies',
#  'Sesame oil for pan frying',
#  ...}

# %% [markdown]
# ----
# ## Save Processed Data
#
# Export the cleaned dataset for further use.

# %%
# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("./data/all_recipes.db")

# Save DataFrame to SQL database
df_combined.to_sql("recipes", conn, if_exists="replace", index=False)

# Close the connection
conn.close()

print("Data saved to database!")
# Out:
# Data saved to database!
